# %% [markdown]
# ###  html kodu ile veri çekme

# %%
import pandas as pd
from bs4 import BeautifulSoup

# Verilen HTML kodu

html_code = """<html><head>
  <base href="https://www.felgenshop.de/">
        <style data-tippy-stylesheet="">.tippy-box[data-animation=fade][data-state=hidden]{opacity:0}[data-tippy-root]{max-width:calc(100vw - 10px)}.tippy-box{position:relative;background-color:#333;color:#fff;border-radius:4px;font-size:14px;line-height:1.4;white-space:normal;outline:0;transition-property:transform,visibility,opacity}.tippy-box[data-placement^=top]>.tippy-arrow{bottom:0}.tippy-box[data-placement^=top]>.tippy-arrow:before{bottom:-7px;left:0;border-width:8px 8px 0;border-top-color:initial;transform-origin:center top}.tippy-box[data-placement^=bottom]>.tippy-arrow{top:0}.tippy-box[data-placement^=bottom]>.tippy-arrow:before{top:-7px;left:0;border-width:0 8px 8px;border-bottom-color:initial;transform-origin:center bottom}.tippy-box[data-placement^=left]>.tippy-arrow{right:0}.tippy-box[data-placement^=left]>.tippy-arrow:before{border-width:8px 0 8px 8px;border-left-color:initial;right:-7px;transform-origin:center left}.tippy-box[data-placement^=right]>.tippy-arrow{left:0}.tippy-box[data-placement^=right]>.tippy-arrow:before{left:-7px;border-width:8px 8px 8px 0;border-right-color:initial;transform-origin:center right}.tippy-box[data-inertia][data-state=visible]{transition-timing-function:cubic-bezier(.54,1.5,.38,1.11)}.tippy-arrow{width:16px;height:16px;color:#333}.tippy-arrow:before{content:"";position:absolute;border-color:transparent;border-style:solid}.tippy-content{position:relative;padding:5px 9px;z-index:1}</style><link rel="shortcut icon" href="https://www.felgenshop.de/source/skin/default/img/icon/favicon_felgenshop.ico" type="image/x-icon">
    <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
  <meta http-equiv="content-language" content="de-de">

  <meta http-equiv="cache-control" content="no-cache">
  <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">
  <meta name="google-site-verification" content="u3OCwjptvmqICOeDty31bT2sT3Ix1lj9toIfbCTcQBU">
  <meta name="google-site-verification" content="Vg69M9l0gdG3TVR5sKMVj_8IB5J7Mwro879jCJ506_w">
  <meta name="p:domain_verify" content="3fc6b197e03299c9919a4ea1c79a827b">
      <meta name="robots" content="INDEX,FOLLOW">
  
  
<meta name="description" content="Reifen bekannter Marken für PKWs mit Alufelgen als Komplettrad oder ohne Felgen online günstig kaufen. Sommerreifen, Winterreifen, Allwetterreifen / Ganzjahresreifen. | felgenshop.de">
<title>Reifen günstig online kaufen</title>

    
  <!-- Kameleoon Integration -->
  <script type="text/javascript" charset="utf-8" async="" src="//widgets.trustedshops.com/js/X29D756F9C95ACDD6CBBE4712BEE04289.js"></script><script>window.kameleoonQueue = window.kameleoonQueue || [];</script>
      <script src="https://q2uvcjpjdk.kameleoon.eu/kameleoon.js" async=""></script>
    <!-- End Kameleoon Integration -->

  <script>
    // dataLayer = [];
    gtmEnhancedEcommerce = true;
    var articlesOnPage = 0;
    var articlesPushed = false;
    var dfShopId = 1;
  </script>
    
  
  
        
    
        

      <script>
    var ajax_basearticle_id = 'reifen';
        var pkw_motor_id = '0';
                  var search_redirect = 'https://www.felgenshop.de/alufelgen/';
      </script>

  
  
  <!-- <script src="https://www.felgenshop.de/source/skin/default/js/fahrzeugauswahl__3544552712.js" type="text/javascript" charset="utf-8"></script> -->

    
  
                                                        <link rel="canonical" href="https://www.felgenshop.de/reifen/">
                                                                                                                                              <link rel="alternate" href="https://www.felgenshop.de/reifen/" hreflang="de-DE">
                                                                                                                                                                                              <link rel="alternate" href="https://www.alufelgenshop.at/reifen/" hreflang="de-AT">
                                                                                                                                                                                              <link rel="alternate" href="https://velonity.fr/pneus/" hreflang="fr-FR">
                                                                                                                                                                                              <link rel="alternate" href="https://velonity.dk/daek/" hreflang="da-DK">
                                                                                                                                                                                              <link rel="alternate" href="https://velonity.com/tyre/" hreflang="en-GB">
                                                                                                                                                                                              <link rel="alternate" href="https://velonity.se/daeck/" hreflang="sv-SE">
                                                                                                                                                                                              <link rel="alternate" href="https://velonity.es/neumaticos/" hreflang="es-ES">
                                                                                                                                                                                              <link rel="alternate" href="https://velonity.pl/opony/" hreflang="pl-PL">
                                                                        








 

<link type="text/css" href="/minified/877625f4a8414f8f68756909041b46b0.css" rel="stylesheet">

<script src="/minified/877625f4a8414f8f68756909041b46b0.js"></script><style id="css-ddslick" type="text/css">.dd-select{ border-radius:2px; border:solid 1px #ccc; position:relative; cursor:pointer;}.dd-desc { color:#aaa; display:block; overflow: hidden; font-weight:normal; line-height: 1.4em; }.dd-selected{ overflow:hidden; display:block; padding:10px; font-weight:bold;}.dd-pointer{ width:0; height:0; position:absolute; right:10px; top:50%; margin-top:-3px;}.dd-pointer-down{ border:solid 5px transparent; border-top:solid 5px #000; }.dd-pointer-up{border:solid 5px transparent !important; border-bottom:solid 5px #000 !important; margin-top:-8px;}.dd-options{ border:solid 1px #ccc; border-top:none; list-style:none; box-shadow:0px 1px 5px #ddd; display:none; position:absolute; z-index:2000; margin:0; padding:0;background:#fff; overflow:auto;}.dd-option{ padding:10px; display:block; border-bottom:solid 1px #ddd; overflow:hidden; text-decoration:none; color:#333; cursor:pointer;-webkit-transition: all 0.25s ease-in-out; -moz-transition: all 0.25s ease-in-out;-o-transition: all 0.25s ease-in-out;-ms-transition: all 0.25s ease-in-out; }.dd-options > li:last-child > .dd-option{ border-bottom:none;}.dd-option:hover{ background:#f3f3f3; color:#000;}.dd-selected-description-truncated { text-overflow: ellipsis; white-space:nowrap; }.dd-option-selected { background:#f6f6f6; }.dd-option-image, .dd-selected-image { vertical-align:middle; float:left; margin-right:5px; max-width:64px;}.dd-image-right { float:right; margin-right:15px; margin-left:5px;}.dd-container{ position:relative;}​ .dd-selected-text { font-weight:bold}​</style>            <script>
            var initLegalText;
            # !function (e, n) {
                function t(e, n, t, a, i, s, l, r, o) {
                    var d = {};
                    this.getProductChangeIndex = function () {
                        var e = Object.keys(d), n = -1;
                        return e[e.length - 1] >= r && (n = e.reduce(function (e, n, t) {
                            return n < r ? t : e
                        }, -1)), n
                    }, this.calcMonthlyRates = function () {
                        return d = function e(n, t, a, i, s, l, r, o) {
                            var d = l, u = d / 100 + 1, c = 1 / 12, h = Math.pow(u, c),
                                v = Math.floor((Math.pow(1 + d / 100, c) - 1) * 12e4) / 100, f = 0, g = 0, $ = {};
                            if (0 !== n) for (var p = t; p <= a; p += i) {
                                if (p < 72 && (h = Math.pow(u = (d = o) / 100 + 1, c), v = Math.floor((Math.pow(1 + d / 100, c) - 1) * 12e4) / 100), p < 60 && (h = Math.pow(u = (d = r) / 100 + 1, c), v = Math.floor((Math.pow(1 + d / 100, c) - 1) * 12e4) / 100), p < 12 && (h = Math.pow(u = (d = l) / 100 + 1, c), v = Math.floor((Math.pow(1 + d / 100, c) - 1) * 12e4) / 100), p < s && (h = Math.pow(u = (d = 0) / 100 + 1, c), v = Math.floor((Math.pow(1 + d / 100, c) - 1) * 12e4) / 100), 0 === d) g = Math.floor(n / p * 100) / 100, f = n; else {
                                    var m = Math.pow(h, p);
                                    g = Math.floor(n * m / (m - 1) * (h - 1) * 100) / 100, f = Math.floor(n * m / (m - 1) * (h - 1) * 100) / 100 * p
                                }
                                parseFloat(g) >= 9 && ($[p] = {
                                    months: p,
                                    amount: n,
                                    monthlyInstallment: g,
                                    interestRate: v,
                                    effInterestRate: d,
                                    total: f,
                                    interestValue: f - n
                                })
                            }
                            return $
                        }(o, e, n, t, a, i, s, l)
                    }
                }

                n.fn.calculator = function (a) {
                    var i = this, s = n(e), l = a.inputProductPriceFlag, r = !1;

                    function o(e, n, t, a, i) {
                        var s, l, r, o;
                        return null == n && (n = 2), null == t && (t = ""), null == a && (a = ""), "" + t + (e = (e = (s = e, l = n, r = i, "function" != typeof r && (r = Math.round), o = Math.pow(10, l), r(s * o) / o)).toLocaleString("de-DE", {
                            useGrouping: !1,
                            minimumFractionDigits: n
                        })) + a
                    }

                                        var calculator_template = '<div class="calculator"><div class="row"><div class="col-xs-12 col-lg-4"><div class="calculator-wrapper"><div class="calculator-title"> Ihr möglicher <span class="nowrap">Finanzierungsplan<sup>1</sup></span></div><div class="finance-amount"><div class="finance-amount-label">Finanzierungsbetrag</div><div class="finance-amount-value"><input class="autosize" value="00.00" title="Finanzierungsbetrag"><span class="unit">&euro;</span></div><div class="ubernehmen-button"><input class="btn btn-change-value submit" type="submit" value="Übernehmen"></div></div><div class="duration"><div class="duration-label"> GEWÜNSCHTE <span class="nowrap">ANZAHL AN RATEN</span></div><div class="duration-value"><button class="prev-month"><span class="arrow-icon left"/></button><button class="month">1</button><button class="month selected">2</button><button class="month">3</button><button class="next-month"><span class="arrow-icon right"/></button></div></div><div class="more-months-switch"><div class="more-month-label"> Zusätzliche Monatsraten anzeigen</div><div class="more-month-button-wrapper"><div class="button"><div class="button-label">Nein</div><div class="button-label on">Ja</div></div></div></div><div class="financial-box"><div class="monthly-rate"><div class="monthly-rate-label"> Monatliche Rate <span class="nowrap">für Ihren Einkauf</span></div><div class="monthly-rate-value-wrapper"><span class="unit">&euro;</span><span class="monthly-rate-value">00,00</span></div></div><!-- less months --><div class="show-on-less-month"><div class="interest-rate financial-box-detail"><div class="interest-rate-label detail-label"> Sollzinssatz für diesen Einkauf <span class="nowrap"> für <span class="months">0</span> Monate (jährl., gebunden):</span></div><div class="interest-rate-value detail-value nowrap">0,00 %</div></div><div class="interest-value financial-box-detail"><div class="interest-value-label detail-label"> Mögliche Sollzinsen <span class="nowrap"> für diesen Einkauf:</span></div><div class="interest-value-value detail-value nowrap">0,00 &euro;</div></div></div><!-- more month --><div class="show-on-more-month"><div class="interest-rate financial-box-detail"><div class="interest-rate-label detail-label"> Sollzinssatz für <span class="months">0</span> Monate (jährl., gebunden):</div><div class="interest-rate-value detail-value nowrap">0,00 %</div></div><div class="eff-interest-rate financial-box-detail"><div class="detail-label">Effektiver Jahreszinssatz:</div><div class="eff-interest-rate-value detail-value nowrap">0,00 %</div></div><div class="amount financial-box-detail"><div class="detail-label">Nettodarlehensbetrag:</div><div class="amount-value detail-value nowrap">0,00 €</div></div><div class="interest-value financial-box-detail"><div class="detail-label">Sollzinsen:</div><div class="interest-value-value detail-value nowrap">0,00 %</div></div><div class="total financial-box-detail"><div class="detail-label">Gesamtbetrag:</div><div class="total-value detail-value nowrap">0,00 €</div></div></div></div></div></div><div class="col-xs-12 col-lg-8"><ul class="legal-text"><li><strong><sup>1</sup>Gesetzlicher Hinweistext</strong></li><li class="show-on-more-month"> Finanzierung über einen bonitätsabhängigen Ratenkredit. Kaufpreis entspricht dem Nettodarlehensbetrag; Angaben zugleich repräsentatives Beispiel i. S. d. § 17 Abs. 4 PAngV.</li><li class="legal-1 show-on-less-month"> Finanzierung Ihres Einkaufs (Ratenplan-Verfügung) über den Kreditrahmen mit Mastercard<sup>®</sup>, den Sie wiederholt in Anspruch nehmen können. Nettodarlehensbetrag bonitätsabhängig bis 15.000 &euro;. 17,90 % effektiver Jahreszinssatz. Vertragslaufzeit auf unbestimmte Zeit.</li><li class="show-on-less-month"><strong><u>Ratenplan-Verfügung:</u></strong> Gebundener Sollzinssatz von <span class="campaign-interest-rate">0,00 %</span> (jährlich) gilt nur für die ersten <span class="campaign-duration">0</span> Monate ab Vertragsschluss (Zinsbindungsdauer); Sie müssen monatliche Teilzahlungen in der von Ihnen gewählten Höhe leisten. Führen Sie Ihre Ratenplan-Verfügung nicht innerhalb der Zinsbindungsdauer zurück, gelten die Konditionen für Folgeverfügungen.</li><li class="show-on-less-month"><strong><u>Folgeverfügungen:</u></strong> Für andere und künftige Verfügungen (Folgeverfügungen) beträgt der veränderliche Sollzinssatz (jährlich) 16,58 % (falls Sie bereits einen Kreditrahmen bei uns haben, kann der tatsächliche veränderliche Sollzinssatz abweichen). Für Folgeverfügungen müssen Sie monatliche Teilzahlungen in der von Ihnen gewählten Höhe, mind. aber 2,5% der jeweils höchsten, auf volle 100 € gerundeten Sollsaldos der Folgeverfügungen (mind. 9 €) leisten. Zahlungen für Folgeverfügungen werden erst auf verzinste Folgeverfügungen angerechnet, bei unterschiedlichen Zinssätzen zuerst auf die höher verzinsten.</li><li class="show-on-less-month">Angaben zugleich repräsentatives Beispiel gem. § 17 Abs. 4 PAngV. Gültig für Kunden ab 18 Jahren mit Wohnsitz in Deutschland, gültigem Personalausweis oder Reisepass (Nicht-EU-Bürger i.V.m. gültigem Aufenthaltstitel), gültiger EC-Karte auf eigenen Namen und Mindestnettoeinkommen von 450 € (ohne Kindergeld). Selbständige: Finanzierung nur für private Zwecke, mind. 24 Monate Selbständigkeit. Ggfs. wird ein aktueller Gehalts-/Einkommensnachweis benötigt. Vermittlung erfolgt ausschließlich für den Kreditgeber BNP Paribas S.A. Niederlassung Deutschland, Rüdesheimer Straße 1, 80686 München. Widerrufsrecht: Der Darlehensnehmer kann seine Vertragserklärung innerhalb von 14 Tagen ohne Angabe von Gründen widerrufen. Zur Wahrung der Widerrufsfrist genügt die rechtzeitige Absendung des Widerrufs, wenn die Erklärung auf einem dauerhaften Datenträger (z.B. Brief, Telefax, E-Mail) erfolgt. Der Widerruf ist zu richten an: BNP Paribas S.A. Niederlassung Deutschland, Wuhanstraße 5, 47051 Duisburg (Fax: 02 03/34 69 54-09; Tel.: 02 03/34 69 54-02; E- Mail: widerruf@consorsfinanz.de).</li></ul><div class="consors-finance-images"><img src="https://www.felgenshop.de/source/skin/default/img/Consors_Finanz_Finanzierungsprozess_tbm.png" alt="ConsorsFinanzProzess" title="Finanzieren Sie sich Ihre Felgen bequem mit der Consors Finanz"><img class="consors-logo" src="https://www.felgenshop.de/source/skin/default/img/consorsfinanz_logo_gross.png" alt="ConsorsFinanz" title="Finanzieren Sie sich Ihre Felgen bequem mit der Consors Finanz"></div></div></div></div>'
                    
                    return a = n.extend({
                        minMonth: 6,
                        maxMonth: 72,
                        stepMonth: 1,
                        zeroMonth: 0,
                        firstInterestRate: 9.9,
                        secondInterestRate: 9.9,
                        thirdInterestRate: 9.9,
                        productChangeMonth: 74,
                        productPrice: !1,
                        variablePrice: !1,
                        $legalTexts: null,
                        template: calculator_template
                    }, a), this.each(function () {
                        # !function e(i) {
                            var d, u, c, h, v, f, g, $, p, m, _, b, w, x, z;

                            function C(e) {
                                (void 0 != (l = (a = n.extend(a, e)).inputProductPriceFlag) && l || a.variablePrice) && null != a.$legalTexts && (initLegalText = a.$legalTexts), ($ = i.find(".duration")).parent().hasClass("duration-slider-wrapper") ? ($ = i.find(".duration-slider .duration.duration-less"), p = i.find(".duration-slider .duration.duration-more")) : ($.wrap('<div class="duration-slider"></div>').wrap('<div class="duration-slider-wrapper"></div>'), (p = $.clone(!1)).addClass("duration-more"), p.insertAfter($.addClass("duration-less")));
                                var s = i.find(".finance-amount-value input");
                                s.off("change.calculator").on("change.calculator", function () {
                                    var e = n(this), t = e.val();
                                    isNaN(t) && (t = t.replace(/,/, ".")), isNaN(parseFloat(t)) || isNaN(t) || t < 54 ? e.addClass("invalid") : (e.removeClass("invalid"), C({
                                        productPrice: t,
                                        variablePrice: !0
                                    }))
                                }), s.autosize(), d = i.find(".duration .duration-value .prev-month"), c = i.find(".duration .duration-value .next-month"), u = i.find(".duration .duration-value .month"), f = $.find(".duration-value .month"), g = p.find(".duration-value .month"), v = (h = i.find(".more-months-switch")).find(".button"), w = Object.keys(b = (_ = new t(a.minMonth, a.maxMonth, a.stepMonth, a.zeroMonth, a.firstInterestRate, a.secondInterestRate, a.thirdInterestRate, a.productChangeMonth, a.productPrice)).calcMonthlyRates()), z = (x = _.getProductChangeIndex()) > -1 ? Math.min(x, w.length - 1) : w.length - 1, i.hasClass("more-month") && (v.removeClass("on"), R(!1)), M();
                                var r = "click.calculator";
                                d.off(r).on(r, function () {
                                    # !n(this).is(":disabled") && z - 1 >= 0 && (z -= 1, M())
                                }), c.off(r).on(r, function () {
                                    # !n(this).is(":disabled") && z + 1 < w.length && (z += 1, M())
                                }), u.off(r).on(r, function (e) {
                                    var t = n(this);
                                    if (!t.hasClass("calculator-duration-selected")) {
                                        var a = t.html(), i = w.indexOf(a);
                                        i >= 0 && (z = i, M())
                                    }
                                }), v.off(r).on(r, function () {
                                    var e = n(this);
                                    e.hasClass("on") ? (e.removeClass("on"), R(!1), z = z > x ? x : z) : x > -1 && (z = x + 1, e.addClass("on"), R(!0)), M()
                                })
                            }

                            function M() {
                                var e = w[z], t = n(".show-on-less-month"), a = n(".show-on-more-month");
                                if (x > -1 && z > x ? (t.hide(), a.show()) : (t.show(), a.hide()), l || (t.find(".campaign-interest-rate").text("0,00 %"), t.find(".campaign-duration").text("0")), m = initLegalText, b.hasOwnProperty(e)) {
                                    var r, u, v, $, p = b[e];
                                    (function e() {
                                        d.eq(0).prop("disabled", z <= 0), c.eq(0).prop("disabled", z + 1 >= w.length), x > -1 && (c.eq(0).prop("disabled", z >= x), d.eq(1).prop("disabled", z - 1 <= x), c.eq(1).prop("disabled", z + 1 >= w.length));
                                        var n = [z - 1, z, z + 1], t = 1, a = n, i = t;
                                        z - 1 < 0 && (t = 0, n = 1 === x ? [0, 1] : 0 === x ? [0] : [0, 1, 2]);
                                        var s = w.length - 1;
                                        x > -1 && (s = x), z >= s && (s >= 2 ? (t = 2, n = [s - 2, s - 1, s]) : 1 === s ? (t = 1, n = [s - 1, s, -1]) : (t = 0, n = [s, -1, -1])), x > -1 && (z - 1 <= x && (i = 0, a = [x + 1, x + 2, x + 3]), z + 1 >= w.length && (w.length - x - 1 == 1 ? (i = 0, a = [w.length - 1]) : w.length - x - 1 == 2 ? (i = 1, a = [w.length - 2, w.length - 1]) : (i = 2, a = [w.length - 3, w.length - 2, w.length - 1]))), f.removeClass("selected").hide(), g.removeClass("selected").hide();
                                        for (var l = 0; l < 3; l++) {
                                            var r = f.eq(l), o = n[l];
                                            void 0 !== w[o] ? (r.text(w[o]), t === l && r.addClass("selected")) : r.html("&nbsp;"), r.show();
                                            var u = g.eq(l), h = a[l];
                                            void 0 !== w[h] ? (u.text(w[h]), i === l && u.addClass("selected")) : u.html("&nbsp;"), u.show()
                                        }
                                    })(), x > -1 && (z >= x || i.hasClass("more-month")) ? h.slideDown(600).animate({opacity: 1}, {
                                        queue: !1,
                                        duration: 600
                                    }) : h.slideUp(600).animate({opacity: 0}, {
                                        queue: !1,
                                        duration: 600
                                    }), r = p, i.find(".finance-amount .finance-amount-value input").val(o(r.amount, 2)), i.find(".financial-box .monthly-rate .monthly-rate-value").text(o(r.monthlyInstallment)), i.find(".financial-box .interest-rate .months").text(o(r.months, 0)), i.find(".financial-box .interest-rate .interest-rate-value").text(o(r.interestRate, 2, "", " %", Math.floor)), i.find(".financial-box .interest-value .interest-value-value").text(o(r.interestValue, 2, "", " €")), i.find(".financial-box .eff-interest-rate .eff-interest-rate-value").text(o(r.effInterestRate, 2, "", " %", Math.floor)), i.find(".financial-box .amount .amount-value").text(o(r.amount, 2, "", " €")), i.find(".financial-box .total .total-value").text(o(r.total, 2, "", " €")), i.find("input.autosize").autosize(), u = p, v = b[w[w.length - 1]].interestRate, $ = b[w[w.length - 1]].effInterestRate, m.find(".campaign-interest-rate").text(o(u.interestRate, 2, "", " %", Math.floor)), m.find(".campaign-duration").text(o(u.months, 0)), s.trigger("calculator-ui-updated", [i])
                                }
                            }

                            function R(e) {
                                var n = i.find(".duration-slider").width();
                                i.find(".duration-slider-wrapper").css("left", (e ? "-=" : "+=") + n), e ? i.addClass("more-month") : i.removeClass("more-month")
                            }

                            i.html(a.template), r || (initLegalText = i.find("ul.legal-text"), r = !0), void 0 == l || l || (m = i.find("ul.legal-text").empty()), m = null === a.$legalTexts ? i.find("ul.legal-text") : i.find("ul.legal-text").appendTo(n(a.$legalTexts)), i.reload = C, i.updateUI = M, i.generateTableBody = function e() {
                                var t = [];
                                return n.each(b, function (e, a) {
                                    var i = n("<tr/>");
                                    i.append(n("<td>" + o(e, 0) + "</td>")), i.append(n("<td>" + o(a.monthlyInstallment, 2, "", " €") + "</td>")), i.append(n("<td>" + o(a.interestRate, 2, "", " %", Math.floor) + "</td>")), t.push(i)
                                }), t
                            }, C()
                        }(i)
                    })
                }, n.fn.autosize = function () {
                    var e = this;
                    return this.each(function () {
                        # !function e(n) {
                            if (n.next().hasClass("autosize-helper")) {
                                n.trigger("input.autosize");
                                return
                            }
                            n.css("width", 90)
                        }(e)
                    })
                }
            }(window, window.jQuery);
        </script>
    




        <script>
          var url_hash = window.location.hash;
          var regex = /&?\??(gclid)=([\d\w]+)/gm;
          var m = regex.exec(url_hash);
          if(m != null) {
              if(m.length > 2) {
                  if(m[1] == "gclid") {
                      var searchparameter = window.location.search;
                      if(searchparameter.length > 0) searchparameter = searchparameter+"&";
                      else searchparameter = searchparameter+"?";
                      searchparameter = searchparameter+"gclid="+m[2];
                      history.replaceState(null, "", window.location.pathname+searchparameter+window.location.hash);
                  }
              }
          }
      </script>
  

<script>
    var google_optimize_experiment_id = 0;
    var google_optimize_experiment_variation_id = 0;
    </script>



<script>
    var cookieFuncStack = {
        "df-cookie-essenziell": [],
        "df-cookie-marketing": [],
        "df-cookie-statistiken": [],
        "df-cookie-externe-medien": []
    };

    // This function checks if a given cookie is set
    function cookieIsset(name, callback){
        if(document.cookie.indexOf(name) > -1) {
            if(typeof callback === "function") callback();
            return true;
        } else {
            if(typeof callback === "function") cookieFuncStack[name].push(callback);
            return false;
        }
    }

    // Open CookieOptInModal
    function openCookieOptInModal(){
        $('.keksbox-checkbox').each(function (key, element) {
            var checkbox = $(element).siblings('input');
            if(cookieIsset($(element).data('keks-name'))){
                checkbox.prop('checked', true);
                $(element).addClass('checked');
                $(element).attr('src', '/source/skin/default/img/fsv2/icon/icon-checkbox.svg');
            }
        })
        $('.keksbox-overlay-layer').removeClass('d-none');
        $('.keksbox-overlay').removeClass('d-none');
    }
</script>



    <!-- Google tag (gtag.js) -->
            <script>
            cookieIsset('df-cookie-marketing', function () {
                var gtagScript = document.createElement('script');
                gtagScript.async = true;
                gtagScript.setAttribute('src', 'https://ads.df-automotive.de/www.googletagmanager.com/gtag/js?id=G-B2NPTSGSFZ');
                document.head.appendChild(gtagScript);
            });
        </script>
    
    <script>
        window.dataLayer = window.dataLayer || [];
        function gtag(){dataLayer.push(arguments);}

        gtag('consent', 'default', {
            'ad_storage': 'granted',
            'analytics_storage': 'granted'
        });

        gtag('js', new Date());
                gtag('config', 'AW-976086976', { 'allow_enhanced_conversions': true });
                        gtag('config', 'G-B2NPTSGSFZ');
                        gtag('config', 'UA-56120586-1');
            </script>
    <!-- End Google tag (gtag.js) -->



<!-- Google Tag Manager -->
    <script>
        cookieIsset('df-cookie-marketing', function () {
            (function (w, d, s, l, i) {
                w[l] = w[l] || [];
                w[l].push({
                    'gtm.start':
                        new Date().getTime(), event: 'gtm.js'
                });
                var f = d.getElementsByTagName(s)[0],
                    j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
                j.async = true;
                j.src =
                    'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
                f.parentNode.insertBefore(j, f);
            })(window, document, 'script', 'dataLayer', 'GTM-52P48C');
        });
    </script>
<!-- End Google Tag Manager -->

<!--Start Kameleoon Consent-->
<script>
    cookieIsset('df-cookie-essenziell', function () {
        setTimeout(function () {
            if (cookieIsset('df-cookie-marketing')) {
                kameleoonQueue.push(['Core.enableLegalConsent']);
            } else {
                kameleoonQueue.push(['Core.disableLegalConsent']);
            }
        }, 500);
    });
</script>
<!--END Kameleoon Consent-->


      <script>
        function fbq_api(event_name, params, id) {
            $.post('/ajax_fbq', {
                event_name: event_name,
                params: params,
                event_id: id
            });
        }
    </script>

    <script>
      //Facebook
      cookieIsset('df-cookie-marketing', function () {
        # !function(f,b,e,v,n,t,s)
        {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
          n.callMethod.apply(n,arguments):n.queue.push(arguments)};
          if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
          n.queue=[];t=b.createElement(e);t.async=!0;
          t.src=v;s=b.getElementsByTagName(e)[0];
          s.parentNode.insertBefore(t,s)}(window, document,'script',
          'https://connect.facebook.net/en_US/fbevents.js');
        fbq('init', '250148212425438');
        const pageViewId = ("" + Date.now() + Math.random()).replace(".","");

        fbq('track', 'PageView', {}, {eventID: pageViewId});
        fbq_api('PageView',{}, pageViewId);
      });

      // Pinterest Pixel Base Code
      cookieIsset('df-cookie-marketing', function () {
        # !function(e){if(!window.pintrk){window.pintrk=function(){window.pintrk.queue.push(
          Array.prototype.slice.call(arguments))};var
          n=window.pintrk;n.queue=[],n.version="3.0";var
          t=document.createElement("script");t.async=!0,t.src=e;var
          r=document.getElementsByTagName("script")[0];r.parentNode.insertBefore(t,r)}}("https://s.pinimg.com/ct/core.js");
        pintrk('load', '2613184998098');
        pintrk('page');
      });
      // End Pinterest Pixel Base Code

            // TikTok Pixel Base Code
      cookieIsset('df-cookie-marketing', function () {
          # !function (w, d, t) {
              w.TiktokAnalyticsObject = t;
              var ttq = w[t] = w[t] || [];
              ttq.methods = ["page", "track", "identify", "instances", "debug", "on", "off", "once", "ready", "alias", "group", "enableCookie", "disableCookie"], ttq.setAndDefer = function (t, e) {
                  t[e] = function () {
                      t.push([e].concat(Array.prototype.slice.call(arguments, 0)))
                  }
              };
              for (var i = 0; i < ttq.methods.length; i++) ttq.setAndDefer(ttq, ttq.methods[i]);
              ttq.instance = function (t) {
                  for (var e = ttq._i[t] || [], n = 0; n < ttq.methods.length; n++) ttq.setAndDefer(e, ttq.methods[n]);
                  return e
              }, ttq.load = function (e, n) {
                  var i = "https://analytics.tiktok.com/i18n/pixel/events.js";
                  ttq._i = ttq._i || {}, ttq._i[e] = [], ttq._i[e]._u = i, ttq._t = ttq._t || {}, ttq._t[e] = +new Date, ttq._o = ttq._o || {}, ttq._o[e] = n || {};
                  var o = document.createElement("script");
                  o.type = "text/javascript", o.async = !0, o.src = i + "?sdkid=" + e + "&lib=" + t;
                  var a = document.getElementsByTagName("script")[0];
                  a.parentNode.insertBefore(o, a)
              };
              ttq.load('CG2TF03C77UCL8BN9TC0');
              ttq.page();
          }(window, document, 'ttq');
      });
      function ttq_api(event, data, event_id) {
          $.post('/ajax_ttq', {
              data: data,
              event: event,
              event_id: event_id,
              url: window.location.href
          });
      }
      // END TikTok Pixel Base Code
      
      </script>


      
    <script type="text/javascript">
      var _paq = window._paq || [];
      var _learnq = _learnq || [];
    </script>


    
    <script>
        var url_hash = window.location.hash;
        var regex = /&(gclid)=([\d\w]+)/gm;
        var m = regex.exec(url_hash);
        if(m != null) {
            if(m.length > 2) {
                if(m[1] == "gclid") {
                    var searchparameter = window.location.search;
                    if(searchparameter.length > 0) searchparameter = searchparameter+"&";
                    else searchparameter = searchparameter+"?";
                    searchparameter = searchparameter+"gclid="+m[2];
                    history.replaceState(null, "", window.location.pathname+searchparameter+window.location.hash);
                }
            }
        }
    </script>

<link rel="stylesheet" href="" type="text/css"><style type="text/css" data-aphrodite=""></style></head>

<body style="min-height: auto;">
    
    <!-- Google Tag Manager (noscript) -->
    <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-52P48C"
                      height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
    <!-- End Google Tag Manager (noscript) -->


  
  
<div id="lochanzahl_popup" class="z-depth-3">
  <div id="lochanzahl_popup_inner">
    <p>Wähle Deinen Lochkreis</p>
    <div id="lochanzahl_popup_list" class="row">
          </div>
  </div>
</div>


<script type="application/ld+json">
  {
    "@context": "http://schema.org",
    "@type": "LocalBusiness",
    "url": "https://www.felgenshop.de/",
    "name": "felgenshop.de",
    "image": "https://www.felgenshop.de/source/skin/default/img/logo.png",
    "telephone": "0461 430415-20",
    "address": {
      "@type": "PostalAddress",
      "streetAddress": "Marie-Curie-Ring 13",
      "postalCode": "24941",
      "addressLocality": "Flensburg",
      "addressCountry": "DE"
    }
  }
</script>
<!-- gclid Parameter in Session speichern -->

<!-- Übersetzungsfunktion -->
<script>
    var adyen_language = 'de-DE'
    var adyen_country = 'DE'
    var translate_kreditkarte = 'Kreditkarte'
    var translate_modell_waehlen = 'Modell wählen'
</script>

<div class="fs-debug" style="display: none;">
                                          </div>
<div class="fs-wrapper clearfix">
    <div class="fs-header clearfix">
        <nav class="navbar pmd-navbar">
      <div class="container-fluid z-depth-1">
        <div class="head-section-wrap clearifx">
                    <div class="row">
            <div class="top-bar clearfix">
              <div class="col-xs-12">
                <ul>
                  <li>
                    <a class="no-click" href="#">
                                                    <i class="icon">
                                <img alt="icon-kostenloser-versand" src="data:image/svg+xml;base64,...">
                            </i>
                            Kostenloser Versand                                            </a>
                  </li>
                  <li class="widerruf-mobile">
                    <a class="no-click" href="#">
                                                    <img src="source/skin/default/img/icon-group-top-nav.svg" style="height: 15px" alt="icon-group-top-nav">
                            Über 400.000 zufriedene Kunden                                            </a>
                  </li>
                  <li>
                    <a href="https://www.felgenshop.de/faq/">
                      <i class="icon">
                        <img alt="icon-faq" src="data:image/svg+xml;base64,...">
                      </i>
                        Beratung durch Experten                    </a>
                  </li>
                                      <li>
                      <a href="https://www.trustedshops.com/shop/certificate.php?shop_id=X29D756F9C95ACDD6CBBE4712BEE04289&amp;tb" target="_blank">
                        <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/navigation/trusted_shops_logo_32.png" width="16" height="17" alt="trustedshops">
                        Sicher einkaufen                      </a>
                    </li>
                                                            <li style="margin-right: 0">
                        <a href="#" class="no-click">
                          <img src="data:image/svg+xml;base64,..." width="16" height="17" alt="icon-phone">
                          0461 430415-20                        </a>
                      </li>
                                        <li class="region-list-and-login">
                                                    <a class="nav-login-button" href="https://www.felgenshop.de/login/">
                                <i class="icon">
                                    <img alt="icon-login" src="data:image/svg+xml;base64,...">
                                </i>
                                Login</a>
                                                <div class="region-list">
                                                            <span class="region-select current-region">
                                                                                                                        <img src="/source/skin/default/FSCheckoutV3/img/country/de.svg" alt="DE">
                                                                                                            </span>
                                                    </div>
                    </li>
                </ul>
              </div>
            </div>
          </div>
            <div class="region-select-wrapper" style="display: none">
                <div class="region-select-container" style="display: none">
                    <div class="region-select-header">
                        <span class="region-select-mobile-title ">Land auswählen</span>
                        <span class="region-select-desktop-title ">Land wählen</span>
                        <img data-src="/source/skin/default/img/chevron-down.svg" alt="chevron-down" class="desktop-version-icon">
                        <img data-src="/source/skin/default/img/times.svg" alt="x" class="mobile-version-icon">
                    </div>
                    <div class="region-select-body">
                        <div class="region-select-current-country">
                            <div class="region-select-name-flag">
                                                                                                            <img data-src="/source/skin/default/FSCheckoutV3/img/country/de.svg" class="region-select-country-img" alt="DE">
                                        <span class="region-select-current-country-name">Deutschland</span>
                                                                                                </div>
                            <img data-src="/source/skin/default/img/check.svg" alt="check" class="region-select-check">
                        </div>
                                                                                                                                                    <a class="region-select-country" href="https://velonity.dk">
                                        <img data-src="/source/skin/default/FSCheckoutV3/img/country/dk.svg" class="region-select-country-img" alt="DK">
                                        <span class="region-select-country-name">Dänemark</span>
                                    </a>
                                                                                                                                                                                                                                            <a class="region-select-country" href="https://velonity.fr/">
                                        <img data-src="/source/skin/default/FSCheckoutV3/img/country/fr.svg" class="region-select-country-img" alt="FR">
                                        <span class="region-select-country-name">Frankreich</span>
                                    </a>
                                                                                                                                                                                                                <a class="region-select-country" href="https://www.alufelgenshop.at">
                                        <img data-src="/source/skin/default/FSCheckoutV3/img/country/at.svg" class="region-select-country-img" alt="AT">
                                        <span class="region-select-country-name">Österreich</span>
                                    </a>
                                                                                                                                                                                                                <a class="region-select-country" href="https://velonity.pl/">
                                        <img data-src="/source/skin/default/FSCheckoutV3/img/country/pl.svg" class="region-select-country-img" alt="PL">
                                        <span class="region-select-country-name">Polen</span>
                                    </a>
                                                                                                                                                                                                                <a class="region-select-country" href="https://velonity.se/">
                                        <img data-src="/source/skin/default/FSCheckoutV3/img/country/se.svg" class="region-select-country-img" alt="SE">
                                        <span class="region-select-country-name">Schweden</span>
                                    </a>
                                                                                                                                                                                                                <a class="region-select-country" href="https://velonity.es/">
                                        <img data-src="/source/skin/default/FSCheckoutV3/img/country/es.svg" class="region-select-country-img" alt="ES">
                                        <span class="region-select-country-name">Spanien</span>
                                    </a>
                                                                                                        </div>
                </div>
            </div>
                    <div class="row">
            <div class="search-info clearfix">
                            <div class="col-xs-8 col-sm-4 col-md-4 col-lg-4 small-logo">
                  <div class="logo">
    <div onclick="window.location.href='//www.felgenshop.de'">
        <a class="logo-img" href="https://www.felgenshop.de">
                                        <svg class="fs-logo" id="Ebene_1" data-name="Ebene 1" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 338.9 52.6">
    <defs>
        <style>.fs-logo .cls-1 {
                fill: #65b32e !important;
            }

            .fs-logo .cls-2 {
                fill: #585d6a !important;
            }</style>
    </defs>
    <title>Felgenshop-Logo</title>
    <path class="cls-1" d="M80.5,240.6V236h4v-1.4q0-10.8,9.6-10.8a10.551,10.551,0,0,1,3.1.4v4.6a8.578,8.578,0,0,0-2.2-.2,10.364,10.364,0,0,0-2,.1,6.393,6.393,0,0,0-1.6.6,3.149,3.149,0,0,0-1.3,1.8,11.205,11.205,0,0,0-.4,3.5V236h7.5v4.6H89.7v24.8H84.4V240.6H80.5Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-1" d="M100.4,250.8c0-10.2,4.3-15.3,12.8-15.3h.1a12.055,12.055,0,0,1,9.3,3.8c2.3,2.5,3.5,5.9,3.5,10.2,0,1.4-.1,2.7-.2,4h-20c.6,5,3.4,7.4,8.2,7.4a20.8,20.8,0,0,0,10-2.2v4.8a25.26,25.26,0,0,1-10.1,1.9h-.2a17.268,17.268,0,0,1-4.7-.6,13.772,13.772,0,0,1-4.2-2.1,9.675,9.675,0,0,1-3.2-4.5A17.175,17.175,0,0,1,100.4,250.8Zm5.3-2.1h14.9a12.611,12.611,0,0,0-.5-2.8,10.656,10.656,0,0,0-1.2-2.7,6.1,6.1,0,0,0-2.3-2.2,7.845,7.845,0,0,0-3.5-.8c-2.4,0-4.2.6-5.4,1.9C106.6,243.4,105.9,245.6,105.7,248.7Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-1" d="M131,265.4V224.9h5.3v40.5Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-1" d="M142.7,250.2c0-4.5,1-8.1,3-10.7,2-2.7,5.1-4,9.4-4a13.514,13.514,0,0,1,8.4,2.4,8,8,0,0,1,3.2,6.8v21.5a10.46,10.46,0,0,1-.6,3.6,9.678,9.678,0,0,1-1.9,3.2,9.4,9.4,0,0,1-3.9,2.5,19.734,19.734,0,0,1-6.4.9,31.328,31.328,0,0,1-8.6-1.2v-5a28.388,28.388,0,0,0,8.1,1.2,17.473,17.473,0,0,0,4.5-.5,3.933,3.933,0,0,0,2.4-1.4,4.771,4.771,0,0,0,.8-1.6,8.116,8.116,0,0,0,.1-1.7v-2.5a23.8,23.8,0,0,1-5.8.8c-4.1,0-7.3-1.2-9.5-3.6A17.455,17.455,0,0,1,142.7,250.2Zm5.3,0c0,3.8.7,6.3,2,7.5a8.053,8.053,0,0,0,5.6,1.9,15.754,15.754,0,0,0,5.8-1.1V244.3a3.749,3.749,0,0,0-.1-1.1,11.816,11.816,0,0,0-.6-1.3,3,3,0,0,0-1.9-1.2,12.329,12.329,0,0,0-3.6-.4,9,9,0,0,0-2.5.3,6.363,6.363,0,0,0-2.2,1.3,5.741,5.741,0,0,0-1.7,3.1A12.918,12.918,0,0,0,148,250.2Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-1" d="M171.9,250.8c0-10.2,4.3-15.3,12.8-15.3h.1a12.055,12.055,0,0,1,9.3,3.8c2.3,2.5,3.5,5.9,3.5,10.2,0,1.4-.1,2.7-.2,4h-20c.6,5,3.4,7.4,8.2,7.4a20.8,20.8,0,0,0,10-2.2v4.8a25.26,25.26,0,0,1-10.1,1.9h-.2a17.268,17.268,0,0,1-4.7-.6,13.772,13.772,0,0,1-4.2-2.1,9.675,9.675,0,0,1-3.2-4.5A18.812,18.812,0,0,1,171.9,250.8Zm5.4-2.1h14.9a12.611,12.611,0,0,0-.5-2.8,10.656,10.656,0,0,0-1.2-2.7,6.1,6.1,0,0,0-2.3-2.2,7.845,7.845,0,0,0-3.5-.8c-2.4,0-4.2.6-5.4,1.9C178.2,243.4,177.5,245.6,177.3,248.7Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-1" d="M203.1,265.4v-27a27.209,27.209,0,0,1,12.3-3c3.7,0,6.5,1,8.6,2.9a10.176,10.176,0,0,1,3.1,7.9v19.2h-5.4V245.8a5.676,5.676,0,0,0-1.3-4c-.9-1-2.6-1.5-5.3-1.5a22.011,22.011,0,0,0-6.8,1.1v24Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-2" d="M233.6,243.8a7.79,7.79,0,0,1,2.5-5.9c1.7-1.6,4.3-2.5,7.7-2.5a16.787,16.787,0,0,1,7.4,1.8v4.2a13.508,13.508,0,0,0-7-2c-4.4,0-6.5,1.5-6.5,4.4a2.641,2.641,0,0,0,1.6,2.4,17.633,17.633,0,0,0,3.9,1.5,41.068,41.068,0,0,1,4.6,1.5,9.1,9.1,0,0,1,3.9,2.9,8.067,8.067,0,0,1,1.6,5.2,6.9,6.9,0,0,1-2.8,5.9,12.9,12.9,0,0,1-7.8,2.1,17.691,17.691,0,0,1-8.8-2.2v-4.4a16.273,16.273,0,0,0,8.6,2.6c4.4,0,6.6-1.3,6.6-4a4,4,0,0,0-1.6-3.4,11.673,11.673,0,0,0-3.9-1.8c-1.5-.4-3.1-.9-4.6-1.3a8.826,8.826,0,0,1-3.9-2.4A6.882,6.882,0,0,1,233.6,243.8Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-2" d="M258.6,265.4V224.9h4.2v12.3a22.6,22.6,0,0,1,8.7-1.8c3.6,0,6.3,1.1,8.2,3.2s2.9,5.2,2.9,9.1v17.7h-4.2V247.7c0-5.4-2.5-8.1-7.4-8.1a21.075,21.075,0,0,0-8.3,1.8v24Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-2" d="M289.1,257.9a21.069,21.069,0,0,1-1.2-7.5,20.689,20.689,0,0,1,1.2-7.5,10.145,10.145,0,0,1,3.3-4.6,15.934,15.934,0,0,1,4.3-2.2,17.5,17.5,0,0,1,4.8-.6,18.022,18.022,0,0,1,4.8.6,11.74,11.74,0,0,1,4.3,2.2,10.719,10.719,0,0,1,3.3,4.6,24.037,24.037,0,0,1,0,15,10.145,10.145,0,0,1-3.3,4.6,15.934,15.934,0,0,1-4.3,2.2,19.5,19.5,0,0,1-9.6,0,12.566,12.566,0,0,1-4.3-2.2A10.145,10.145,0,0,1,289.1,257.9Zm5.2-16c-1.5,1.8-2.2,4.6-2.2,8.5s.7,6.7,2.2,8.5,3.9,2.7,7.2,2.7,5.7-.9,7.2-2.6c1.5-1.8,2.3-4.6,2.3-8.5s-.8-6.7-2.3-8.5-3.9-2.6-7.2-2.6S295.8,240.1,294.3,241.9Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-2" d="M320.4,276.2V244.5a6.723,6.723,0,0,1,.4-2.4,10.73,10.73,0,0,1,1.4-2.9,7.414,7.414,0,0,1,3.7-2.8,18.85,18.85,0,0,1,9.7-.8,9.832,9.832,0,0,1,3.3,1.3,11.022,11.022,0,0,1,3.1,2.6,13.485,13.485,0,0,1,2.2,4.5,22.173,22.173,0,0,1,.9,6.7,19.565,19.565,0,0,1-1.2,7.3,9.675,9.675,0,0,1-3.2,4.5,13.772,13.772,0,0,1-4.2,2.1,17.268,17.268,0,0,1-4.7.6,25.682,25.682,0,0,1-7.2-1.1v12h-4.2Zm4.2-16.2a17.142,17.142,0,0,0,7.2,1.4c3.2,0,5.5-.8,6.9-2.5s2.1-4.4,2.1-8.2a20.984,20.984,0,0,0-.8-6.1,6.434,6.434,0,0,0-2.2-3.5,9.14,9.14,0,0,0-2.7-1.5,11.935,11.935,0,0,0-2.9-.4c-5.1,0-7.7,1.7-7.7,5.1V260Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-2" d="M351.5,265.3v-4.6h4.2v4.6Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-2" d="M364.2,250a19.565,19.565,0,0,1,1.2-7.3,9.675,9.675,0,0,1,3.2-4.5,13.772,13.772,0,0,1,4.2-2.1,17.268,17.268,0,0,1,4.7-.6,24.619,24.619,0,0,1,7.2,1.1V224.9h4.2v31.3a9.863,9.863,0,0,1-.3,2.4,10.73,10.73,0,0,1-1.4,2.9,7.3,7.3,0,0,1-3.7,2.7,18.48,18.48,0,0,1-9.6.8,10.71,10.71,0,0,1-3.3-1.3,11.023,11.023,0,0,1-3.1-2.6,12.578,12.578,0,0,1-2.2-4.5A16.3,16.3,0,0,1,364.2,250Zm4.2,0a20.984,20.984,0,0,0,.8,6.1,6.839,6.839,0,0,0,4.9,4.9,11.934,11.934,0,0,0,2.9.4c5.1,0,7.7-1.7,7.7-5.1V240.6a18.446,18.446,0,0,0-7.2-1.4c-3.2,0-5.5.8-6.9,2.5S368.4,246.3,368.4,250Z" transform="translate(-80.5 -223.8)"></path>
    <path class="cls-2" d="M394.1,250.8v-.4c0-10,4.2-14.9,12.7-14.9a14.194,14.194,0,0,1,4.8.8,10.905,10.905,0,0,1,3.4,2,10.149,10.149,0,0,1,2.2,3c.6,1.2,1.1,2.3,1.4,3.1a12.168,12.168,0,0,1,.6,3.1,12.515,12.515,0,0,1,.2,2.2v1.2l-.1,2h-21q.45,4.35,2.7,6.3c1.5,1.3,3.8,2,6.7,2,4.2,0,7.5-.7,9.9-2.2v4.3a23.929,23.929,0,0,1-10.1,2h-.2a17.8,17.8,0,0,1-4.7-.6,13.772,13.772,0,0,1-4.2-2.1,9.676,9.676,0,0,1-3.2-4.5A20.036,20.036,0,0,1,394.1,250.8Zm4.2-1.6h17a17.959,17.959,0,0,0-.2-2.2,21.511,21.511,0,0,0-1-3.1,7.863,7.863,0,0,0-2.6-3.2,8.663,8.663,0,0,0-4.7-1.3c-2.9,0-5,.7-6.3,2.2S398.5,245.6,398.3,249.2Z" transform="translate(-80.5 -223.8)"></path>
</svg>
                    </a>
    </div>
</div>
              </div>
                            <div class="col-xs-6 col-sm-4 col-md-4 col-lg-4 hidden-xs">
                <div class="search">
                  <form class="clearfix" name="js-search">
                    <input type="text" id="js-search-input" name="search" placeholder="Artikelsuche..." class="ie-search-height">
                    <button type="submit" class="pmd-ripple-effect">
                      <i class="icon">
                        <img alt="icon-search" src="data:image/svg+xml;base64,...">
                      </i>
                    </button>
                  </form>
                </div>
              </div>
                            <div class="col-xs-4 col-sm-4 col-md-4 col-lg-4 small-info">
                <div class="info">
                    <label for="fs-sidenav">
                      <span class="menu-tag">
                        <i class="icon menu-icon">
                          <img alt="icon-menu" src="...">
                        </i>
                      </span>
                    </label>
                  <ul>
                    <li>
                      <span><strong>30 Tage</strong></span>
                      <span>Widerrufsrecht</span>
                    </li>
                    <li>
                    <a href="https://www.trustedshops.com/shop/certificate.php?shop_id=X29D756F9C95ACDD6CBBE4712BEE04289&amp;tb" target="_blank">
                        <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/navigation/trusted_shops_logo_32.png" width="32" height="32" alt="trustedshops">
                      </a>
                    </li>
                    <li>
                                                                              <img width="34" height="32" alt="continental-approved" data-src="/source/skin/default/img/approved-online-shop.png" class="" src="/source/skin/default/img/approved-online-shop.png">
                                                                      </li>
                    <li>
                                                                                  <a href="https://www.df-automotive.de" target="_blank">
                                <img class="df-logo-navigation" data-src="https://www.felgenshop.de/source/skin/default/img/fsv2/navigation/logo_ohne_pictos.png" width="50" height="28" alt="df-logo" src="https://www.felgenshop.de/source/skin/default/img/fsv2/navigation/logo_ohne_pictos.png">
                              </a>
                                                                        </li>
                    <li class="search-toggle pmd-ripple-effect d-none">
                      <label for="mobile-search">
                        <i class="icon">
                          <img alt="icon-mobile-search" src="data:image/svg+xml;base64,...">
                        </i>
                      </label>
                    </li>
                                          <li>
                      <span class="basket">
                          <span class="setlink" onclick="setLink('https://www.felgenshop.de/warenkorb/')">
                            <span id="basket_value" class="d-none d-sm-inline">
                                                                  379,71 €                                                            </span>
                              <i class="icon">
                                                                      <img alt="icon-basket" src="data:image/svg+xml;base64,...">
                                                                </i>
                              <div class="df-basket-counter-badge">
                                  <div class="counter-number">

                                  </div>
                              </div>
                          </span>
                      </span>
                    </li>
                  </ul>
                </div>
              </div>
            </div>
          </div>
                    <div class="row">
            <div class="mega-menu clearfix">
              <div class="col-xs-12 on-top">
                <ul>
                  <li>
                                          <a href="https://www.felgenshop.de/alufelgen/">Felgen</a>
                                      </li>
                                      <li class="has-sub">
                      <a href="https://www.felgenshop.de/reifen/">Reifen</a>
                      <ul>
                        <div>
                          <li class="link">
                            <a href="https://www.felgenshop.de/sommerreifen/">Sommerreifen</a>
                          </li>
                        </div>
                        <div>
                          <li class="link">
                              <a href="https://www.felgenshop.de/winterreifen/">Winterreifen</a>
                          </li>
                        </div>
                        <div>
                          <li class="link">
                              <a href="https://www.felgenshop.de/allwetterreifen-ganzjahresreifen/">Ganzjahresreifen</a>
                          </li>
                        </div>
                      </ul>
                    </li>
                                    <li>
                    <a href="https://www.felgenshop.de/marken/">Marken</a>
                  </li>
                                      <li>
                      <a href="https://www.felgenshop.de/blog/">Blog</a>
                    </li>
                                    <li>
                    <a href="https://www.felgenshop.de/faq/">FAQ</a>
                  </li>
                                      <li>
                      <a href="https://www.felgenshop.de/3d-felgenkonfigurator/">3D Felgenkonfigurator</a>
                    </li>
                                                        <li>
                        <a class="aktionen-red">Aktionen</a>
                    </li>
                                  </ul>
              </div>
            </div>
          </div>
        </div>
      </div>
    </nav>
  </div>
    <div class="fs-cookie-hint">
    <div class="col-xs-12">
      <div id="cookiesNotEnabled" class="cookie-hint">
        Felgenshop verwendet Cookies, um Ihnen den bestmöglichen Service zu gewährleisten. <b>Bitte aktivieren Sie Cookies in Ihrem Webbrowser.</b>
      </div>
    </div>
  </div>

        <div class="campaignpopup-container" style="display: none">
        <div class="campaignpopup">
            <div class="campaignpopup-header">
                <p>Aktionen</p>
                <img class="campaignpopup-close" src="..." alt="close">
            </div>
                                                <div class="campaignpopup-body">
                        <div class="campaign-img-wrapper">
                            <img class="campaign-img" data-src="https://ministatic.df-automotive.de/aktionsuebersicht/nachhaltigkeitsmonat-aktionsuebersicht.jpg" alt="campaign-image">
                        </div>
                        <div class="campaignpopup-content">
                            <div class="campaignpopup-content-header">
                                <p class="campaignname">GREEN MONTH</p>
                                                                                                    <span class="time"><img src="data:image/svg+xml;base64,..." alt="clock">Endet in 17d 7h</span>
                                                            </div>
                            <img class="campaign-img-mobile" data-src="https://ministatic.df-automotive.de/aktionsuebersicht/nachhaltigkeitsmonat-aktionsuebersicht.jpg" alt="campaign-image">
                            <div class="campaign-description">
                                <p><span style="font-size: 14px;">Für jede&nbsp;Bestellung, mit den ausgewählten Artikeln unserer Partner Borbet, Ronal, Brock/RC-Design und Nokian Tyres, lassen wir einen Baum pflanzen. Dazu legt ihr lediglich die ausgewählten Artikel von Borbet, Ronal, Brock/RC-Design und/oder Nokian Tyres bei der Bestellung mit in den Warenkorb und wir erledigen den Rest. Es entstehen keine Mehrkosten für euch, wir übernehmen den vollen Betrag für das Pflanzen eines Baumes inklusive Zertifikat.</span></p>
                            </div>

                            
                                                        <div class="campaign-conditions">
                                <span class="conditions-title">Teilnahmebedingungen<img class="conditions-icon" data-src="/source/skin/default/img/chevron_down.png" alt="Arrow" width="16px"></span>
                                <div class="conditions-list">
                                    <p><span style="font-size:12px;">• <strong>Produkte</strong>:<br>
<strong>Borbet</strong> N<br>
<strong>Ronal</strong> R70, R71<br>
<strong>Brock</strong> B43, B41, B32<br>
<strong>RC-Design</strong> RC34, RC32<br>
sowie das gesamte <strong>NOKIAN TYRES</strong> Sortiment</span></p>

<p><span style="font-size:12px;">•​ <strong>Mindestbestellwert</strong>: 0€<br>
•​ <strong>kombinierbar</strong></span></p>
                                </div>
                            </div>
                                                    </div>
                    </div>
                <hr>
                                                                <div class="campaignpopup-body">
                        <div class="campaign-img-wrapper">
                            <img class="campaign-img" data-src="https://ministatic.df-automotive.de/aktionsuebersicht/pirelli-tyrelife.png" alt="campaign-image">
                        </div>
                        <div class="campaignpopup-content">
                            <div class="campaignpopup-content-header">
                                <p class="campaignname">TYRELIFE - REIFENGARANTIE VON PIRELLI</p>
                                                                                            </div>
                            <img class="campaign-img-mobile" data-src="https://ministatic.df-automotive.de/aktionsuebersicht/pirelli-tyrelife.png" alt="campaign-image">
                            <div class="campaign-description">
                                <p><span style="font-size:14px;">Sicher unterwegs sein ist einfach, spart Geld und Nerven!<br>
Profitiere im Schadensfall von der kostenlosen Tyrelife Reifengarantie und sichere deine im Felgenshop erworbenen Pirelli Reifen ab.</span></p>
                            </div>

                            
                                                        <div class="campaign-conditions">
                                <span class="conditions-title">Teilnahmebedingungen<img class="conditions-icon" data-src="/source/skin/default/img/chevron_down.png" alt="Arrow" width="16px"></span>
                                <div class="conditions-list">
                                    <p><span style="font-size:12px;"><strong>Das sind die Voraussetzungen</strong><br>
•&nbsp;Du hast mindestens 2 garantiefähige Pirelli Reifen im Felgenshop gekauft.<br>
•&nbsp;Die Reifen haben eine Größe von mindestens 17 Zoll.</span></p>

<p><span style="font-size:12px;"><strong>Das musst du tun:</strong><br>
•&nbsp;Registriere dich innerhalb von 4 Wochen ab Kaufdatum auf My Pirelli.<br>
•&nbsp;Aktiviere dort die Tyrelife Reifengarantie.<br>
•&nbsp;Lade deine Rechnung aus dem Felgenshop fristgerecht bei Pirelli hoch und erhalte eine Bestätigungsmail mit deinem persönlichen Tyrelife Code und deiner PIN.</span></p>

<p><span style="font-size:12px;"><strong>Höhe des Erstattungsbetrags im Garantiefall</strong><br>
•&nbsp;1. Halbjahr: 100%<br>
•&nbsp;2. Halbjahr: 50%<br>
•&nbsp;2. Jahr: 25%</span></p>

<p><span style="font-size:12px;"><strong>Weitere Infos findest du unter</strong></span></p>

<p><u><span style="font-size:12px;">https://www.pirelli.com/tyres/de-de/pkw/reifen-angebote-und-aktionen/tyrelife</span></u></p>
                                </div>
                            </div>
                                                    </div>
                    </div>
                <hr>
                                    </div>
    </div>

    <!--Aktionsbanner-->
            <div class="aktionsbannerv2-container" style="background-color: #32803B; color: #FFFFFF;">
        <div class="aktionsbannerv2-mobile-info">
            <svg xmlns="http://www.w3.org/2000/svg" class="aktionsbannerv2-info openPopup" style="padding-left: 8px" width="16" height="16" viewBox="0 0 16 16">
                <path id="info-circle" d="M16,8a8,8,0,1,0,8,8A8,8,0,0,0,16,8Zm0,3.548A1.355,1.355,0,1,1,14.645,12.9,1.355,1.355,0,0,1,16,11.548Zm1.806,8.194a.387.387,0,0,1-.387.387H14.581a.387.387,0,0,1-.387-.387v-.774a.387.387,0,0,1,.387-.387h.387V16.516h-.387a.387.387,0,0,1-.387-.387v-.774a.387.387,0,0,1,.387-.387h2.065a.387.387,0,0,1,.387.387v3.226h.387a.387.387,0,0,1,.387.387Z" transform="translate(-8 -8)" fill="#ffffff"></path>
            </svg>
        </div>
        <div class="aktionsbannerv2-content">
            <div class="aktionsbannerv2-box left">
                <div class="aktionsbannerv2-amount">
                                        <span class="aktionsbannerv2-addon">powered by</span>
                </div>
                <div class="aktionsbannerv2-description">NOKIAN • BORBET • RONAL • BROCK / RC-DESIGN</div>
            </div>
            <div class="aktionsbannerv2-box center">
                <div class="aktionsbannerv2-title">GREEN MONTH</div>
                                    <div class="aktionsbannerv2-mobile-timer-replacement">Radsatz kaufen, Baum pflanzen</div>
                            </div>
            <div class="aktionsbannerv2-box right">
                <div class="aktionsbannerv2-code-title">Radsatz kaufen,</div>
                                    <div class="aktionsbannerv2-code info openPopup">
                        <span>
                            Baum pflanzen                            <svg xmlns="http://www.w3.org/2000/svg" class="aktionsbannerv2-info aktionsbannerv2-code-icon" width="16" height="16" viewBox="0 0 16 16">
                                <path id="info-circle" d="M16,8a8,8,0,1,0,8,8A8,8,0,0,0,16,8Zm0,3.548A1.355,1.355,0,1,1,14.645,12.9,1.355,1.355,0,0,1,16,11.548Zm1.806,8.194a.387.387,0,0,1-.387.387H14.581a.387.387,0,0,1-.387-.387v-.774a.387.387,0,0,1,.387-.387h.387V16.516h-.387a.387.387,0,0,1-.387-.387v-.774a.387.387,0,0,1,.387-.387h2.065a.387.387,0,0,1,.387.387v3.226h.387a.387.387,0,0,1,.387.387Z" transform="translate(-8 -8)" fill="#ffffff"></path>
                            </svg>
                        </span>
                    </div>
                            </div>
        </div>
        <div class="aktionsbannerv2-close">
            <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16.001" viewBox="0 0 16 16.001">
                <path id="times" d="M10.387,104l5.386-5.386a.8.8,0,0,0,0-1.129l-1.252-1.252a.8.8,0,0,0-1.129,0l-5.386,5.387L2.621,96.232a.8.8,0,0,0-1.129,0L.241,97.483a.8.8,0,0,0,0,1.129L5.627,104,.241,109.384a.8.8,0,0,0,0,1.129l1.252,1.252a.8.8,0,0,0,1.129,0l5.386-5.387,5.386,5.386a.8.8,0,0,0,1.129,0l1.252-1.252a.8.8,0,0,0,0-1.129Z" transform="translate(-0.008 -95.997)" fill="#ffffff"></path>
            </svg>
        </div>
    </div>

    <!-- <input type="checkbox" name="fs-sidenav" id="fs-sidenav"/> -->
  <div class="fs-sidenav" data-sidebar="navigation">
      <ul>
          <li>
              <!--              <input type="checkbox" name="mobile-search" id="mobile-search"/>-->
              <div class="container-fluid mobile-search clearfix">
                  <div class="row">
                      <div class="slide-search clearfix">
                          <div class="col-xs-12">
                              <form method="post" name="js-search">
                                  <input type="text" name="search" id="js-search-input-mobile" placeholder="Artikelsuche..." class="ie-search-height">
                                  <button class="pmd-ripple-effect" type="submit">
                                      <i class="icon">
                                          <img alt="icon-search" src="data:image/svg+xml;base64,...">
                                      </i>
                                  </button>
                              </form>
                          </div>
                      </div>
                  </div>
              </div>
          </li>
          <li class="side-nav-title"><a href="#">Navigation</a></li>
          <li class="link">
              <a href="https://www.felgenshop.de">Startseite</a>
          </li>
          <li class="link">
                          <a href="https://www.felgenshop.de/alufelgen/">Felgen</a>
                      </li>
                      <li class="link has-sub">
              <input type="checkbox" id="reifen" name="reifen">
              <label for="reifen" class="ripple">Reifen</label>
              <ul>
                <li class="link">
                  <a href="https://www.felgenshop.de/reifen/">Reifen</a>
                </li>
                <li class="link">
                  <a href="https://www.felgenshop.de/sommerreifen/">Sommerreifen</a>
                </li>
                <li class="link">
                  <a href="https://www.felgenshop.de/winterreifen/">Winterreifen</a>
                </li>
                <li class="link">
                  <a href="https://www.felgenshop.de/allwetterreifen-ganzjahresreifen/">Ganzjahresreifen</a>
                </li>
              </ul>
            </li>
                    <li class="link">
            <a href="https://www.felgenshop.de/marken/">Marken</a>
          </li>
                      <li class="link">
              <a class="ripple" href="https://www.felgenshop.de/blog/">Blog</a>
            </li>
                    <li class="link">
            <a class="ripple" href="https://www.felgenshop.de/faq/">FAQ</a>
          </li>
                      <li class="link">
              <a class="ripple" href="https://www.felgenshop.de/3d-felgenkonfigurator/">3D Felgenkonfigurator</a>
            </li>
                                <li class="link">
              <a class="ripple aktionen-red">Aktionen</a>
            </li>
                    <li class="link leading"> <a class="ripple" href="#">Kundenkonto</a></li>
                      <li class="link"> <a class="ripple" href="https://www.felgenshop.de/login/">Login</a></li>
                    <li class="link leading">
            <a href="https://www.df-automotive.de" target="_blank">DF-Automotive</a>
          </li>
                                              <li class="link">
                <a class="ripple" href="https://www.df-automotive.de/unternehmen/ueber-uns/" target="_blank">Über uns</a>
              </li>
                                                <li class="link ">
                <a class="ripple" href="https://www.df-automotive.de/karriere/df-als-arbeitgeber/" target="_blank">Karriere</a>
              </li>
                                                                <li class="link">
                  <a class="ripple" href="https://www.felgenshop.de/impressum/">Impressum</a>
                </li>
                                                                              <li class="link">
                  <a class="ripple" href="https://www.felgenshop.de/kontakt/">Kontakt</a>
                </li>
                                                                              <li class="link">
                  <a class="ripple" href="https://www.felgenshop.de/B2B/">B2B</a>
                </li>
                                              <li class="link leading"><a class="ripple" href="#">Informationen</a></li>
                                              <li class="link">
                <a class="ripple" href="https://www.felgenshop.de/meinebestellungen/">Meine Bestellungen</a>
              </li>
                                                <li class="link">
                <a class="ripple" href="https://www.felgenshop.de/retouren/">Retouren
</a>
              </li>
                                                <li class="link">
                <a class="ripple" href="https://www.felgenshop.de/faq/">FAQ</a>
              </li>
                                                <li class="link">
                <a class="ripple" href="https://www.felgenshop.de/datenschutz/">Datenschutz</a>
              </li>
                                                <li class="link">
                <a class="ripple" href="https://www.felgenshop.de/agb/">AGB</a>
              </li>
                            </ul>
  </div>
  <div class="sidenav-overlay"></div>

    <!-- Region-Select Popup -->
    <div class="rs-popup-container" style="display: none" data-shop-id="1" data-remote-shop-id="" data-rs-shop-id="1">
        <div class="rs-popup-body">
            <span class="rs-popup-close"><img src="..." alt="close-icon" width="24px"></span>
            <div class="rs-popup-content">
                <div class="rs-popup-text">
                    <p class="rs-title">It looks like you are in a different country.</p>
                                            <p>Do you want to switch to the <b>international</b> store?</p>
                                    </div>
                <div class="rs-popup-button">
                                            <button class="fs-btn rs-btn goto" data-suggested-url="">Go to
                                                        <img class="" data-src="/source/skin/default/FSCheckoutV3/img/country/com.svg">
                                                    </button>
                                        <button class="fs-btn rs-btn stayon">Stay on
                                                    <img class="" data-src="/source/skin/default/FSCheckoutV3/img/country/de.svg" alt="flag">
                                            </button>
                </div>
            </div>
        </div>
    </div>

    <div class="fs-base clearfix">


                <!-- <div class="container">
          <div class="row">
            <div class="col-xs-12">
              <div class="subpage">
                              </div>
            </div>
          </div>
        </div> -->
    
<div class="fhz-banner">
    <div class="emotion">
        <div>
                            <img class="abs tire-banner" src="https://www.felgenshop.de/source/skin/default/img/fsv2/reifen/tirebanner.webp" alt="Reifenbanner">
                    </div>
    </div>
</div>

<div class="container-fluid">
    <div class="row colored">
        <div class="container">
            <div class="row">
                <div class="col-xs-12">
                    <div class="heading">
                        
<div class="breadcrumbstyle">
  <ol id="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
    <ul>
      <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
      <a itemprop="item" href="/">
        <span itemprop="name">Startseite</span></a>
        <meta itemprop="position" content="0">
      </li>
      <span itemprop="">/</span>
              <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
                                    <a itemprop="item" href="https://www.felgenshop.de/reifen/">
                <div class="lastbreadcrumb" itemprop="name">Reifen</div>
              </a>
                                <meta itemprop="position" content="1">
        </li>
                  </ul>
  </ol>
  </div>

                        <h1>Reifen günstig online kaufen</h1>
                    </div>
                </div>
            </div>
        </div>
    </div>
</div>

<div class="tire-select-overlay-background"></div>

<div class="container-fluid tire-container-max-width">
    <div class="row d-md-flex justify-content-center">
                <div class="col-xs-12 col-md-3 mb-4">
            <div class="tire-filter">
                <div class="row">
                    <div class="col-xs-12">
                        <div class="tire-size-vehicle-filter-container">
                            <div class="tire-size-vehicle-filter">
                                <span class="tire-size-vehicle-filter-text left active">Reifengröße</span>
                                <div class="tire-size-vehicle-filter-button-slide">
                                    <div class="tire-size-vehicle-filter-button"></div>
                                </div>
                                <span class="tire-size-vehicle-filter-text right">PKW-Auswahl</span>
                            </div>
                        </div>
                    </div>

                    <div class="col-xs-12 vehicle-select-filter">
                        <div class="chosen-wrap">
                                                        <span class="vehicle-filter-label">Hersteller</span>
                            <div class="select-wrap first">
<select id="overlay_pkw_hersteller" tabindex="-1" class="select2-hidden-accessible" aria-hidden="true"><option value="">Hersteller wählen</option><option value="96">Aiways</option><option value="28">Alfa Romeo</option><option value="66">Aston Martin</option><option value="3">Audi</option><option value="58">Austin</option><option value="106">B-ON</option><option value="109">Baic</option><option value="70">Bentley</option><option value="4">BMW</option><option value="80">BMW Alpina</option><option value="110">Borgward</option><option value="108">Bugatti</option><option value="105">BYD</option><option value="61">Cadillac</option><option value="37">Chevrolet</option><option value="18">Chrysler</option><option value="36">Citroen</option><option value="55">Corvette</option><option value="91">Cupra</option><option value="56">Dacia</option><option value="38">Daewoo</option><option value="62">Daihatsu</option><option value="78">DeLorean</option><option value="104">Dethleffs</option><option value="98">DFSK</option><option value="63">Dodge</option><option value="90">DS Automobiles</option><option value="39">Ferrari</option><option value="16">Fiat</option><option value="85">Fisker</option><option value="5">Ford</option><option value="100">Genesis</option><option value="71">Holden</option><option value="11">Honda</option><option value="40">Hummer</option><option value="22">Hyundai</option><option value="107">Ineos</option><option value="67">Infiniti</option><option value="72">Isuzu</option><option value="93">Iveco</option><option value="41">Jaguar</option><option value="42">Jeep</option><option value="43">Kia</option><option value="88">KTM</option><option value="73">Lada</option><option value="68">Lamborghini</option><option value="44">Lancia</option><option value="45">Land Rover</option><option value="111">LEVC</option><option value="13">Lexus</option><option value="46">Lotus</option><option value="99">Lynk &amp; Co</option><option value="47">Maserati</option><option value="87">Maybach</option><option value="19">Mazda</option><option value="84">McLaren</option><option value="8">Mercedes</option><option value="48">MG</option><option value="49">Mini</option><option value="21">Mitsubishi</option><option value="102">Nio</option><option value="20">Nissan</option><option value="94">NSU</option><option value="15">Opel</option><option value="26">Peugeot</option><option value="103">Pössl</option><option value="95">Polestar</option><option value="75">Pontiac</option><option value="7">Porsche</option><option value="65">Proton</option><option value="50">Renault</option><option value="92">Renault Alpine</option><option value="89">Rolls Royce</option><option value="51">Rover</option><option value="17">Saab</option><option value="76">Saturn</option><option value="77">Scion</option><option value="10">Seat</option><option value="9">Skoda</option><option value="23">Smart</option><option value="64">Ssangyong</option><option value="52">Subaru</option><option value="97">Sunbeam</option><option value="25">Suzuki</option><option value="86">Tesla</option><option value="12">Toyota</option><option value="53">Trabant</option><option value="1">Volkswagen (VW)</option><option value="24">Volvo</option></select><span class="select2 select2-container select2-container--default" dir="ltr" style="width: 100%;"><span class="selection"><span class="select2-selection select2-selection--single" role="combobox" aria-haspopup="true" aria-expanded="false" tabindex="0" aria-labelledby="select2-overlay_pkw_hersteller-container"><span class="select2-selection__rendered" id="select2-overlay_pkw_hersteller-container" title="Hersteller wählen">Hersteller wählen</span><span class="select2-selection__arrow" role="presentation"><b role="presentation"></b></span></span></span><span class="dropdown-wrapper" aria-hidden="true"></span></span>
</div>
                            <span class="vehicle-filter-label vehicle-filter-label-baugruppe">Baugruppe</span>
                             <div class="select-wrap ">
    <select id="overlay_pkw_baugruppe" disabled="" tabindex="-1" class="select2-hidden-accessible" aria-hidden="true"><option value="">Baugruppe wählen</option></select><span class="select2 select2-container select2-container--default select2-container--disabled" dir="ltr" style="width: 100%;"><span class="selection"><span class="select2-selection select2-selection--single" role="combobox" aria-haspopup="true" aria-expanded="false" tabindex="-1" aria-labelledby="select2-overlay_pkw_baugruppe-container"><span class="select2-selection__rendered" id="select2-overlay_pkw_baugruppe-container" title="Baugruppe wählen">Baugruppe wählen</span><span class="select2-selection__arrow" role="presentation"><b role="presentation"></b></span></span></span><span class="dropdown-wrapper" aria-hidden="true"></span></span>
</div>
                            <span class="vehicle-filter-label">Modell</span>
                            <script>
    var baujahr_translate ="(Baujahr)";
</script>
<div class="select-wrap">
<select id="overlay_pkw_modell" class="show_baujahr select2-hidden-accessible" disabled="" tabindex="-1" aria-hidden="true"><option value="">Modell wählen</option></select><span class="select2 select2-container select2-container--default select2-container--disabled" dir="ltr" style="width: 100%;"><span class="selection"><span class="select2-selection select2-selection--single" role="combobox" aria-haspopup="true" aria-expanded="false" tabindex="-1" aria-labelledby="select2-overlay_pkw_modell-container"><span class="select2-selection__rendered" id="select2-overlay_pkw_modell-container" title="Modell wählen">Modell wählen</span><span class="select2-selection__arrow" role="presentation"><b role="presentation"></b></span></span></span><span class="dropdown-wrapper" aria-hidden="true"></span></span>
</div>                            <span class="vehicle-filter-label">motor</span>
                            <div class="select-wrap">
<select id="overlay_pkw_motor" disabled="" tabindex="-1" class="select2-hidden-accessible" aria-hidden="true"><option value="">Motor wählen</option></select><span class="select2 select2-container select2-container--default select2-container--disabled" dir="ltr" style="width: 100%;"><span class="selection"><span class="select2-selection select2-selection--single" role="combobox" aria-haspopup="true" aria-expanded="false" tabindex="-1" aria-labelledby="select2-overlay_pkw_motor-container"><span class="select2-selection__rendered" id="select2-overlay_pkw_motor-container" title="Motor wählen">Motor wählen</span><span class="select2-selection__arrow" role="presentation"><b role="presentation"></b></span></span></span><span class="dropdown-wrapper" aria-hidden="true"></span></span>
</div>
                                                    </div>
                    </div>

                    <div class="col-xs-12 d-flex justify-content-center">
                        <div class="tire-filter-visuell-image">
                            <div class="tire-filter-visuell-text">
                                <svg viewBox="0 0 500 500" id="svg-text-first">
                                    <path fill="transparent" id="curve" d="M89,169c4-6.1,65-96,148-95c111,-11.2,170,90,175,97"></path>
                                    <text width="500">
                                        <textPath xlink:href="#curve">
                                            <tspan class="tire-select tire-filter-visuell-text-width" data-select="tire-width-select" style="mix-blend-mode: overlay;">225</tspan>
                                            <tspan class="">/</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-height" data-select="tire-height-select" style="mix-blend-mode: overlay;">45</tspan>
                                            <tspan textLength="10" class="">&nbsp;</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-inch" data-select="tire-inch-select" style="mix-blend-mode: overlay;">R17</tspan>
                                            <tspan textLength="10" class="">&nbsp;</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-loadindex" data-select="tire-loadindex-select" style="mix-blend-mode: overlay;">–</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-speedindex" data-select="tire-speedindex-select" style="mix-blend-mode: overlay;">–</tspan>
                                        </textPath>
                                        <textPath xlink:href="#curve" class="opacity-10-percent">
                                            <tspan class="tire-select tire-filter-visuell-text-width" data-select="tire-width-select" style="mix-blend-mode: overlay;">225</tspan>
                                            <tspan class="">/</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-height" data-select="tire-height-select" style="mix-blend-mode: overlay;">45</tspan>
                                            <tspan textLength="10" class="">&nbsp;</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-inch" data-select="tire-inch-select" style="mix-blend-mode: overlay;">R17</tspan>
                                            <tspan textLength="10" class="">&nbsp;</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-loadindex" data-select="tire-loadindex-select" style="mix-blend-mode: overlay;">–</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-speedindex" data-select="tire-speedindex-select" style="mix-blend-mode: overlay;">–</tspan>
                                        </textPath>
                                    </text>
                                </svg>
                                <svg viewBox="0 0 500 500" id="svg-text-second" class="d-none">
                                    <path fill="transparent" id="curve" d="M89,169c4-6.1,65-96,148-95c111,-11.2,170,90,175,97"></path>
                                    <text width="500">
                                        <textPath xlink:href="#curve">
                                            <tspan class="tire-select tire-filter-visuell-text-width" data-select="tire-width-select" style="mix-blend-mode: overlay;">225</tspan>
                                            <tspan class="">/</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-height" data-select="tire-height-select" style="mix-blend-mode: overlay;">45</tspan>
                                            <tspan textLength="10" class="">&nbsp;</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-inch" data-select="tire-inch-select" style="mix-blend-mode: overlay;">R17</tspan>
                                            <tspan textLength="10" class="">&nbsp;</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-loadindex" data-select="tire-loadindex-select" style="mix-blend-mode: overlay;">–</tspan>
                                            <tspan class="tire-select tire-filter-visuell-text-speedindex" data-select="tire-speedindex-select" style="mix-blend-mode: overlay;">–</tspan>
                                        </textPath>
                                    </text>
                                </svg>
                            </div>
                                                            <img alt="Reifenfilter" src="/source/skin/default/img/fsv2/reifen/reifenfilter.png">
                                                    </div>
                    </div>
                    <div class="col-xs-12 vehicle-select-filter">
                        <div class="tire-select-container margin-bottom-30">
                            <div class="tire-select-arrow"></div>
                            <span class="tire-filter-label">Reifengröße</span>
                            <div class="tire-select" data-select="tire-tiresize-select" data-text="Reifengröße">
                                <div class="option selected">Kein Fahrzeug gewählt</div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12 tire-select-filter">
                        <div class="row margin-bottom-30">
                            <div class="col-xs-4">
                                <div class="tire-select-container small">
                                    <div class="tire-select-arrow" data-target-arrow="tire-width-select"></div>
                                    <span class="tire-filter-label" data-information="breite">
                                        Breite                                        <i class="icon information-icon">
                                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/icon/gutachten-tutorial.svg" alt="Information Icon">
                                        </i>
                                    </span>
                                    <div class="tire-select small" data-select="tire-width-select" data-text="Breite">
                                                                                    <div class="option" data-value="125">125</div>
                                                                                    <div class="option" data-value="135">135</div>
                                                                                    <div class="option" data-value="145">145</div>
                                                                                    <div class="option" data-value="155">155</div>
                                                                                    <div class="option" data-value="165">165</div>
                                                                                    <div class="option" data-value="175">175</div>
                                                                                    <div class="option" data-value="185">185</div>
                                                                                    <div class="option" data-value="195">195</div>
                                                                                    <div class="option" data-value="205">205</div>
                                                                                    <div class="option" data-value="215">215</div>
                                                                                    <div class="option selected" data-value="225">225</div>
                                                                                    <div class="option" data-value="235">235</div>
                                                                                    <div class="option" data-value="245">245</div>
                                                                                    <div class="option" data-value="255">255</div>
                                                                                    <div class="option" data-value="265">265</div>
                                                                                    <div class="option" data-value="275">275</div>
                                                                                    <div class="option" data-value="285">285</div>
                                                                                    <div class="option" data-value="295">295</div>
                                                                                    <div class="option" data-value="305">305</div>
                                                                                    <div class="option" data-value="315">315</div>
                                                                                    <div class="option" data-value="325">325</div>
                                                                                    <div class="option" data-value="335">335</div>
                                                                                    <div class="option" data-value="345">345</div>
                                                                                    <div class="option" data-value="355">355</div>
                                                                            </div>
                                </div>
                            </div>
                            <div class="col-xs-4 d-flex d-md-block justify-content-center">
                                <div class="tire-select-container small">
                                    <div class="tire-select-arrow" data-target-arrow="tire-height-select"></div>
                                    <span class="tire-filter-label" data-information="hoehe">
                                        Höhe                                        <i class="icon information-icon">
                                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/icon/gutachten-tutorial.svg" alt="Information Icon">
                                        </i>
                                    </span>
                                    <div class="tire-select small" data-select="tire-height-select" data-text="Höhe">
                    <div class="option" data-value="30">
                        30
                    </div>
                
                    <div class="option" data-value="35">
                        35
                    </div>
                
                    <div class="option" data-value="40">
                        40
                    </div>
                
                    <div class="option selected" data-value="45">
                        45
                    </div>
                
                    <div class="option" data-value="50">
                        50
                    </div>
                
                    <div class="option" data-value="55">
                        55
                    </div>
                
                    <div class="option" data-value="60">
                        60
                    </div>
                
                    <div class="option" data-value="65">
                        65
                    </div>
                
                    <div class="option" data-value="70">
                        70
                    </div>
                
                    <div class="option" data-value="75">
                        75
                    </div>
                </div>
                                </div>
                            </div>
                            <div class="col-xs-4 d-flex d-md-block justify-content-right">
                                <div class="tire-select-container small">
                                    <div class="tire-select-arrow" data-target-arrow="tire-inch-select"></div>
                                    <span class="tire-filter-label" data-information="zoll">
                                        Zoll                                        <i class="icon information-icon">
                                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/icon/gutachten-tutorial.svg" alt="Information Icon">
                                        </i>
                                    </span>
                                    <div class="tire-select small" data-select="tire-inch-select" data-text="Zoll">
                    <div class="option" data-value="16">
                        16
                    </div>
                
                    <div class="option selected" data-value="17">
                        17
                    </div>
                
                    <div class="option" data-value="18">
                        18
                    </div>
                
                    <div class="option" data-value="19">
                        19
                    </div>
                </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <div class="row margin-bottom-45">
                            <div class="col-xs-6 tire-loadindex">
                                <div class="tire-select-container">
                                    <div class="tire-select-arrow" data-target-arrow="tire-loadindex-select"></div>
                                    <span class="tire-filter-label" data-information="loadindex">
                                        Traglast                                        <i class="icon information-icon">
                                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/icon/gutachten-tutorial.svg" alt="Information Icon">
                                        </i>
                                    </span>
                                    <div class="tire-select" data-select="tire-loadindex-select" data-text="Traglast">
                    <div class="option selected" data-value="-">–</div>
                
                    <div class="option" data-value="91">
                        91
                        &nbsp;
                        <div class="option-additional-text">
                            (615 kg)
                        </div>
                    
                    </div>
                
                    <div class="option" data-value="94">
                        94
                        &nbsp;
                        <div class="option-additional-text">
                            (670 kg)
                        </div>
                    
                    </div>
                </div>
                                </div>
                            </div>
                            <div class="col-xs-6 d-md-block tire-speedindex">
                                <div class="tire-select-container">
                                    <div class="tire-select-arrow" data-target-arrow="tire-speedindex-select"></div>
                                    <span class="tire-filter-label" data-information="speedindex">
                                        Geschwindigkeit                                        <i class="icon information-icon">
                                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/icon/gutachten-tutorial.svg" alt="Information Icon">
                                        </i>
                                    </span>
                                    <div class="tire-select" data-select="tire-speedindex-select" data-text="Geschwindigkeit">
                    <div class="option selected" data-value="-">–</div>
                
                    <div class="option" data-value="H">
                        H
                        &nbsp;
                        <div class="option-additional-text">
                            (210 km/h)
                        </div>
                    
                    </div>
                
                    <div class="option" data-value="V">
                        V
                        &nbsp;
                        <div class="option-additional-text">
                            (240 km/h)
                        </div>
                    
                    </div>
                
                    <div class="option" data-value="W">
                        W
                        &nbsp;
                        <div class="option-additional-text">
                            (270 km/h)
                        </div>
                    
                    </div>
                
                    <div class="option" data-value="Y">
                        Y
                        &nbsp;
                        <div class="option-additional-text">
                            (300 km/h)
                        </div>
                    
                    </div>
                </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <span class="tire-filter-label margin-bottom-15">
                            Saison                            <i class="icon information-icon d-none">
                                <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/icon/gutachten-tutorial.svg" alt="Information Icon">
                            </i>
                        </span>
                        <div class="row margin-bottom-30" data-select="tire-saisons-select" data-text="Saison">
                            <div class="col-xs-4">
                                <div class="tire-filter-season-image mb-2 active">
                                    <img alt="Sommer" src="data:image/svg+xml;base64,...">
                                </div>
                                <div class="tire-filter-season-label active">
                                    Sommer                                </div>
                                <input class="tire-filter-season-summer tire-filter-season-checkbox" type="checkbox" checked="">
                            </div>
                            <div class="col-xs-4">
                                <div class="tire-filter-season-image mb-2">
                                    <img alt="Winter" src="data:image/svg+xml;base64,...">
                                </div>
                                <div class="tire-filter-season-label">
                                    Winter                                </div>
                                <input class="tire-filter-season-winter tire-filter-season-checkbox" type="checkbox">
                            </div>
                            <div class="col-xs-4">
                                <div class="tire-filter-season-image mb-2">
                                    <img alt="Ganzjahr" src="data:image/svg+xml;base64,...">
                                </div>
                                <div class="tire-filter-season-label">
                                    Ganzjahr                                </div>
                                <input class="tire-filter-season-allyear tire-filter-season-checkbox" type="checkbox">
                            </div>
                        </div>
                    </div>
                    <div class="more-filter-container">
                        <div class="more-filter-header">
                            <span class="more-filter-title">Weitere Filter</span>
                            <img class="more-filter-close" alt="schließen" src="data:image/svg+xml;base64,...">
                        </div>
                        <div class="col-xs-12 margin-bottom-30">
                            <div class="tire-select-container">
                                <div class="tire-select-arrow"></div>
                                <span class="tire-filter-label">Hersteller</span>
                                <div class="tire-select multi-select" data-select="tire-manufacturer-select" data-text="Hersteller"><div class="option selected initial cloned-selected sticky" data-value="0" style="display: none;">Alle</div>
                                    <div class="option search sticky" style="display: none;">
        <img alt="search" src="/source/skin/default/img/fsv2/reifen/search.svg">
        <input class="tire-select-search-input" value="" placeholder="Suche" data-input="REPLACE-ME">
    </div><div class="option selected initial" data-value="0" style="display: none;">Alle</div>
                                                                            <div class="option" data-value="A-PLUS" data-manufacturer-id="436" data-imageurl="//static.felgenshop.de/a-plus-manufacturer-160x65.webp" style="display: none;">A-PLUS<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="ACHILLES" data-manufacturer-id="183" data-imageurl="//static.felgenshop.de/achilles-manufacturer-160x65.webp" style="display: none;">ACHILLES<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="APOLLO" data-manufacturer-id="224" data-imageurl="//static.felgenshop.de/apollo-manufacturer-160x65.webp" style="display: none;">APOLLO<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="ARIVO" data-manufacturer-id="829" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">ARIVO<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="ATLAS" data-manufacturer-id="315" data-imageurl="//static.felgenshop.de/atlas-manufacturer-160x65.webp" style="display: none;">ATLAS<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="ATTURO" data-manufacturer-id="317" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">ATTURO<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="AUSTONE" data-manufacturer-id="337" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">AUSTONE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="AVON" data-manufacturer-id="206" data-imageurl="//static.felgenshop.de/avon-manufacturer-160x65.webp" style="display: none;">AVON<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="BARUM" data-manufacturer-id="203" data-imageurl="//static.felgenshop.de/barum-manufacturer-160x65.webp" style="display: none;">BARUM<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="BERLIN TIRES" data-manufacturer-id="812" data-imageurl="//static.felgenshop.de/berlin-tires-manufacturer-160x65.webp" style="display: none;">BERLIN TIRES<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="BF-GOODRICH" data-manufacturer-id="209" data-imageurl="//static.felgenshop.de/bf-goodrich-manufacturer-160x65.webp" style="display: none;">BF-GOODRICH<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="BK-TRAILER" data-manufacturer-id="517" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">BK-TRAILER<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="BOKA" data-manufacturer-id="602" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">BOKA<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="BRIDGESTONE" data-manufacturer-id="179" data-imageurl="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp" style="display: none;">BRIDGESTONE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="CEAT" data-manufacturer-id="205" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">CEAT<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="COMPASS" data-manufacturer-id="215" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">COMPASS<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="CONTINENTAL" data-manufacturer-id="180" data-imageurl="//static.felgenshop.de/continental-manufacturer-7-160x65.webp" style="display: none;">CONTINENTAL<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="COOPER" data-manufacturer-id="213" data-imageurl="//static.felgenshop.de/cooper-manufacturer-160x65.webp" style="display: none;">COOPER<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="CRATOS" data-manufacturer-id="603" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">CRATOS<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="CROSSWIND" data-manufacturer-id="918" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">CROSSWIND<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="CST (CHENG SHIN TIRE)" data-manufacturer-id="763" data-imageurl="//static.felgenshop.de/cst-cheng-shin-tire-manufacturer-160x65.webp" style="display: none;">CST (CHENG SHIN TIRE)<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="DAVANTI" data-manufacturer-id="724" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">DAVANTI<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="DEBICA" data-manufacturer-id="159" data-imageurl="//static.felgenshop.de/debica-manufacturer-160x65.webp" style="display: none;">DEBICA<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="DELINTE" data-manufacturer-id="391" data-imageurl="//static.felgenshop.de/delinte-manufacturer-160x65.webp" style="display: none;">DELINTE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="DELMAX" data-manufacturer-id="867" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">DELMAX<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="DOUBLE COIN" data-manufacturer-id="340" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">DOUBLE COIN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="DUNLOP" data-manufacturer-id="170" data-imageurl="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp" style="display: none;">DUNLOP<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="EP-TYRES" data-manufacturer-id="221" data-imageurl="//static.felgenshop.de/ep-tyres-manufacturer-160x65.webp" style="display: none;">EP-TYRES<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="EVERGREEN" data-manufacturer-id="207" data-imageurl="//static.felgenshop.de/evergreen-manufacturer-160x65.webp" style="display: none;">EVERGREEN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="FALKEN" data-manufacturer-id="160" data-imageurl="//static.felgenshop.de/falken-manufacturer-160x65.webp" style="display: none;">FALKEN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="FEDERAL" data-manufacturer-id="181" data-imageurl="//static.felgenshop.de/federal-manufacturer-160x65.webp" style="display: none;">FEDERAL<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="FIRESTONE" data-manufacturer-id="193" data-imageurl="//static.felgenshop.de/firestone-manufacturer-160x65.webp" style="display: none;">FIRESTONE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="FORTUNE" data-manufacturer-id="712" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">FORTUNE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="FULDA" data-manufacturer-id="176" data-imageurl="//static.felgenshop.de/fulda-manufacturer-160x65.webp" style="display: none;">FULDA<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="FULLRUN" data-manufacturer-id="321" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">FULLRUN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="GENERAL" data-manufacturer-id="192" data-imageurl="//static.felgenshop.de/general-manufacturer-160x65.webp" style="display: none;">GENERAL<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="GITI" data-manufacturer-id="690" data-imageurl="//static.felgenshop.de/giti-manufacturer-160x65.webp" style="display: none;">GITI<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="GOLDEN CROWN" data-manufacturer-id="816" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">GOLDEN CROWN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="GOLDLINE" data-manufacturer-id="628" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">GOLDLINE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="GOODRIDE" data-manufacturer-id="227" data-imageurl="//static.felgenshop.de/goodride-manufacturer-160x65.webp" style="display: none;">GOODRIDE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="GOODYEAR" data-manufacturer-id="210" data-imageurl="//static.felgenshop.de/goodyear-manufacturer-160x65.webp" style="display: none;">GOODYEAR<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="GRIPMAX" data-manufacturer-id="397" data-imageurl="//static.felgenshop.de/gripmax-manufacturer-160x65.webp" style="display: none;">GRIPMAX<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="GT RADIAL" data-manufacturer-id="169" data-imageurl="//static.felgenshop.de/gt-radial-manufacturer-160x65.webp" style="display: none;">GT RADIAL<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="HANKOOK" data-manufacturer-id="167" data-imageurl="//static.felgenshop.de/hankook-manufacturer-160x65.webp" style="display: none;">HANKOOK<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="HIFLY" data-manufacturer-id="222" data-imageurl="//static.felgenshop.de/hifly-manufacturer-160x65.webp" style="display: none;">HIFLY<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="IMPERIAL" data-manufacturer-id="196" data-imageurl="//static.felgenshop.de/imperial-manufacturer-160x65.webp" style="display: none;">IMPERIAL<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="KENDA" data-manufacturer-id="216" data-imageurl="//static.felgenshop.de/kenda-manufacturer-160x65.webp" style="display: none;">KENDA<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="KHEFREN" data-manufacturer-id="890" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">KHEFREN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="KINGSTAR" data-manufacturer-id="261" data-imageurl="//static.felgenshop.de/kingstar-manufacturer-160x65.webp" style="display: none;">KINGSTAR<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="KLEBER" data-manufacturer-id="211" data-imageurl="//static.felgenshop.de/kleber-manufacturer-160x65.webp" style="display: none;">KLEBER<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="KORMORAN" data-manufacturer-id="188" data-imageurl="//static.felgenshop.de/kormoran-manufacturer-160x65.webp" style="display: none;">KORMORAN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="KUMHO" data-manufacturer-id="175" data-imageurl="//static.felgenshop.de/kumho-manufacturer-2-160x65.webp" style="display: none;">KUMHO<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="LANDSAIL" data-manufacturer-id="233" data-imageurl="//static.felgenshop.de/landsail-manufacturer-160x65.webp" style="display: none;">LANDSAIL<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="LASSA" data-manufacturer-id="256" data-imageurl="//static.felgenshop.de/lassa-manufacturer-160x65.webp" style="display: none;">LASSA<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="LAUFENN" data-manufacturer-id="562" data-imageurl="//static.felgenshop.de/laufenn-manufacturer-160x65.webp" style="display: none;">LAUFENN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="LEAO" data-manufacturer-id="312" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">LEAO<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="LINGLONG" data-manufacturer-id="524" data-imageurl="//static.felgenshop.de/linglong-manufacturer-160x65.webp" style="display: none;">LINGLONG<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="MARSHAL" data-manufacturer-id="223" data-imageurl="//static.felgenshop.de/marshal-manufacturer-160x65.webp" style="display: none;">MARSHAL<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="MASSIMO" data-manufacturer-id="860" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">MASSIMO<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="MASTERSTEEL" data-manufacturer-id="171" data-imageurl="//static.felgenshop.de/mastersteel-manufacturer-160x65.webp" style="display: none;">MASTERSTEEL<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="MATADOR" data-manufacturer-id="199" data-imageurl="//static.felgenshop.de/matador-manufacturer-160x65.webp" style="display: none;">MATADOR<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="MAXTREK" data-manufacturer-id="272" data-imageurl="//static.felgenshop.de/maxtrek-manufacturer-160x65.webp" style="display: none;">MAXTREK<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="MAXXIS" data-manufacturer-id="164" data-imageurl="//static.felgenshop.de/maxxis-manufacturer-160x65.webp" style="display: none;">MAXXIS<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="MAZZINI" data-manufacturer-id="531" data-imageurl="//static.felgenshop.de/mazzini-manufacturer-160x65.webp" style="display: none;">MAZZINI<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="MICHELIN" data-manufacturer-id="165" data-imageurl="//static.felgenshop.de/michelin-manufacturer-160x65.webp" style="display: none;">MICHELIN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="MILESTONE" data-manufacturer-id="309" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">MILESTONE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="MINERVA" data-manufacturer-id="198" data-imageurl="//static.felgenshop.de/minerva-manufacturer-160x65.webp" style="display: none;">MINERVA<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="MIRAGE" data-manufacturer-id="719" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">MIRAGE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="NANKANG" data-manufacturer-id="172" data-imageurl="//static.felgenshop.de/nankang-manufacturer-160x65.webp" style="display: none;">NANKANG<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="NEXEN" data-manufacturer-id="191" data-imageurl="//static.felgenshop.de/nexen-manufacturer-160x65.webp" style="display: none;">NEXEN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="NOKIAN" data-manufacturer-id="249" data-imageurl="//static.felgenshop.de/nokian-manufacturer-160x65.webp" style="display: none;">NOKIAN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="NORDEXX" data-manufacturer-id="228" data-imageurl="//static.felgenshop.de/nordexx-manufacturer-160x65.webp" style="display: none;">NORDEXX<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="NOVEX" data-manufacturer-id="173" data-imageurl="//static.felgenshop.de/novex-manufacturer-160x65.webp" style="display: none;">NOVEX<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="ONYX" data-manufacturer-id="591" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">ONYX<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="OVATION" data-manufacturer-id="194" data-imageurl="//static.felgenshop.de/ovation-manufacturer-160x65.webp" style="display: none;">OVATION<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="PETLAS" data-manufacturer-id="246" data-imageurl="//static.felgenshop.de/petlas-manufacturer-160x65.webp" style="display: none;">PETLAS<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="PIRELLI" data-manufacturer-id="127" data-imageurl="//static.felgenshop.de/pirelli-manufacturer-160x65.webp" style="display: none;">PIRELLI<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="POWERTRAC" data-manufacturer-id="563" data-imageurl="//static.felgenshop.de/powertrac-manufacturer-160x65.webp" style="display: none;">POWERTRAC<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="RADAR" data-manufacturer-id="271" data-imageurl="//static.felgenshop.de/radar-manufacturer-160x65.webp" style="display: none;">RADAR<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="RIKEN" data-manufacturer-id="239" data-imageurl="//static.felgenshop.de/riken-manufacturer-160x65.webp" style="display: none;">RIKEN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="ROAD X" data-manufacturer-id="842" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">ROAD X<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="ROADHOG" data-manufacturer-id="765" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">ROADHOG<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="ROADSTONE" data-manufacturer-id="200" data-imageurl="//static.felgenshop.de/roadstone-manufacturer-160x65.webp" style="display: none;">ROADSTONE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="ROTALLA" data-manufacturer-id="304" data-imageurl="//static.felgenshop.de/rotalla-manufacturer-160x65.webp" style="display: none;">ROTALLA<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="SAILUN" data-manufacturer-id="187" data-imageurl="//static.felgenshop.de/sailun-manufacturer-160x65.webp" style="display: none;">SAILUN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="SAVA" data-manufacturer-id="197" data-imageurl="//static.felgenshop.de/sava-manufacturer-160x65.webp" style="display: none;">SAVA<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="SECURITY" data-manufacturer-id="217" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">SECURITY<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="SEMPERIT" data-manufacturer-id="174" data-imageurl="//static.felgenshop.de/semperit-manufacturer-160x65.webp" style="display: none;">SEMPERIT<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="SENTURY" data-manufacturer-id="932" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">SENTURY<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="SPORTIVA" data-manufacturer-id="267" data-imageurl="//static.felgenshop.de/sportiva-manufacturer-160x65.webp" style="display: none;">SPORTIVA<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="SUNNY" data-manufacturer-id="244" data-imageurl="//static.felgenshop.de/sunny-manufacturer-160x65.webp" style="display: none;">SUNNY<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="SUNWIDE" data-manufacturer-id="583" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">SUNWIDE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="SUPERIA TIRES" data-manufacturer-id="462" data-imageurl="//static.felgenshop.de/superia-tires-manufacturer-160x65.webp" style="display: none;">SUPERIA TIRES<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="SYRON" data-manufacturer-id="251" data-imageurl="//static.felgenshop.de/syron-manufacturer-160x65.webp" style="display: none;">SYRON<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="TIGAR" data-manufacturer-id="254" data-imageurl="//static.felgenshop.de/tigar-manufacturer-160x65.webp" style="display: none;">TIGAR<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="TOMASON" data-manufacturer-id="725" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">TOMASON<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="TORQUE" data-manufacturer-id="235" data-imageurl="//static.felgenshop.de/torque-manufacturer-160x65.webp" style="display: none;">TORQUE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="TOURADOR" data-manufacturer-id="811" data-imageurl="//static.felgenshop.de/404-160x65.png" style="display: none;">TOURADOR<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="TOYO" data-manufacturer-id="161" data-imageurl="//static.felgenshop.de/toyo-manufacturer-160x65.webp" style="display: none;">TOYO<span class="article-count">(1)</span></div>
                                                                            <div class="option" data-value="TRACMAX" data-manufacturer-id="259" data-imageurl="//static.felgenshop.de/tracmax-manufacturer-160x65.webp" style="display: none;">TRACMAX<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="TRAZANO" data-manufacturer-id="314" data-imageurl="//static.felgenshop.de/trazano-manufacturer-160x65.webp" style="display: none;">TRAZANO<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="TRISTAR" data-manufacturer-id="408" data-imageurl="//static.felgenshop.de/tristar-manufacturer-160x65.webp" style="display: none;">TRISTAR<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="UNIGRIP" data-manufacturer-id="332" data-imageurl="//static.felgenshop.de/unigrip-manufacturer-160x65.webp" style="display: none;">UNIGRIP<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="UNIROYAL" data-manufacturer-id="202" data-imageurl="//static.felgenshop.de/uniroyal-manufacturer-160x65.webp" style="display: none;">UNIROYAL<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="VREDESTEIN" data-manufacturer-id="178" data-imageurl="//static.felgenshop.de/vredestein-manufacturer-160x65.webp" style="display: none;">VREDESTEIN<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="WESTLAKE" data-manufacturer-id="229" data-imageurl="//static.felgenshop.de/westlake-manufacturer-160x65.webp" style="display: none;">WESTLAKE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="WINDFORCE" data-manufacturer-id="445" data-imageurl="//static.felgenshop.de/windforce-manufacturer-160x65.webp" style="display: none;">WINDFORCE<span class="article-count">(0)</span></div>
                                                                            <div class="option" data-value="YOKOHAMA" data-manufacturer-id="177" data-imageurl="//static.felgenshop.de/yokohama-manufacturer-2-160x65.webp" style="display: none;">YOKOHAMA<span class="article-count">(2)</span></div>
                                                                    <div class="option sticky footer" style="display: none;">
        <div class="save">Speichern</div>
        <div class="reset">Zurücksetzen</div>
    </div></div>
                            </div>
                        </div>
                        <div class="col-xs-12 margin-bottom-60">
                            <div class="tire-select-container">
                                <div class="tire-select-arrow"></div>
                                <span class="tire-filter-label">Kategorie</span>
                                <div class="tire-select" data-select="tire-category-select" data-text="Kategorie">
                                    <div class="option selected initial" data-value="-1">Alle</div>
                                    <div class="option" data-value="2">Premium</div>
                                    <div class="option" data-value="1">Preistipp</div>
                                    <div class="option" data-value="0">Günstig</div>
                                </div>
                            </div>
                        </div>
                        <div class="col-xs-12 margin-bottom-30">
                            <div class="tire-checkbox-container">
                                <label>
                                    <input data-select="tire-ms-select" type="checkbox">
                                </label>
                                <span class="tire-filter-label" data-information="ms">
                                    M+S                                    <i class="icon information-icon">
                                        <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/icon/gutachten-tutorial.svg" alt="Information Icon">
                                    </i>
                                </span>
                            </div>
                        </div>
                        <div class="col-xs-12 margin-bottom-30">
                            <div class="tire-checkbox-container">
                                <label>
                                    <input data-select="tire-3pmsf-select" type="checkbox">
                                </label>
                                <span class="tire-filter-label" data-information="3pmsf">
                                    Schneeflockensymbol                                    <i class="icon information-icon">
                                        <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/icon/gutachten-tutorial.svg" alt="Information Icon">
                                    </i>
                                </span>
                            </div>
                        </div>
                        <div class="col-xs-12 margin-bottom-30">
                            <div class="tire-checkbox-container">
                                <label>
                                    <input data-select="tire-runflat-select" type="checkbox">
                                </label>
                                <span class="tire-filter-label" data-information="runflat">
                                    Runflat                                    <i class="icon information-icon">
                                        <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/icon/gutachten-tutorial.svg" alt="Information Icon">
                                    </i>
                                </span>
                            </div>
                        </div>
                        <div class="col-xs-12 margin-bottom-30">
                            <div class="tire-checkbox-container">
                                <label>
                                    <input data-select="tire-oe-select" type="checkbox">
                                </label>
                                <span class="tire-filter-label" data-information="oe">
                                    Reifen mit OE Kennung                                    <i class="icon information-icon">
                                        <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/icon/gutachten-tutorial.svg" alt="Information Icon">
                                    </i>
                                </span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <label class="more-filter-button">
                            <i class="icon">
                                <img alt="more-filter-button" src="...">
                            </i>
                            Weitere Filter                        </label>
                    </div>
                    <!-- Select Overlays -->
                    <div class="tire-select-overlays">
                        <div class="tire-select-overlay-background d-none"></div>

                        <div class="tire-select-overlay standard-filter tire-width-select-overlay">
                            <div class="overlay-header sticky">
                                <span class="tire-select-overlay-label">Breite</span>
                                <img class="tire-select-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
                            </div>
                            <div class="tire-select-overlay-item-container" data-select="tire-width-select" data-text="Breite">
                                                                    <div class="option" data-value="125">125</div>
                                                                    <div class="option" data-value="135">135</div>
                                                                    <div class="option" data-value="145">145</div>
                                                                    <div class="option" data-value="155">155</div>
                                                                    <div class="option" data-value="165">165</div>
                                                                    <div class="option" data-value="175">175</div>
                                                                    <div class="option" data-value="185">185</div>
                                                                    <div class="option" data-value="195">195</div>
                                                                    <div class="option" data-value="205">205</div>
                                                                    <div class="option" data-value="215">215</div>
                                                                    <div class="option selected" data-value="225">225</div>
                                                                    <div class="option" data-value="235">235</div>
                                                                    <div class="option" data-value="245">245</div>
                                                                    <div class="option" data-value="255">255</div>
                                                                    <div class="option" data-value="265">265</div>
                                                                    <div class="option" data-value="275">275</div>
                                                                    <div class="option" data-value="285">285</div>
                                                                    <div class="option" data-value="295">295</div>
                                                                    <div class="option" data-value="305">305</div>
                                                                    <div class="option" data-value="315">315</div>
                                                                    <div class="option" data-value="325">325</div>
                                                                    <div class="option" data-value="335">335</div>
                                                                    <div class="option" data-value="345">345</div>
                                                                    <div class="option" data-value="355">355</div>
                                                            </div>
                        </div>

                        <div class="tire-select-overlay standard-filter tire-height-select-overlay">
                            <div class="overlay-header sticky">
                                <span class="tire-select-overlay-label">Höhe</span>
                                <img class="tire-select-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
                            </div>
                            <div class="tire-select-overlay-item-container" data-select="tire-height-select" data-text="Höhe">
                    <div class="option" data-value="30">
                        30
                    </div>
                
                    <div class="option" data-value="35">
                        35
                    </div>
                
                    <div class="option" data-value="40">
                        40
                    </div>
                
                    <div class="option selected" data-value="45">
                        45
                    </div>
                
                    <div class="option" data-value="50">
                        50
                    </div>
                
                    <div class="option" data-value="55">
                        55
                    </div>
                
                    <div class="option" data-value="60">
                        60
                    </div>
                
                    <div class="option" data-value="65">
                        65
                    </div>
                
                    <div class="option" data-value="70">
                        70
                    </div>
                
                    <div class="option" data-value="75">
                        75
                    </div>
                </div>
                        </div>

                        <div class="tire-select-overlay standard-filter tire-inch-select-overlay">
                            <div class="overlay-header sticky">
                                <span class="tire-select-overlay-label">Zoll</span>
                                <img class="tire-select-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
                            </div>
                            <div class="tire-select-overlay-item-container" data-select="tire-inch-select" data-text="Zoll">
                    <div class="option" data-value="16">
                        16
                    </div>
                
                    <div class="option selected" data-value="17">
                        17
                    </div>
                
                    <div class="option" data-value="18">
                        18
                    </div>
                
                    <div class="option" data-value="19">
                        19
                    </div>
                </div>
                        </div>

                        <div class="tire-select-overlay standard-filter tire-loadindex-select-overlay">
                            <div class="overlay-header sticky">
                                <span class="tire-select-overlay-label">Traglast</span>
                                <img class="tire-select-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
                            </div>
                            <div class="tire-select-overlay-item-container" data-select="tire-loadindex-select" data-text="Traglast">
                    <div class="option selected" data-value="-">–</div>
                
                    <div class="option" data-value="91">
                        91
                        &nbsp;
                        <div class="option-additional-text">
                            (615 kg)
                        </div>
                    
                    </div>
                
                    <div class="option" data-value="94">
                        94
                        &nbsp;
                        <div class="option-additional-text">
                            (670 kg)
                        </div>
                    
                    </div>
                </div>
                        </div>

                        <div class="tire-select-overlay standard-filter tire-speedindex-select-overlay">
                            <div class="overlay-header sticky">
                                <span class="tire-select-overlay-label">Geschwindigkeit</span>
                                <img class="tire-select-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
                            </div>
                            <div class="tire-select-overlay-item-container" data-select="tire-speedindex-select" data-text="Geschwindigkeit">
                    <div class="option selected" data-value="-">–</div>
                
                    <div class="option" data-value="H">
                        H
                        &nbsp;
                        <div class="option-additional-text">
                            (210 km/h)
                        </div>
                    
                    </div>
                
                    <div class="option" data-value="V">
                        V
                        &nbsp;
                        <div class="option-additional-text">
                            (240 km/h)
                        </div>
                    
                    </div>
                
                    <div class="option" data-value="W">
                        W
                        &nbsp;
                        <div class="option-additional-text">
                            (270 km/h)
                        </div>
                    
                    </div>
                
                    <div class="option" data-value="Y">
                        Y
                        &nbsp;
                        <div class="option-additional-text">
                            (300 km/h)
                        </div>
                    
                    </div>
                </div>
                        </div>

                        <div class="tire-select-overlay more-filter tire-manufacturer-select-overlay">
                            <div class="overlay-header sticky">
                                <span class="tire-select-overlay-label">Hersteller</span>
                                <img class="tire-select-overlay-back" alt="schließen" src="data:image/png;base64,...">
                            </div>
                            <div class="tire-select-overlay-item-container multi-select" data-select="tire-manufacturer-select" data-text="Hersteller"><div class="option selected initial cloned-selected sticky" data-value="0" style="display: none;">Alle</div>
                                <div class="option search sticky" style="display: none;">
        <img alt="search" src="/source/skin/default/img/fsv2/reifen/search.svg">
        <input class="tire-select-search-input" value="" placeholder="Suche" data-input="REPLACE-ME">
    </div><div class="option selected initial" data-value="0" style="display: none;">Alle</div>
                                                                    <div class="option" data-value="A-PLUS" data-manufacturer-id="436" style="display: none;">A-PLUS<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="ACHILLES" data-manufacturer-id="183" style="display: none;">ACHILLES<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="APOLLO" data-manufacturer-id="224" style="display: none;">APOLLO<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="ARIVO" data-manufacturer-id="829" style="display: none;">ARIVO<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="ATLAS" data-manufacturer-id="315" style="display: none;">ATLAS<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="ATTURO" data-manufacturer-id="317" style="display: none;">ATTURO<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="AUSTONE" data-manufacturer-id="337" style="display: none;">AUSTONE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="AVON" data-manufacturer-id="206" style="display: none;">AVON<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="BARUM" data-manufacturer-id="203" style="display: none;">BARUM<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="BERLIN TIRES" data-manufacturer-id="812" style="display: none;">BERLIN TIRES<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="BF-GOODRICH" data-manufacturer-id="209" style="display: none;">BF-GOODRICH<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="BK-TRAILER" data-manufacturer-id="517" style="display: none;">BK-TRAILER<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="BOKA" data-manufacturer-id="602" style="display: none;">BOKA<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="BRIDGESTONE" data-manufacturer-id="179" style="display: none;">BRIDGESTONE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="CEAT" data-manufacturer-id="205" style="display: none;">CEAT<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="COMPASS" data-manufacturer-id="215" style="display: none;">COMPASS<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="CONTINENTAL" data-manufacturer-id="180" style="display: none;">CONTINENTAL<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="COOPER" data-manufacturer-id="213" style="display: none;">COOPER<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="CRATOS" data-manufacturer-id="603" style="display: none;">CRATOS<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="CROSSWIND" data-manufacturer-id="918" style="display: none;">CROSSWIND<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="CST (CHENG SHIN TIRE)" data-manufacturer-id="763" style="display: none;">CST (CHENG SHIN TIRE)<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="DAVANTI" data-manufacturer-id="724" style="display: none;">DAVANTI<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="DEBICA" data-manufacturer-id="159" style="display: none;">DEBICA<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="DELINTE" data-manufacturer-id="391" style="display: none;">DELINTE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="DELMAX" data-manufacturer-id="867" style="display: none;">DELMAX<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="DOUBLE COIN" data-manufacturer-id="340" style="display: none;">DOUBLE COIN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="DUNLOP" data-manufacturer-id="170" style="display: none;">DUNLOP<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="EP-TYRES" data-manufacturer-id="221" style="display: none;">EP-TYRES<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="EVERGREEN" data-manufacturer-id="207" style="display: none;">EVERGREEN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="FALKEN" data-manufacturer-id="160" style="display: none;">FALKEN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="FEDERAL" data-manufacturer-id="181" style="display: none;">FEDERAL<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="FIRESTONE" data-manufacturer-id="193" style="display: none;">FIRESTONE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="FORTUNE" data-manufacturer-id="712" style="display: none;">FORTUNE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="FULDA" data-manufacturer-id="176" style="display: none;">FULDA<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="FULLRUN" data-manufacturer-id="321" style="display: none;">FULLRUN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="GENERAL" data-manufacturer-id="192" style="display: none;">GENERAL<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="GITI" data-manufacturer-id="690" style="display: none;">GITI<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="GOLDEN CROWN" data-manufacturer-id="816" style="display: none;">GOLDEN CROWN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="GOLDLINE" data-manufacturer-id="628" style="display: none;">GOLDLINE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="GOODRIDE" data-manufacturer-id="227" style="display: none;">GOODRIDE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="GOODYEAR" data-manufacturer-id="210" style="display: none;">GOODYEAR<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="GRIPMAX" data-manufacturer-id="397" style="display: none;">GRIPMAX<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="GT RADIAL" data-manufacturer-id="169" style="display: none;">GT RADIAL<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="HANKOOK" data-manufacturer-id="167" style="display: none;">HANKOOK<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="HIFLY" data-manufacturer-id="222" style="display: none;">HIFLY<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="IMPERIAL" data-manufacturer-id="196" style="display: none;">IMPERIAL<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="KENDA" data-manufacturer-id="216" style="display: none;">KENDA<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="KHEFREN" data-manufacturer-id="890" style="display: none;">KHEFREN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="KINGSTAR" data-manufacturer-id="261" style="display: none;">KINGSTAR<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="KLEBER" data-manufacturer-id="211" style="display: none;">KLEBER<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="KORMORAN" data-manufacturer-id="188" style="display: none;">KORMORAN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="KUMHO" data-manufacturer-id="175" style="display: none;">KUMHO<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="LANDSAIL" data-manufacturer-id="233" style="display: none;">LANDSAIL<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="LASSA" data-manufacturer-id="256" style="display: none;">LASSA<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="LAUFENN" data-manufacturer-id="562" style="display: none;">LAUFENN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="LEAO" data-manufacturer-id="312" style="display: none;">LEAO<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="LINGLONG" data-manufacturer-id="524" style="display: none;">LINGLONG<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="MARSHAL" data-manufacturer-id="223" style="display: none;">MARSHAL<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="MASSIMO" data-manufacturer-id="860" style="display: none;">MASSIMO<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="MASTERSTEEL" data-manufacturer-id="171" style="display: none;">MASTERSTEEL<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="MATADOR" data-manufacturer-id="199" style="display: none;">MATADOR<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="MAXTREK" data-manufacturer-id="272" style="display: none;">MAXTREK<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="MAXXIS" data-manufacturer-id="164" style="display: none;">MAXXIS<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="MAZZINI" data-manufacturer-id="531" style="display: none;">MAZZINI<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="MICHELIN" data-manufacturer-id="165" style="display: none;">MICHELIN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="MILESTONE" data-manufacturer-id="309" style="display: none;">MILESTONE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="MINERVA" data-manufacturer-id="198" style="display: none;">MINERVA<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="MIRAGE" data-manufacturer-id="719" style="display: none;">MIRAGE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="NANKANG" data-manufacturer-id="172" style="display: none;">NANKANG<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="NEXEN" data-manufacturer-id="191" style="display: none;">NEXEN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="NOKIAN" data-manufacturer-id="249" style="display: none;">NOKIAN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="NORDEXX" data-manufacturer-id="228" style="display: none;">NORDEXX<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="NOVEX" data-manufacturer-id="173" style="display: none;">NOVEX<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="ONYX" data-manufacturer-id="591" style="display: none;">ONYX<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="OVATION" data-manufacturer-id="194" style="display: none;">OVATION<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="PETLAS" data-manufacturer-id="246" style="display: none;">PETLAS<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="PIRELLI" data-manufacturer-id="127" style="display: none;">PIRELLI<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="POWERTRAC" data-manufacturer-id="563" style="display: none;">POWERTRAC<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="RADAR" data-manufacturer-id="271" style="display: none;">RADAR<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="RIKEN" data-manufacturer-id="239" style="display: none;">RIKEN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="ROAD X" data-manufacturer-id="842" style="display: none;">ROAD X<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="ROADHOG" data-manufacturer-id="765" style="display: none;">ROADHOG<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="ROADSTONE" data-manufacturer-id="200" style="display: none;">ROADSTONE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="ROTALLA" data-manufacturer-id="304" style="display: none;">ROTALLA<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="SAILUN" data-manufacturer-id="187" style="display: none;">SAILUN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="SAVA" data-manufacturer-id="197" style="display: none;">SAVA<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="SECURITY" data-manufacturer-id="217" style="display: none;">SECURITY<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="SEMPERIT" data-manufacturer-id="174" style="display: none;">SEMPERIT<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="SENTURY" data-manufacturer-id="932" style="display: none;">SENTURY<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="SPORTIVA" data-manufacturer-id="267" style="display: none;">SPORTIVA<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="SUNNY" data-manufacturer-id="244" style="display: none;">SUNNY<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="SUNWIDE" data-manufacturer-id="583" style="display: none;">SUNWIDE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="SUPERIA TIRES" data-manufacturer-id="462" style="display: none;">SUPERIA TIRES<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="SYRON" data-manufacturer-id="251" style="display: none;">SYRON<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="TIGAR" data-manufacturer-id="254" style="display: none;">TIGAR<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="TOMASON" data-manufacturer-id="725" style="display: none;">TOMASON<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="TORQUE" data-manufacturer-id="235" style="display: none;">TORQUE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="TOURADOR" data-manufacturer-id="811" style="display: none;">TOURADOR<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="TOYO" data-manufacturer-id="161" style="display: none;">TOYO<span class="article-count">(1)</span></div>
                                                                    <div class="option" data-value="TRACMAX" data-manufacturer-id="259" style="display: none;">TRACMAX<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="TRAZANO" data-manufacturer-id="314" style="display: none;">TRAZANO<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="TRISTAR" data-manufacturer-id="408" style="display: none;">TRISTAR<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="UNIGRIP" data-manufacturer-id="332" style="display: none;">UNIGRIP<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="UNIROYAL" data-manufacturer-id="202" style="display: none;">UNIROYAL<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="VREDESTEIN" data-manufacturer-id="178" style="display: none;">VREDESTEIN<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="WESTLAKE" data-manufacturer-id="229" style="display: none;">WESTLAKE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="WINDFORCE" data-manufacturer-id="445" style="display: none;">WINDFORCE<span class="article-count">(0)</span></div>
                                                                    <div class="option" data-value="YOKOHAMA" data-manufacturer-id="177" style="display: none;">YOKOHAMA<span class="article-count">(2)</span></div>
                                                            <div class="option sticky footer" style="display: none;">
        <div class="save">Speichern</div>
        <div class="reset">Zurücksetzen</div>
    </div></div>
                        </div>

                        <div class="tire-select-overlay more-filter tire-category-select-overlay">
                            <div class="overlay-header">
                                <span class="tire-select-overlay-label">Kategorie</span>
                                <img class="tire-select-overlay-back" alt="schließen" src="data:image/png;base64,...">
                            </div>
                            <div class="tire-select-overlay-item-container" data-select="tire-category-select" data-text="Kategorie">
                                <div class="option selected initial" data-value="-1">Alle</div>
                                <div class="option" data-value="2">Premium</div>
                                <div class="option" data-value="1">Preistipp</div>
                                <div class="option" data-value="0">Günstig</div>
                            </div>
                        </div>

                        <div class="tire-select-overlay standard-filter tire-tiresize-select-overlay">
                            <div class="overlay-header">
                                <span class="tire-select-overlay-label">Reifengröße</span>
                                <img class="tire-select-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
                            </div>
                            <div class="tire-select-overlay-item-container" data-select="tire-tiresize-select" data-text="Reifengröße">
                                <div class="option selected">Kein Fahrzeug gewählt</div>
                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </div>
        <div class="col-xs-12 col-md-7 tire-box-margin-left-60">
            <div class="row">
                <div class="col-xs-12 d-flex justify-content-right">
                    <div class="tire-select-container tire-sorting">
                        <div class="tire-select-arrow"></div>
                        <select class="tire-select" name="tire-sorting" data-select="tire-sorting-select">
                            <option selected="" value="empfehlung">Empfehlung</option>
                            <option value="preis-asc">Preis aufsteigend</option>
                            <option value="preis-desc">preis absteigend</option>
                            <option value="rollwiderstand-asc">Rollwiderstand aufsteigend</option>
                            <option value="rollwiderstand-desc">Rollwiderstand absteigend</option>
                            <option value="rollgeraeusch-asc">Rollgeräusche aufsteigend</option>
                            <option value="rollgeraeusch-desc">Rollgeräusche absteigend</option>
                            <option value="nasshaftung-asc">Nasshaftung aufsteigend</option>
                            <option value="nasshaftung-desc">Nasshaftung absteigend</option>
                        </select>
                    </div>
                </div>
                                <div class="tire-filter-bubbles d-none"></div>
                                <div id="tire-list" class=""><div class="col-xs-12 tire-box-container " data-tire-box-position="1" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="PIRELLI POWERGY" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21426-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">68</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/pirelli-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="198205092">
                                <span class="tire-article-name" itemprop="name">PIRELLI POWERGY</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="PIRELLI">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////198205092" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(349,48 €)</span>
                            <span class="tire-buy-button-article-price">87,37 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="87.37">
                            <meta itemprop="price" content="87.37">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="PIRELLI POWERGY" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21426-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/pirelli-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">PIRELLI POWERGY</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">68</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////198205092" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">87,37 €</span>
                            <span class="tire-buy-button-total-price">(349,48 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container " data-tire-box-position="2" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="CONTINENTAL ULTRACONTACT" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21806-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/continental-manufacturer-7-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="605505957">
                                <span class="tire-article-name" itemprop="name">CONTINENTAL ULTRACONTACT</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">FR</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="CONTINENTAL">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////605505957" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(385,40 €)</span>
                            <span class="tire-buy-button-article-price">96,35 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="96.35">
                            <meta itemprop="price" content="96.35">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="CONTINENTAL ULTRACONTACT" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21806-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/continental-manufacturer-7-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">CONTINENTAL ULTRACONTACT</span>
                                <span class="tire-article-extra">FR</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////605505957" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">96,35 €</span>
                            <span class="tire-buy-button-total-price">(385,40 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container " data-tire-box-position="3" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="BRIDGESTONE TURANZA 6" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/22227-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="573824715">
                                <span class="tire-article-name" itemprop="name">BRIDGESTONE TURANZA 6</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">ENLITEN MFS</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="BRIDGESTONE">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////573824715" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(376,16 €)</span>
                            <span class="tire-buy-button-article-price">94,04 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="94.04">
                            <meta itemprop="price" content="94.04">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="BRIDGESTONE TURANZA 6" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/22227-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">BRIDGESTONE TURANZA 6</span>
                                <span class="tire-article-extra">ENLITEN MFS</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////573824715" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">94,04 €</span>
                            <span class="tire-buy-button-total-price">(376,16 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container " data-tire-box-position="4" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="HANKOOK K127B VENTUS S1 EVO3" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19969-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="386139418">
                                <span class="tire-article-name" itemprop="name">HANKOOK K127B VENTUS S1 EVO3</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">(*) HRS RUNFLAT</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="HANKOOK">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////386139418" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(428,00 €)</span>
                            <span class="tire-buy-button-article-price">107,00 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="107.00">
                            <meta itemprop="price" content="107.00">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="HANKOOK K127B VENTUS S1 EVO3" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19969-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">HANKOOK K127B VENTUS S1 EVO3</span>
                                <span class="tire-article-extra">(*) HRS RUNFLAT</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////386139418" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">107,00 €</span>
                            <span class="tire-buy-button-total-price">(428,00 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container " data-tire-box-position="5" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="BRIDGESTONE TURANZA T005" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17279-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="189443666">
                                <span class="tire-article-name" itemprop="name">BRIDGESTONE TURANZA T005</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">AO</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="BRIDGESTONE">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////189443666" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(413,24 €)</span>
                            <span class="tire-buy-button-article-price">103,31 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="103.31">
                            <meta itemprop="price" content="103.31">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="BRIDGESTONE TURANZA T005" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17279-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">BRIDGESTONE TURANZA T005</span>
                                <span class="tire-article-extra">AO</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////189443666" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">103,31 €</span>
                            <span class="tire-buy-button-total-price">(413,24 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container " data-tire-box-position="6" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="YOKOHAMA BLUEARTH-GT AE51" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20805-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/yokohama-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="166963417">
                                <span class="tire-article-name" itemprop="name">YOKOHAMA BLUEARTH-GT AE51</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="YOKOHAMA">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////166963417" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(345,56 €)</span>
                            <span class="tire-buy-button-article-price">86,39 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="86.39">
                            <meta itemprop="price" content="86.39">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="YOKOHAMA BLUEARTH-GT AE51" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20805-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/yokohama-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">YOKOHAMA BLUEARTH-GT AE51</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////166963417" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">86,39 €</span>
                            <span class="tire-buy-button-total-price">(345,56 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container " data-tire-box-position="7" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="DUNLOP SP SPORT BLURESPONSE" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/11019-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="14865685">
                                <span class="tire-article-name" itemprop="name">DUNLOP SP SPORT BLURESPONSE</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="DUNLOP">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////14865685" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(359,48 €)</span>
                            <span class="tire-buy-button-article-price">89,87 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="89.87">
                            <meta itemprop="price" content="89.87">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="DUNLOP SP SPORT BLURESPONSE" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/11019-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">DUNLOP SP SPORT BLURESPONSE</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////14865685" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">89,87 €</span>
                            <span class="tire-buy-button-total-price">(359,48 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container " data-tire-box-position="8" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="HANKOOK K135 VENTUS PRIME4" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21827-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="358740316">
                                <span class="tire-article-name" itemprop="name">HANKOOK K135 VENTUS PRIME4</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">SBL</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="HANKOOK">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////358740316" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(335,88 €)</span>
                            <span class="tire-buy-button-article-price">83,97 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="83.97">
                            <meta itemprop="price" content="83.97">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="HANKOOK K135 VENTUS PRIME4" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21827-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">HANKOOK K135 VENTUS PRIME4</span>
                                <span class="tire-article-extra">SBL</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////358740316" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">83,97 €</span>
                            <span class="tire-buy-button-total-price">(335,88 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container " data-tire-box-position="9" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="PIRELLI P-ZERO (PZ4) (NEW) S.C." class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16697-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/pirelli-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="193500735">
                                <span class="tire-article-name" itemprop="name">PIRELLI P-ZERO (PZ4) (NEW) S.C.</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">P-ZERO (NEU) S.C. (*)</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="PIRELLI">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////193500735" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(461,96 €)</span>
                            <span class="tire-buy-button-article-price">115,49 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="115.49">
                            <meta itemprop="price" content="115.49">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="PIRELLI P-ZERO (PZ4) (NEW) S.C." class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16697-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/pirelli-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">PIRELLI P-ZERO (PZ4) (NEW) S.C.</span>
                                <span class="tire-article-extra">P-ZERO (NEU) S.C. (*)</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////193500735" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">115,49 €</span>
                            <span class="tire-buy-button-total-price">(461,96 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container " data-tire-box-position="10" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="KLEBER Dynaxer UHP" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19438-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/kleber-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="345302541">
                                <span class="tire-article-name" itemprop="name">KLEBER Dynaxer UHP</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="KLEBER">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////345302541" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(310,48 €)</span>
                            <span class="tire-buy-button-article-price">77,62 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="77.62">
                            <meta itemprop="price" content="77.62">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="KLEBER Dynaxer UHP" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19438-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/kleber-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">KLEBER Dynaxer UHP</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////345302541" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">77,62 €</span>
                            <span class="tire-buy-button-total-price">(310,48 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="11" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="VREDESTEIN ULTRAC (NEU)" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21364-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/vredestein-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="243053511">
                                <span class="tire-article-name" itemprop="name">VREDESTEIN ULTRAC (NEU)</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="VREDESTEIN">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////243053511" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(359,16 €)</span>
                            <span class="tire-buy-button-article-price">89,79 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="89.79">
                            <meta itemprop="price" content="89.79">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="VREDESTEIN ULTRAC (NEU)" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21364-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/vredestein-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">VREDESTEIN ULTRAC (NEU)</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////243053511" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">89,79 €</span>
                            <span class="tire-buy-button-total-price">(359,16 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="12" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="GOODYEAR EAGLE F1 ASYMMETRIC 6" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21779-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/goodyear-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="335880875">
                                <span class="tire-article-name" itemprop="name">GOODYEAR EAGLE F1 ASYMMETRIC 6</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">FP</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="GOODYEAR">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////335880875" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(367,56 €)</span>
                            <span class="tire-buy-button-article-price">91,89 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="91.89">
                            <meta itemprop="price" content="91.89">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="GOODYEAR EAGLE F1 ASYMMETRIC 6" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21779-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/goodyear-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">GOODYEAR EAGLE F1 ASYMMETRIC 6</span>
                                <span class="tire-article-extra">FP</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////335880875" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">91,89 €</span>
                            <span class="tire-buy-button-total-price">(367,56 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="13" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="HANKOOK K117 VENTUS S1 EVO2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/9700-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="127777042">
                                <span class="tire-article-name" itemprop="name">HANKOOK K117 VENTUS S1 EVO2</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="HANKOOK">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////127777042" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(356,16 €)</span>
                            <span class="tire-buy-button-article-price">89,04 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="89.04">
                            <meta itemprop="price" content="89.04">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="HANKOOK K117 VENTUS S1 EVO2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/9700-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">HANKOOK K117 VENTUS S1 EVO2</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////127777042" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">89,04 €</span>
                            <span class="tire-buy-button-total-price">(356,16 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="14" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="BF-GOODRICH ADVANTAGE" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20792-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bf-goodrich-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="511892143">
                                <span class="tire-article-name" itemprop="name">BF-GOODRICH ADVANTAGE</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="BF-GOODRICH">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////511892143" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(472,32 €)</span>
                            <span class="tire-buy-button-article-price">118,08 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="118.08">
                            <meta itemprop="price" content="118.08">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="BF-GOODRICH ADVANTAGE" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20792-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bf-goodrich-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">BF-GOODRICH ADVANTAGE</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////511892143" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">118,08 €</span>
                            <span class="tire-buy-button-total-price">(472,32 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="15" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="TOYO PROXES COMFORT" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21352-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/toyo-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="229543123">
                                <span class="tire-article-name" itemprop="name">TOYO PROXES COMFORT</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="TOYO">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////229543123" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(311,44 €)</span>
                            <span class="tire-buy-button-article-price">77,86 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="77.86">
                            <meta itemprop="price" content="77.86">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="TOYO PROXES COMFORT" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21352-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/toyo-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">TOYO PROXES COMFORT</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////229543123" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">77,86 €</span>
                            <span class="tire-buy-button-total-price">(311,44 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="16" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="MICHELIN PRIMACY 4+" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21805-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/michelin-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="359154370">
                                <span class="tire-article-name" itemprop="name">MICHELIN PRIMACY 4+</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="MICHELIN">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////359154370" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(423,24 €)</span>
                            <span class="tire-buy-button-article-price">105,81 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="105.81">
                            <meta itemprop="price" content="105.81">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="MICHELIN PRIMACY 4+" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21805-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/michelin-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">MICHELIN PRIMACY 4+</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////359154370" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">105,81 €</span>
                            <span class="tire-buy-button-total-price">(423,24 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="17" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="FALKEN FK520 AZENIS" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21953-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/falken-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="341526542">
                                <span class="tire-article-name" itemprop="name">FALKEN FK520 AZENIS</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">MFS</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="FALKEN">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////341526542" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(321,40 €)</span>
                            <span class="tire-buy-button-article-price">80,35 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="80.35">
                            <meta itemprop="price" content="80.35">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="FALKEN FK520 AZENIS" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21953-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/falken-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">FALKEN FK520 AZENIS</span>
                                <span class="tire-article-extra">MFS</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////341526542" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">80,35 €</span>
                            <span class="tire-buy-button-total-price">(321,40 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="18" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="GOODYEAR EFFICIENTGRIP PERFORMANCE 2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20800-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/goodyear-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="141007014">
                                <span class="tire-article-name" itemprop="name">GOODYEAR EFFICIENTGRIP PERFORMANCE 2</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">FP</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="GOODYEAR">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////141007014" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(339,72 €)</span>
                            <span class="tire-buy-button-article-price">84,93 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="84.93">
                            <meta itemprop="price" content="84.93">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="GOODYEAR EFFICIENTGRIP PERFORMANCE 2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20800-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/goodyear-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">GOODYEAR EFFICIENTGRIP PERFORMANCE 2</span>
                                <span class="tire-article-extra">FP</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////141007014" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">84,93 €</span>
                            <span class="tire-buy-button-total-price">(339,72 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="19" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="PIRELLI CINTURATO P7 (P7C2)" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20904-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/pirelli-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="594334600">
                                <span class="tire-article-name" itemprop="name">PIRELLI CINTURATO P7 (P7C2)</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="PIRELLI">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////594334600" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(350,68 €)</span>
                            <span class="tire-buy-button-article-price">87,67 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="87.67">
                            <meta itemprop="price" content="87.67">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="PIRELLI CINTURATO P7 (P7C2)" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20904-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/pirelli-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">PIRELLI CINTURATO P7 (P7C2)</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////594334600" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">87,67 €</span>
                            <span class="tire-buy-button-total-price">(350,68 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="20" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="CONTINENTAL PREMIUM CONTACT 7" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/22599-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/continental-manufacturer-7-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="606461898">
                                <span class="tire-article-name" itemprop="name">CONTINENTAL PREMIUM CONTACT 7</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">FR</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="CONTINENTAL">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////606461898" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(380,08 €)</span>
                            <span class="tire-buy-button-article-price">95,02 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="95.02">
                            <meta itemprop="price" content="95.02">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="CONTINENTAL PREMIUM CONTACT 7" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/22599-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/continental-manufacturer-7-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">CONTINENTAL PREMIUM CONTACT 7</span>
                                <span class="tire-article-extra">FR</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////606461898" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">95,02 €</span>
                            <span class="tire-buy-button-total-price">(380,08 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="21" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="NANKANG AS-2 PLUS" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16316-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/nankang-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="391724156">
                                <span class="tire-article-name" itemprop="name">NANKANG AS-2 PLUS</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="NANKANG">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////391724156" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(326,36 €)</span>
                            <span class="tire-buy-button-article-price">81,59 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="81.59">
                            <meta itemprop="price" content="81.59">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="NANKANG AS-2 PLUS" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16316-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/nankang-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">NANKANG AS-2 PLUS</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////391724156" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">81,59 €</span>
                            <span class="tire-buy-button-total-price">(326,36 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="22" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="KUMHO HS52 ECSTA" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21811-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/kumho-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="337398616">
                                <span class="tire-article-name" itemprop="name">KUMHO HS52 ECSTA</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="KUMHO">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////337398616" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(290,60 €)</span>
                            <span class="tire-buy-button-article-price">72,65 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="72.65">
                            <meta itemprop="price" content="72.65">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="KUMHO HS52 ECSTA" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21811-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/kumho-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">KUMHO HS52 ECSTA</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////337398616" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">72,65 €</span>
                            <span class="tire-buy-button-total-price">(290,60 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="23" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="UNIROYAL RAINSPORT 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20586-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/uniroyal-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="139046147">
                                <span class="tire-article-name" itemprop="name">UNIROYAL RAINSPORT 5</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="UNIROYAL">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////139046147" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(318,00 €)</span>
                            <span class="tire-buy-button-article-price">79,50 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="79.50">
                            <meta itemprop="price" content="79.50">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="UNIROYAL RAINSPORT 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20586-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/uniroyal-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">UNIROYAL RAINSPORT 5</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////139046147" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">79,50 €</span>
                            <span class="tire-buy-button-total-price">(318,00 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="24" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="HANKOOK K117B VENTUS S1 EVO2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/18217-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="133016256">
                                <span class="tire-article-name" itemprop="name">HANKOOK K117B VENTUS S1 EVO2</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">RUNFLAT (*)</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="HANKOOK">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////133016256" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(398,76 €)</span>
                            <span class="tire-buy-button-article-price">99,69 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="99.69">
                            <meta itemprop="price" content="99.69">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="HANKOOK K117B VENTUS S1 EVO2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/18217-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">HANKOOK K117B VENTUS S1 EVO2</span>
                                <span class="tire-article-extra">RUNFLAT (*)</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////133016256" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">99,69 €</span>
                            <span class="tire-buy-button-total-price">(398,76 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="25" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="MAXXIS VICTRA SPORT 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19604-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/maxxis-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="133154276">
                                <span class="tire-article-name" itemprop="name">MAXXIS VICTRA SPORT 5</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="MAXXIS">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////133154276" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(287,36 €)</span>
                            <span class="tire-buy-button-article-price">71,84 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="71.84">
                            <meta itemprop="price" content="71.84">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="MAXXIS VICTRA SPORT 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19604-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/maxxis-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">MAXXIS VICTRA SPORT 5</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////133154276" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">71,84 €</span>
                            <span class="tire-buy-button-total-price">(287,36 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="26" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="KUMHO PS71" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17611-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/kumho-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="547719648">
                                <span class="tire-article-name" itemprop="name">KUMHO PS71</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="KUMHO">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////547719648" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(291,92 €)</span>
                            <span class="tire-buy-button-article-price">72,98 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="72.98">
                            <meta itemprop="price" content="72.98">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="KUMHO PS71" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17611-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/kumho-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">KUMHO PS71</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////547719648" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">72,98 €</span>
                            <span class="tire-buy-button-total-price">(291,92 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="27" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="FIRESTONE ROADHAWK" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17566-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/firestone-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="617764492">
                                <span class="tire-article-name" itemprop="name">FIRESTONE ROADHAWK</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="FIRESTONE">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////617764492" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(318,68 €)</span>
                            <span class="tire-buy-button-article-price">79,67 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="79.67">
                            <meta itemprop="price" content="79.67">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="FIRESTONE ROADHAWK" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17566-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/firestone-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">FIRESTONE ROADHAWK</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////617764492" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">79,67 €</span>
                            <span class="tire-buy-button-total-price">(318,68 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="28" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="HANKOOK K127 VENTUS S1 EVO3" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19877-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="133074348">
                                <span class="tire-article-name" itemprop="name">HANKOOK K127 VENTUS S1 EVO3</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="HANKOOK">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////133074348" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(347,84 €)</span>
                            <span class="tire-buy-button-article-price">86,96 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="86.96">
                            <meta itemprop="price" content="86.96">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="HANKOOK K127 VENTUS S1 EVO3" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19877-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">HANKOOK K127 VENTUS S1 EVO3</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////133074348" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">86,96 €</span>
                            <span class="tire-buy-button-total-price">(347,84 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="29" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="MICHELIN PILOT SPORT 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21807-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/michelin-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="334632568">
                                <span class="tire-article-name" itemprop="name">MICHELIN PILOT SPORT 5</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="MICHELIN">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////334632568" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(459,92 €)</span>
                            <span class="tire-buy-button-article-price">114,98 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="114.98">
                            <meta itemprop="price" content="114.98">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="MICHELIN PILOT SPORT 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21807-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/michelin-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">MICHELIN PILOT SPORT 5</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////334632568" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">114,98 €</span>
                            <span class="tire-buy-button-total-price">(459,92 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="30" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="DUNLOP SP SPORT MAXX RT V1" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/11203-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="14867928">
                                <span class="tire-article-name" itemprop="name">DUNLOP SP SPORT MAXX RT V1</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">AO2</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="DUNLOP">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////14867928" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(360,72 €)</span>
                            <span class="tire-buy-button-article-price">90,18 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="90.18">
                            <meta itemprop="price" content="90.18">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="DUNLOP SP SPORT MAXX RT V1" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/11203-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">DUNLOP SP SPORT MAXX RT V1</span>
                                <span class="tire-article-extra">AO2</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////14867928" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">90,18 €</span>
                            <span class="tire-buy-button-total-price">(360,72 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="31" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="FALKEN ZE-310 ZIEX ECORUN" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/18841-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/falken-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="166723967">
                                <span class="tire-article-name" itemprop="name">FALKEN ZE-310 ZIEX ECORUN</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="FALKEN">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////166723967" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(320,28 €)</span>
                            <span class="tire-buy-button-article-price">80,07 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="80.07">
                            <meta itemprop="price" content="80.07">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="FALKEN ZE-310 ZIEX ECORUN" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/18841-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/falken-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">FALKEN ZE-310 ZIEX ECORUN</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////166723967" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">80,07 €</span>
                            <span class="tire-buy-button-total-price">(320,28 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="32" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="MAXXIS HP-5 PREMITRA 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16223-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/maxxis-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="652438169">
                                <span class="tire-article-name" itemprop="name">MAXXIS HP-5 PREMITRA 5</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="MAXXIS">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////652438169" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(269,84 €)</span>
                            <span class="tire-buy-button-article-price">67,46 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="67.46">
                            <meta itemprop="price" content="67.46">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="MAXXIS HP-5 PREMITRA 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16223-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/maxxis-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">MAXXIS HP-5 PREMITRA 5</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////652438169" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">67,46 €</span>
                            <span class="tire-buy-button-total-price">(269,84 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="33" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="HANKOOK K115 Ventus Prime2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/8775-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="132770690">
                                <span class="tire-article-name" itemprop="name">HANKOOK K115 Ventus Prime2</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">OE HYUNDAI</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="HANKOOK">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////132770690" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(344,28 €)</span>
                            <span class="tire-buy-button-article-price">86,07 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="86.07">
                            <meta itemprop="price" content="86.07">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="HANKOOK K115 Ventus Prime2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/8775-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/hankook-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">HANKOOK K115 Ventus Prime2</span>
                                <span class="tire-article-extra">OE HYUNDAI</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////132770690" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">86,07 €</span>
                            <span class="tire-buy-button-total-price">(344,28 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="34" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="MICHELIN PILOT SPORT 4" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16172-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/michelin-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="189584885">
                                <span class="tire-article-name" itemprop="name">MICHELIN PILOT SPORT 4</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="MICHELIN">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////189584885" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(416,64 €)</span>
                            <span class="tire-buy-button-article-price">104,16 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="104.16">
                            <meta itemprop="price" content="104.16">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="MICHELIN PILOT SPORT 4" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16172-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/michelin-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">MICHELIN PILOT SPORT 4</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////189584885" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">104,16 €</span>
                            <span class="tire-buy-button-total-price">(416,64 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="35" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="NEXEN N`FERA PRIMUS (SU1 PLUS)" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19886-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/nexen-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="133298427">
                                <span class="tire-article-name" itemprop="name">NEXEN N`FERA PRIMUS (SU1 PLUS)</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="NEXEN">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////133298427" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(289,04 €)</span>
                            <span class="tire-buy-button-article-price">72,26 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="72.26">
                            <meta itemprop="price" content="72.26">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="NEXEN N`FERA PRIMUS (SU1 PLUS)" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19886-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/nexen-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">NEXEN N`FERA PRIMUS (SU1 PLUS)</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////133298427" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">72,26 €</span>
                            <span class="tire-buy-button-total-price">(289,04 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="36" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="DUNLOP SP SPORT MAXX RT 2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16171-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="186426124">
                                <span class="tire-article-name" itemprop="name">DUNLOP SP SPORT MAXX RT 2</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">MFS</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="DUNLOP">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////186426124" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(352,08 €)</span>
                            <span class="tire-buy-button-article-price">88,02 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="88.02">
                            <meta itemprop="price" content="88.02">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="DUNLOP SP SPORT MAXX RT 2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16171-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">DUNLOP SP SPORT MAXX RT 2</span>
                                <span class="tire-article-extra">MFS</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////186426124" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">88,02 €</span>
                            <span class="tire-buy-button-total-price">(352,08 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="37" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="BRIDGESTONE POTENZA SPORT" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21354-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="200091593">
                                <span class="tire-article-name" itemprop="name">BRIDGESTONE POTENZA SPORT</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">MFS</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="BRIDGESTONE">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////200091593" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(367,36 €)</span>
                            <span class="tire-buy-button-article-price">91,84 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="91.84">
                            <meta itemprop="price" content="91.84">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="BRIDGESTONE POTENZA SPORT" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21354-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">BRIDGESTONE POTENZA SPORT</span>
                                <span class="tire-article-extra">MFS</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////200091593" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">91,84 €</span>
                            <span class="tire-buy-button-total-price">(367,36 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="38" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="YOKOHAMA ADVAN SPORT V105S" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/15593-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/yokohama-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="136481808">
                                <span class="tire-article-name" itemprop="name">YOKOHAMA ADVAN SPORT V105S</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="YOKOHAMA">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////136481808" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(314,88 €)</span>
                            <span class="tire-buy-button-article-price">78,72 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="78.72">
                            <meta itemprop="price" content="78.72">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="YOKOHAMA ADVAN SPORT V105S" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/15593-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/yokohama-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">YOKOHAMA ADVAN SPORT V105S</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////136481808" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">78,72 €</span>
                            <span class="tire-buy-button-total-price">(314,88 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="39" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="UNIROYAL RAINSPORT 3" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/13159-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">E</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/uniroyal-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="133102774">
                                <span class="tire-article-name" itemprop="name">UNIROYAL RAINSPORT 3</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">RUNFLAT</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="UNIROYAL">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////133102774" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(407,44 €)</span>
                            <span class="tire-buy-button-article-price">101,86 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="101.86">
                            <meta itemprop="price" content="101.86">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="UNIROYAL RAINSPORT 3" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/13159-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/uniroyal-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">UNIROYAL RAINSPORT 3</span>
                                <span class="tire-article-extra">RUNFLAT</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">E</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////133102774" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">101,86 €</span>
                            <span class="tire-buy-button-total-price">(407,44 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="40" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="CONTINENTAL ECO CONTACT 6" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19434-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/continental-manufacturer-7-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="149719662">
                                <span class="tire-article-name" itemprop="name">CONTINENTAL ECO CONTACT 6</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="CONTINENTAL">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////149719662" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(425,00 €)</span>
                            <span class="tire-buy-button-article-price">106,25 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="106.25">
                            <meta itemprop="price" content="106.25">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="CONTINENTAL ECO CONTACT 6" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19434-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/continental-manufacturer-7-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">CONTINENTAL ECO CONTACT 6</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">A</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////149719662" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">106,25 €</span>
                            <span class="tire-buy-button-total-price">(425,00 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="41" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="DUNLOP SP SPORT MAXX RT" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/10117-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="701813187">
                                <span class="tire-article-name" itemprop="name">DUNLOP SP SPORT MAXX RT</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">MFS</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="DUNLOP">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////701813187" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(351,40 €)</span>
                            <span class="tire-buy-button-article-price">87,85 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="87.85">
                            <meta itemprop="price" content="87.85">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="DUNLOP SP SPORT MAXX RT" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/10117-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">DUNLOP SP SPORT MAXX RT</span>
                                <span class="tire-article-extra">MFS</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////701813187" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">87,85 €</span>
                            <span class="tire-buy-button-total-price">(351,40 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="42" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="SYRON PREMIUM PERFORMANCE G2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21561-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/syron-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="226380656">
                                <span class="tire-article-name" itemprop="name">SYRON PREMIUM PERFORMANCE G2</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">G2</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="SYRON">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////226380656" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(248,84 €)</span>
                            <span class="tire-buy-button-article-price">62,21 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="62.21">
                            <meta itemprop="price" content="62.21">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="SYRON PREMIUM PERFORMANCE G2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21561-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/syron-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">SYRON PREMIUM PERFORMANCE G2</span>
                                <span class="tire-article-extra">G2</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////226380656" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">62,21 €</span>
                            <span class="tire-buy-button-total-price">(248,84 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="43" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="FULDA SPORTCONTROL 2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17586-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/fulda-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="140304014">
                                <span class="tire-article-name" itemprop="name">FULDA SPORTCONTROL 2</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">FP</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="FULDA">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////140304014" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(319,88 €)</span>
                            <span class="tire-buy-button-article-price">79,97 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="79.97">
                            <meta itemprop="price" content="79.97">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="FULDA SPORTCONTROL 2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17586-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/fulda-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">FULDA SPORTCONTROL 2</span>
                                <span class="tire-article-extra">FP</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////140304014" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">79,97 €</span>
                            <span class="tire-buy-button-total-price">(319,88 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="44" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="SAVA INTENSA UHP 2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17587-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/sava-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="139344517">
                                <span class="tire-article-name" itemprop="name">SAVA INTENSA UHP 2</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">FP</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="SAVA">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////139344517" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(241,16 €)</span>
                            <span class="tire-buy-button-article-price">60,29 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="60.29">
                            <meta itemprop="price" content="60.29">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="SAVA INTENSA UHP 2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17587-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/sava-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">SAVA INTENSA UHP 2</span>
                                <span class="tire-article-extra">FP</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////139344517" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">60,29 €</span>
                            <span class="tire-buy-button-total-price">(241,16 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="45" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="SUPERIA TIRES ECOBLUE UHP" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/15280-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/superia-tires-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="200410344">
                                <span class="tire-article-name" itemprop="name">SUPERIA TIRES ECOBLUE UHP</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="SUPERIA TIRES">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////200410344" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(231,36 €)</span>
                            <span class="tire-buy-button-article-price">57,84 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="57.84">
                            <meta itemprop="price" content="57.84">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="SUPERIA TIRES ECOBLUE UHP" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/15280-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/superia-tires-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">SUPERIA TIRES ECOBLUE UHP</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////200410344" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">57,84 €</span>
                            <span class="tire-buy-button-total-price">(231,36 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="46" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="MASSIMO OTTIMA PLUS" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/23351-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/404-160x65.png">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="736000541">
                                <span class="tire-article-name" itemprop="name">MASSIMO OTTIMA PLUS</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="MASSIMO">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////736000541" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(208,00 €)</span>
                            <span class="tire-buy-button-article-price">52,00 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="52.00">
                            <meta itemprop="price" content="52.00">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="MASSIMO OTTIMA PLUS" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/23351-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/404-160x65.png">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">MASSIMO OTTIMA PLUS</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////736000541" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">52,00 €</span>
                            <span class="tire-buy-button-total-price">(208,00 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="47" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="CONTINENTAL ECO CONTACT 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/8838-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/continental-manufacturer-7-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="356416516">
                                <span class="tire-article-name" itemprop="name">CONTINENTAL ECO CONTACT 5</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">AO</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="CONTINENTAL">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////356416516" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(418,84 €)</span>
                            <span class="tire-buy-button-article-price">104,71 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="104.71">
                            <meta itemprop="price" content="104.71">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="CONTINENTAL ECO CONTACT 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/8838-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/continental-manufacturer-7-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">CONTINENTAL ECO CONTACT 5</span>
                                <span class="tire-article-extra">AO</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////356416516" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">104,71 €</span>
                            <span class="tire-buy-button-total-price">(418,84 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="48" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="TRISTAR SPORTPOWER 2 (F205)" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17652-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/tristar-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="356416568">
                                <span class="tire-article-name" itemprop="name">TRISTAR SPORTPOWER 2 (F205)</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="TRISTAR">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////356416568" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(286,76 €)</span>
                            <span class="tire-buy-button-article-price">71,69 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="71.69">
                            <meta itemprop="price" content="71.69">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="TRISTAR SPORTPOWER 2 (F205)" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17652-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/tristar-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">TRISTAR SPORTPOWER 2 (F205)</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////356416568" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">71,69 €</span>
                            <span class="tire-buy-button-total-price">(286,76 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="49" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="PIRELLI CINTURATO P7" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/7013-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/pirelli-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="74105673">
                                <span class="tire-article-name" itemprop="name">PIRELLI CINTURATO P7</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">AO</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="PIRELLI">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////74105673" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(363,88 €)</span>
                            <span class="tire-buy-button-article-price">90,97 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="90.97">
                            <meta itemprop="price" content="90.97">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="PIRELLI CINTURATO P7" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/7013-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/pirelli-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">PIRELLI CINTURATO P7</span>
                                <span class="tire-article-extra">AO</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////74105673" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">90,97 €</span>
                            <span class="tire-buy-button-total-price">(363,88 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="50" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="CONTINENTAL SPORT CONTACT 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/9121-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/continental-manufacturer-7-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="63531717">
                                <span class="tire-article-name" itemprop="name">CONTINENTAL SPORT CONTACT 5</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">FR MO</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="CONTINENTAL">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////63531717" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(386,80 €)</span>
                            <span class="tire-buy-button-article-price">96,70 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="96.70">
                            <meta itemprop="price" content="96.70">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="CONTINENTAL SPORT CONTACT 5" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/9121-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/continental-manufacturer-7-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">CONTINENTAL SPORT CONTACT 5</span>
                                <span class="tire-article-extra">FR MO</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////63531717" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">96,70 €</span>
                            <span class="tire-buy-button-total-price">(386,80 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="51" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="DEBICA PRESTO UHP 2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17588-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/debica-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="139344510">
                                <span class="tire-article-name" itemprop="name">DEBICA PRESTO UHP 2</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">FP</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="DEBICA">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////139344510" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(291,92 €)</span>
                            <span class="tire-buy-button-article-price">72,98 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="72.98">
                            <meta itemprop="price" content="72.98">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="DEBICA PRESTO UHP 2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17588-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/debica-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">DEBICA PRESTO UHP 2</span>
                                <span class="tire-article-extra">FP</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////139344510" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">72,98 €</span>
                            <span class="tire-buy-button-total-price">(291,92 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="52" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="MINERVA F205" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17655-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/minerva-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="116255750">
                                <span class="tire-article-name" itemprop="name">MINERVA F205</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="MINERVA">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////116255750" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(238,96 €)</span>
                            <span class="tire-buy-button-article-price">59,74 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="59.74">
                            <meta itemprop="price" content="59.74">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="MINERVA F205" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/17655-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/minerva-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">MINERVA F205</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////116255750" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">59,74 €</span>
                            <span class="tire-buy-button-total-price">(238,96 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="53" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="GOODYEAR EAGLE F1 ASYMMETRIC 3" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16144-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/goodyear-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="165147627">
                                <span class="tire-article-name" itemprop="name">GOODYEAR EAGLE F1 ASYMMETRIC 3</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">FP</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="GOODYEAR">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////165147627" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(342,32 €)</span>
                            <span class="tire-buy-button-article-price">85,58 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="85.58">
                            <meta itemprop="price" content="85.58">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="GOODYEAR EAGLE F1 ASYMMETRIC 3" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16144-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/goodyear-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">GOODYEAR EAGLE F1 ASYMMETRIC 3</span>
                                <span class="tire-article-extra">FP</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////165147627" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">85,58 €</span>
                            <span class="tire-buy-button-total-price">(342,32 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="54" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="SEMPERIT SPEED-LIFE 3" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20631-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/semperit-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="140547197">
                                <span class="tire-article-name" itemprop="name">SEMPERIT SPEED-LIFE 3</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="SEMPERIT">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////140547197" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(372,84 €)</span>
                            <span class="tire-buy-button-article-price">93,21 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="93.21">
                            <meta itemprop="price" content="93.21">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="SEMPERIT SPEED-LIFE 3" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20631-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/semperit-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">SEMPERIT SPEED-LIFE 3</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////140547197" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">93,21 €</span>
                            <span class="tire-buy-button-total-price">(372,84 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="55" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="LAUFENN S-FIT EQ+ (LK01)" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20905-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/laufenn-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="141958762">
                                <span class="tire-article-name" itemprop="name">LAUFENN S-FIT EQ+ (LK01)</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">LK01</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="LAUFENN">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////141958762" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(268,44 €)</span>
                            <span class="tire-buy-button-article-price">67,11 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="67.11">
                            <meta itemprop="price" content="67.11">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="LAUFENN S-FIT EQ+ (LK01)" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20905-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/laufenn-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">LAUFENN S-FIT EQ+ (LK01)</span>
                                <span class="tire-article-extra">LK01</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////141958762" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">67,11 €</span>
                            <span class="tire-buy-button-total-price">(268,44 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="56" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="MICHELIN PILOT SPORT PS2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/190-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/michelin-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="167106302">
                                <span class="tire-article-name" itemprop="name">MICHELIN PILOT SPORT PS2</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">N3</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="MICHELIN">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////167106302" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(445,52 €)</span>
                            <span class="tire-buy-button-article-price">111,38 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="111.38">
                            <meta itemprop="price" content="111.38">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="MICHELIN PILOT SPORT PS2" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/190-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/michelin-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">MICHELIN PILOT SPORT PS2</span>
                                <span class="tire-article-extra">N3</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////167106302" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">111,38 €</span>
                            <span class="tire-buy-button-total-price">(445,52 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="57" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="KUMHO HS51 ECSTA" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/13534-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/kumho-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="194169414">
                                <span class="tire-article-name" itemprop="name">KUMHO HS51 ECSTA</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="KUMHO">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////194169414" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(301,40 €)</span>
                            <span class="tire-buy-button-article-price">75,35 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="75.35">
                            <meta itemprop="price" content="75.35">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="KUMHO HS51 ECSTA" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/13534-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/kumho-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">KUMHO HS51 ECSTA</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">69</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////194169414" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">75,35 €</span>
                            <span class="tire-buy-button-total-price">(301,40 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="58" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="DUNLOP SP SPORT FASTRESPONSE" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/4392-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="568861354">
                                <span class="tire-article-name" itemprop="name">DUNLOP SP SPORT FASTRESPONSE</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">AO MFS AUDI</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="DUNLOP">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////568861354" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(364,88 €)</span>
                            <span class="tire-buy-button-article-price">91,22 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="91.22">
                            <meta itemprop="price" content="91.22">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="DUNLOP SP SPORT FASTRESPONSE" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/4392-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">DUNLOP SP SPORT FASTRESPONSE</span>
                                <span class="tire-article-extra">AO MFS AUDI</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////568861354" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">91,22 €</span>
                            <span class="tire-buy-button-total-price">(364,88 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="59" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="BARUM BRAVURIS 5 HM" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19656-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/barum-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="511892144">
                                <span class="tire-article-name" itemprop="name">BARUM BRAVURIS 5 HM</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="BARUM">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////511892144" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(328,40 €)</span>
                            <span class="tire-buy-button-article-price">82,10 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="82.10">
                            <meta itemprop="price" content="82.10">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="BARUM BRAVURIS 5 HM" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/19656-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/barum-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">BARUM BRAVURIS 5 HM</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////511892144" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">82,10 €</span>
                            <span class="tire-buy-button-total-price">(328,40 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="60" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="BRIDGESTONE POTENZA S001" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/7808-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="216066849">
                                <span class="tire-article-name" itemprop="name">BRIDGESTONE POTENZA S001</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">(*) RUNFLAT</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="BRIDGESTONE">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////216066849" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(462,80 €)</span>
                            <span class="tire-buy-button-article-price">115,70 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="115.70">
                            <meta itemprop="price" content="115.70">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="BRIDGESTONE POTENZA S001" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/7808-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">BRIDGESTONE POTENZA S001</span>
                                <span class="tire-article-extra">(*) RUNFLAT</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////216066849" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">115,70 €</span>
                            <span class="tire-buy-button-total-price">(462,80 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="61" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="BRIDGESTONE Potenza RE 050 A" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/1072-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="356416537">
                                <span class="tire-article-name" itemprop="name">BRIDGESTONE Potenza RE 050 A</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">RUNFLAT (*)</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="BRIDGESTONE">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////356416537" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(497,28 €)</span>
                            <span class="tire-buy-button-article-price">124,32 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="124.32">
                            <meta itemprop="price" content="124.32">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="BRIDGESTONE Potenza RE 050 A" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/1072-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">BRIDGESTONE Potenza RE 050 A</span>
                                <span class="tire-article-extra">RUNFLAT (*)</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////356416537" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">124,32 €</span>
                            <span class="tire-buy-button-total-price">(497,28 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="62" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="BRIDGESTONE TURANZA T001" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/10038-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="205042315">
                                <span class="tire-article-name" itemprop="name">BRIDGESTONE TURANZA T001</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">MO</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="BRIDGESTONE">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////205042315" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(413,28 €)</span>
                            <span class="tire-buy-button-article-price">103,32 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="103.32">
                            <meta itemprop="price" content="103.32">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="BRIDGESTONE TURANZA T001" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/10038-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">BRIDGESTONE TURANZA T001</span>
                                <span class="tire-article-extra">MO</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////205042315" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">103,32 €</span>
                            <span class="tire-buy-button-total-price">(413,28 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="63" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="YOKOHAMA ADVAN SPORT V105" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/11124-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/yokohama-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="511892122">
                                <span class="tire-article-name" itemprop="name">YOKOHAMA ADVAN SPORT V105</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">MO E.A. SLK</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="YOKOHAMA">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////511892122" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(361,48 €)</span>
                            <span class="tire-buy-button-article-price">90,37 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="90.37">
                            <meta itemprop="price" content="90.37">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="YOKOHAMA ADVAN SPORT V105" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/11124-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/yokohama-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">YOKOHAMA ADVAN SPORT V105</span>
                                <span class="tire-article-extra">MO E.A. SLK</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////511892122" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">90,37 €</span>
                            <span class="tire-buy-button-total-price">(361,48 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="64" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="PIRELLI P7" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/650-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">E</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/pirelli-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="206538006">
                                <span class="tire-article-name" itemprop="name">PIRELLI P7</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="PIRELLI">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////206538006" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(329,68 €)</span>
                            <span class="tire-buy-button-article-price">82,42 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="82.42">
                            <meta itemprop="price" content="82.42">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="PIRELLI P7" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/650-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/pirelli-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">PIRELLI P7</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">B</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">E</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////206538006" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">82,42 €</span>
                            <span class="tire-buy-button-total-price">(329,68 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="65" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="FORTUNE FSR701" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/18152-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/404-160x65.png">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="482341294">
                                <span class="tire-article-name" itemprop="name">FORTUNE FSR701</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="FORTUNE">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////482341294" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(235,56 €)</span>
                            <span class="tire-buy-button-article-price">58,89 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="58.89">
                            <meta itemprop="price" content="58.89">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="FORTUNE FSR701" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/18152-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/404-160x65.png">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">FORTUNE FSR701</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////482341294" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">58,89 €</span>
                            <span class="tire-buy-button-total-price">(235,56 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="66" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="DUNLOP SP SPORT MAXX TT" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/6161-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="14865677">
                                <span class="tire-article-name" itemprop="name">DUNLOP SP SPORT MAXX TT</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">MFS (*) RUNFLAT</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="DUNLOP">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////14865677" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(433,88 €)</span>
                            <span class="tire-buy-button-article-price">108,47 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="108.47">
                            <meta itemprop="price" content="108.47">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="DUNLOP SP SPORT MAXX TT" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/6161-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/dunlop-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">DUNLOP SP SPORT MAXX TT</span>
                                <span class="tire-article-extra">MFS (*) RUNFLAT</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////14865677" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">108,47 €</span>
                            <span class="tire-buy-button-total-price">(433,88 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="67" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="BRIDGESTONE Turanza ER 33" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/4728-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="356416512">
                                <span class="tire-article-name" itemprop="name">BRIDGESTONE Turanza ER 33</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">RUNFLAT</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="BRIDGESTONE">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////356416512" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(509,80 €)</span>
                            <span class="tire-buy-button-article-price">127,45 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="127.45">
                            <meta itemprop="price" content="127.45">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="BRIDGESTONE Turanza ER 33" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/4728-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">BRIDGESTONE Turanza ER 33</span>
                                <span class="tire-article-extra">RUNFLAT</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////356416512" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">127,45 €</span>
                            <span class="tire-buy-button-total-price">(509,80 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="68" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="GOODYEAR EXCELLENCE" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/517-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/goodyear-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="364113745">
                                <span class="tire-article-name" itemprop="name">GOODYEAR EXCELLENCE</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">MO EXTENDED</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="GOODYEAR">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////364113745" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(371,28 €)</span>
                            <span class="tire-buy-button-article-price">92,82 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="92.82">
                            <meta itemprop="price" content="92.82">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="GOODYEAR EXCELLENCE" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/517-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/goodyear-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">GOODYEAR EXCELLENCE</span>
                                <span class="tire-article-extra">MO EXTENDED</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////364113745" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">92,82 €</span>
                            <span class="tire-buy-button-total-price">(371,28 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="69" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="YOKOHAMA C DRIVE 2 AC02" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/7825-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/yokohama-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="14866402">
                                <span class="tire-article-name" itemprop="name">YOKOHAMA C DRIVE 2 AC02</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">MO A/B KLASSE (W246)</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="YOKOHAMA">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////14866402" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(398,60 €)</span>
                            <span class="tire-buy-button-article-price">99,65 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="99.65">
                            <meta itemprop="price" content="99.65">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="YOKOHAMA C DRIVE 2 AC02" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/7825-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/yokohama-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">YOKOHAMA C DRIVE 2 AC02</span>
                                <span class="tire-article-extra">MO A/B KLASSE (W246)</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91V</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">V</div> (max. 240 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">70</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////14866402" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">99,65 €</span>
                            <span class="tire-buy-button-total-price">(398,60 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="70" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="BRIDGESTONE Turanza ER 300" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/1031-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="205042317">
                                <span class="tire-article-name" itemprop="name">BRIDGESTONE Turanza ER 300</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">ECOPIA MO</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="BRIDGESTONE">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////205042317" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(433,16 €)</span>
                            <span class="tire-buy-button-article-price">108,29 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="108.29">
                            <meta itemprop="price" content="108.29">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="BRIDGESTONE Turanza ER 300" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/1031-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/bridgestone-manufacturer-2-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">BRIDGESTONE Turanza ER 300</span>
                                <span class="tire-article-extra">ECOPIA MO</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">71</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////205042317" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">108,29 €</span>
                            <span class="tire-buy-button-total-price">(433,16 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="71" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="BERLIN TIRES SUMMER HP 1" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20882-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/berlin-tires-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="142930253">
                                <span class="tire-article-name" itemprop="name">BERLIN TIRES SUMMER HP 1</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="BERLIN TIRES">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////142930253" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(222,36 €)</span>
                            <span class="tire-buy-button-article-price">55,59 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="55.59">
                            <meta itemprop="price" content="55.59">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="BERLIN TIRES SUMMER HP 1" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/20882-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/berlin-tires-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">BERLIN TIRES SUMMER HP 1</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">D</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////142930253" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">55,59 €</span>
                            <span class="tire-buy-button-total-price">(222,36 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="72" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="SPORTIVA PERFORMANCE" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16450-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">E</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/sportiva-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="66990073">
                                <span class="tire-article-name" itemprop="name">SPORTIVA PERFORMANCE</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="SPORTIVA">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////66990073" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(258,56 €)</span>
                            <span class="tire-buy-button-article-price">64,64 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="64.64">
                            <meta itemprop="price" content="64.64">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="SPORTIVA PERFORMANCE" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/16450-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/sportiva-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">SPORTIVA PERFORMANCE</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94Y</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">Y</div> (max. 300 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">E</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////66990073" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">64,64 €</span>
                            <span class="tire-buy-button-total-price">(258,56 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="73" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="EP-TYRES ACCELERA PHI" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/3810-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">E</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/ep-tyres-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="454338101">
                                <span class="tire-article-name" itemprop="name">EP-TYRES ACCELERA PHI</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model"></span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="EP-TYRES">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////454338101" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(211,80 €)</span>
                            <span class="tire-buy-button-article-price">52,95 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="52.95">
                            <meta itemprop="price" content="52.95">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="EP-TYRES ACCELERA PHI" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/3810-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/ep-tyres-manufacturer-160x65.webp">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">EP-TYRES ACCELERA PHI</span>
                                <span class="tire-article-extra"></span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 94W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">94</div> (670 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">C</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">E</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">72</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////454338101" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">52,95 €</span>
                            <span class="tire-buy-button-total-price">(211,80 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div><div class="col-xs-12 tire-box-container" data-tire-box-position="74" itemtype="https://schema.org/Product" itemscope="">
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge " style="background-color: "></div>
                    <div class="tire-badge express "><img alt="Express Versand" src="data:image/svg+xml;base64,..."> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="KHEFREN K11" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21146-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">--</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">--</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">0</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/404-160x65.png">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="224045573">
                                <span class="tire-article-name" itemprop="name">KHEFREN K11</span>
                                <meta itemprop="category" content="Fahrzeuge &amp; Teile > Fahrzeugersatzteile &amp; -zubehör > Kfz-Teile > Kfz-Räder > Felgen &amp; Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">RETREAD</span>
                                <meta itemprop="model" content="">
                                <span itemprop="brand" itemscope="" itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="KHEFREN">
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <img alt="Ganzjahresreifen" class="tire-article-type-image " src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type ">Winterreifen</span>
                                <span class="tire-article-type show">Sommerreifen</span>
                                <span class="tire-article-type ">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope="" href="/indenwarenkorb////224045573" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-total-price">(238,92 €)</span>
                            <span class="tire-buy-button-article-price">59,73 €</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR">
                            <meta itemprop="lowPrice" content="59.73">
                            <meta itemprop="price" content="59.73">
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition">
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="KHEFREN K11" class="tire-image" src="https://www1.tyre24.com/images_ts/tyre/21146-tssoap_1388620713_1410870259-w300-h300-br1-1388620713.jpg">
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="//static.felgenshop.de/404-160x65.png">
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">KHEFREN K11</span>
                                <span class="tire-article-extra">RETREAD</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">225/45 R17 91W</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Sommerreifen" class="tire-article-type-image show" src="data:image/svg+xml;base64,...">
                                <span class="tire-article-type show">Sommerreifen</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">91</div> (615 kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">W</div> (max. 270 km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,...">
                                        <span class="cube">--</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,...">
                                        <span class="cube">--</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,...">
                                        <span class="cube">0</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="/indenwarenkorb////224045573" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,...">
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">59,73 €</span>
                            <span class="tire-buy-button-total-price">(238,92 €)</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div></div>
                <div class="col-xs-12 no-tires-found d-none">
                    <div class="no-tires-found-title">Keine Reifen in dieser Ausführung verfügbar</div>
                    <div class="no-tires-found-text">Derzeit haben wir keine Reifen in der von Dir ausgewählten Größe und Saison im Angebot. Unser Service hilft Dir gerne weiter, um eine passende Alternative zu finden. Nutze gerne unseren Chat, schreibe eine Mail an service@felgenshop.de oder ruf uns an unter 0461 430415-20.</div>
                </div>
                <div class="col-xs-12">
                    <div class="fs-article-load-more">
                        <div class="btn-wrap">
                            <button class="fs-btn default z-depth-1 raise ripple tire-load-more d-none">Mehr laden</button>
                        </div>
                    </div>
                </div>
            </div>
        </div>
    </div>
</div>

<div class="container">
    <div class="row">
        <div class="col-xs-12 tire-seo-text mb-5">
                            <h2>Reifen - Dein Ratgeber für deine neuen Pneus</h2>
                <p>Welche Reifen darf ich fahren?</p>
                <p>Stehst du vor dem Kauf neuer Kompletträder, aber welche Reifen darfst du fahren? Winterreifen,
                    Sommerreifen sowie Allwetterreifen - und das in verschiedensten Ausführungen. Hier eine Orientierung
                    für dich, um den richtigen Reifen zu finden! Die richtige Wahl zu fahren ist dabei für deine
                    Sicherheit von großer Bedeutung, aber auch für deinen Versicherungsschutz. Außerdem kann die Auswahl
                    der falschen Reifen auch zu einem erhöhten Kraftstoffverbrauch führen. Demnach bietet das genaue
                    Hinschauen beim Reifenkauf einfach einige Vorteile!</p>
                <p>Jetzt deine neuen Reifen günstig online finden!</p>
                <p>Du planst den Wechsel von Ganzjahresreifen auf Sommer- oder Winterreifen? Welcher Reifen darf
                    überhaupt auf deinem Fahrzeug gefahren werden? Wann muss gewechselt werden und ist das Wechseln
                    Pflicht? Bei uns findest du zu all deinen Fragen rund um den Reifen Antworten! So erlangst du hier
                    auch Einblicke in die Bedeutung der Reifenkürzel und was Eco-Reifen können. Außerdem erzählen wir
                    dir, wie du durch den Kauf des richtigen Reifens noch sparen kannst: Spritsparendes Fahren ist
                    angesagt!</p>
                <h2>Reifen über Reifen - Sommerreifen, Winterreifen und Ganzjahresreifen</h2>
                <h3>1. Wann muss ich meine Reifen wechseln?</h3>
                <p>Fährst du mit Sommerreifen oder Winterreifen? Stellt sich dir die Frage, wann sollte gewechselt
                    werden? Grundsätzlich kannst du dabei der Faustformel folgen, diese lautet von O bis O – von Ostern
                    bis Oktober Sommerreifen und von Oktober bis Ostern Winterreifen. Demnach solltest du deine Pneus
                    also zwei Mal im Jahr wechseln, dabei aber auf jeden Fall immer die Wetterlage nicht außer Acht
                    lassen. Aber auch im Allgemeinen solltest du deine Reifen spätestens alle 8.000 bis 10.000 Kilometer
                    auswechseln und neue kaufen. Es gilt zu beachten, dass die Mindestprofiltiefe von 1,6 Millimeter
                    nicht unterschritten wird, ganz gleich ob Sommer-, Winter- oder Ganzjahresreifen.</p>
                <h3>2. Gibt es eine Winter- und Sommerreifenpflicht?</h3>
                <p>Prinzipiell kann zunächst eines gesagt werden: Es gibt in Deutschland keine generelle
                    Winterreifenpflicht, jedoch eine situative! Ein Wechsel zu Winterreifen ist bei einer winterlichen
                    Witterung verpflichtend-, ansonsten muss dein Auto stehen bleiben. Ein Wechsel von Sommer- auf
                    Winterreifen in der kälteren Jahreszeit schützt dich außerdem vor Strafe und im Falle eines Unfalls
                    vor Problemen mit der Versicherung. So trägt der Versicherer unter Umständen die Kostenübernahme
                    nicht, wenn du im Winter mit Sommerreifen fährst. Für den Wechsel auf Sommerreifen herrscht in
                    Deutschland keine Pflicht.</p>
                <h2>Spritsparend fahren – Tipps und Tricks zur Senkung des Spritverbrauchs</h2>
                <p>Auch dir gehen die steigenden Spritkosten auf die Nerven?</p>
                <p>Hier die Faktoren, die deinen Spritverbrauch beeinflussen im Überblick:</p>
                <p>· Rollwiderstand des Reifens - Verringerung des Rollwiderstandes ermöglicht Einsparungen im
                    Kraftstoffverbrauch</p>
                <p>· Reifengröße - größere Reifen erhöhen den Gesamtfahrwiderstand des Fahrzeugs</p>
                <p>· Im Sommer auf Sommerreifen wechseln - Winterreifen haben erhöhten Rollwiderstand</p>
                <p>· Reifendruck regelmäßig kontrollieren - zu niedriger Reifendruck erhöht Verbrauch</p>
                <p>· Vorausschauendes Fahren - schnell hochschalten, nach dem Drehzahlmesser richten</p>
                <p>· Leichtlaufreifen statt herkömmliche Reifen - können den Kraftstoffverbrauch um bis zu sechs Prozent
                    reduzieren</p>
                <a href="https://www.umweltbundesamt.de/sites/default/files/medien/publikation/long/3705.pdf">Umweltbundesamt
                    - Sprit sparen und mobil sein</a>
                <h2>Nachhaltigkeit in der Reifenbranche – Material für die Zukunft</h2>
                <h3>1. Eco-Reifen – Was hat es damit auf sich?</h3>
                <p>Was sind eigentlich Eco Reifen? Eco Reifen, auch Leichtlaufreifen genannt, sind den
                    Kraftstoffverbrauch senkende Reifen. Aber was macht diesen Reifen aus und machen diese Reifen
                    wirklich einen Unterschied im Kraftstoffverbrauch? Von herkömmlichen Reifen unterscheidet sich
                    dieser Reifen durch seine andersartige Materialzusammensetzung. Er besteht aus einer vergleichsweise
                    umweltfreundlicheren Gummimischung und hat ein spezielles Profil, welches den Rollwiderstand
                    reduziert. Der Reifen eignet sich dabei eher für umsichtige Fahrer, da das glatte Profil des Reifens
                    auch die Bodenhaftung verringert und dadurch den Bremsweg verlängert.</p>
                <p>An dieser Stelle nochmals die Vorteile in Zusammenfassung:</p>
                <p>· Umweltfreundlichere Gummimischung</p>
                <p>· Geringerer Rollwiderstand</p>
                <p>· Leichter und geräuschärmer als herkömmliche Reifen</p>
                <p>· Ersparnis im Vergleich: um die 0,6 bis 0,8 Liter Kraftstoff pro 100 Kilometer</p>
                <h3>2. Innovative Reifen - Der neue Goodyear Konzeptreifen</h3>
                <p>Autoreifen und Umweltschutz? Ja, auch in der Reifenbranche hat die Nachhaltigkeit immer mehr an
                    Wichtigkeit gewonnen! So stellt beispielsweise das Unternehmen Goodyear, welches eines der größten
                    Reifenunternehmen der Welt ist, einen neuen Konzeptreifen vor. Das Faszinierende: dieser besteht zu
                    90% aus nachhaltigem Material. Heraussticht darüber hinaus auch der geringere Rollwiderstand, den
                    dieser Reifen im Vergleich zu Herkömmlichen aufweist. Letzterer sorgt für einen geringeren
                    Kraftstoffverbrauch, was wiederum zu einer Reduzierung der CO2-Emissionen führt.</p>
                <h2>Dein Reifenduden – 3 Fakten, die du kennen musst</h2>
                <h3>1. Was bedeutet die DOT-Nummer bei Reifen?</h3>
                <p>Auf der Seitenflanke eines Reifens findet sich eine Reihe an Nummern und Buchstaben, so
                    beispielsweise auch die DOT-Nummer. Aber was sagt diese eigentlich aus? Die DOT-Nummer, gibt dir
                    eine Angabe zum Alter der Reifen. Anhand eines Beispiels soll diese nun kurz erklärt werden:</p>
                <p>DOT XXX XXX XXX 2218</p>
                <p>Bei dieser Nummer sind die hinteren drei bis vier Ziffern entscheidend, die Länge der Nummer kann je
                    nach Hersteller variieren. Die vorderen zwei Ziffern geben an, in welcher Kalenderwoche der Reifen
                    hergestellt wurde. Demnach wurde der Reifen in diesem Beispiel in Kalenderwoche 22 hergestellt. Die
                    hinteren zwei Ziffern repräsentieren das Herstellungsjahr, in diesem Fall also 2018.</p>
                <h3>2. Reifenkürzel verstehen – Einfach gewusst wie!</h3>
                <p>Was hat es eigentlich mit den Reifenkürzeln auf der Reifenflanke auf sich? Wir verschaffen hier eine
                    kurze Aufklärung!</p>
                <p>Reifenbezeichnungen und ihre Bedeutung:</p>
                <p>· 225/35 R19 88 Y: Reifenkennung - Angaben zur Größe, Bau und Betriebskennung</p>
                <p>· M+S: Kennzeichen für “Matsch und Schnee” geeignet</p>
                <p>· ECE-Prüfzeichen: Zeichen für Einhaltung des EU-Standards, gilt als Betriebserlaubnis</p>
                <p>· Pfeil: Laufrichtung des Reifens, wenn laufrichtungsgebunden</p>
                <p>· DOT-Nummer: Angabe zum Alter des Reifens</p>
                <p>· Tubeless Reifen (TL): Schlauchloser Reifen</p>
                <p>· Run Flat: Reifen mit Notlaufeigenschaft</p>
                <p>· 3PMSF: Offizielle Kennung für Winterreifen</p>
                <h3>3. Reifen – Welcher Reifenhersteller steckt hinter deinen neuen Reifen?</h3>
                <p>Hast du auf deiner Suche bereits entdeckt, wie viele verschiedene Reifenhersteller bei uns im Shop zu
                    finden sind? Dabei gehören einige der Preistipp-Reifen Hersteller zu namhaften Premiumherstellern
                    wie Michelin und Continental.</p>
                <p>Hier ein kleiner Einblick dazu:</p>
                <p>Welcher Reifenhersteller steckt hinter deinen neuen Reifen? Diese Hersteller gehören zu…</p>
                <p>· Firestone, Nokian, Uniroyal: Bridgestone</p>
                <p>· Kleber, BF-Goodrich: Michelin</p>
                <p>· Barum, Uniroyal, Viking: Continental</p>
                <p>· Laufenn, Kingstar: Hankook</p>
                <p>· Dunlop: Goodyear</p>
                <h2>Neue Reifen für dein Fahrzeug online finden – Dein Kaufguide</h2>
                <h3>1. Welche Reifen dürfen ohne Eintragung gefahren werden?</h3>
                <p>Du kaufst dir neue Reifen, aber bist dir unsicher, welche Reifen du ohne eine Eintragung fahren
                    darfst? Grundsätzlich findest du zu den geeigneten Reifen für dein Fahrzeug alle Angaben im
                    Fahrzeugschein oder Zulassungsschein. Es gibt jedoch trotzdem auch Reifen, die für dein Fahrzeug
                    zwar geeignet sind, aber nicht im Schein auftauchen – Aufschluss darüber geben TÜV oder CoC Papiere.
                    Bei Fragen zur Beratung neuer Kompletträder stehen wir dir selbstverständlich gerne zur
                    Verfügung!</p>
                <h3>2. Kompletträder - Jetzt online günstig neue Reifen plus Felgen finden und kaufen</h3>
                <p>Du suchst nicht nur neue Reifen für dein Fahrzeug, sondern bist außerdem auf der Suche nach neuen
                    Felgen? Kein Problem, all das findest du bei uns! Es gibt die Möglichkeit, deine neuen Reifen mit
                    deiner Wunschfelge auf dein Fahrzeug ausgerichtet direkt online zu konfigurieren und als
                    Kompletträder zu kaufen. Dabei kannst du dir über unseren Konfigurator ganz einfach die für dein
                    Auto passenden Felgen anzeigen lassen. Angaben darüber, welche Maße dabei gefahren werden dürfen,
                    werden dir parallel auch vorgegeben.</p>
                <h3>3. Aktiv oder passiv - Braucht mein Auto RDKS-Sensoren?</h3>
                <p>Was ist der Unterschied zwischen aktiven und passiven Reifendruckkontrollsystemen? Am 01. November
                    2014 trat dazu eine EU-Regelung in Kraft - seitdem ist der Einbau eines RDKS in neu zugelassenen
                    Fahrzeugen verpflichtend. Aber was ist dabei der Unterschied zwischen aktivem und passivem System?
                    Bei einem aktiven System werden Sensoren direkt am Reifen angebracht, diese ermitteln permanent
                    Luftdruck und Temperatur. Außerdem wird dabei dauerhaft der Reifendruck im Cockpit angezeigt,
                    während beim passiven zwar ein Druckverlust angezeigt wird, nicht aber der tatsächliche Druck des
                    Reifens.</p>
                <p>Aktives Reifendruckkontrollsystem:</p>
                <p>· Permanente Ermittlung von Luftdruck und Temperatur</p>
                <p>· Dauerhafte Anzeige des Reifendrucks im Cockpit</p>
                <p>· Zukauf von Sensoren verpflichtend</p>
                <p>Passives Reifendruckkontrollsystem:</p>
                <p>· Druckverlusterfassung nur in Bewegung des Fahrzeugs</p>
                <p>· Druckverlust wird angezeigt, nicht aber der tatsächliche Druck des Reifens</p>
                <p>· Keine Mehrkosten</p>
                    </div>
    </div>
</div>

<div class="tire-information-overlay">
    <div class="tire-information-box standard-filter" data-information="breite">
        <div class="tire-information-box-title">
            reifenbreite            <img class="tire-information-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
        </div>
        <div class="tire-information-box-content">
            Die Reifenbreite gibt die Breite des Reifens in Millimetern an.        </div>
        <div class="tire-information-box-media">
                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/reifen/info/Reifen-Breite.jpg" alt="reifenbreite">
                    </div>
    </div>
    <div class="tire-information-box standard-filter" data-information="hoehe">
        <div class="tire-information-box-title">
            Reifenhöhe            <img class="tire-information-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
        </div>
        <div class="tire-information-box-content">
            Die Reifenhöhe, auch als Querschnittsverhältnis bezeichnet, beschreibt das Höhen-Breiten-Verhältnis des Reifens in Prozent.        </div>
        <div class="tire-information-box-media">
                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/reifen/info/Reifenquerschnitt.jpg" alt="Reifenhöhe">
                    </div>
    </div>
    <div class="tire-information-box standard-filter" data-information="zoll">
        <div class="tire-information-box-title">
            Zoll            <img class="tire-information-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
        </div>
        <div class="tire-information-box-content">
            Der Felgendurchmesser ist in Zoll angegeben und stimmt mit dem Innendurchmesser des Reifens überein.        </div>
        <div class="tire-information-box-media">
                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/reifen/info/Reifen-Zoll.jpg" alt="Zoll">
                    </div>
    </div>
    <div class="tire-information-box standard-filter" data-information="loadindex">
        <div class="tire-information-box-title">
            Traglastindex            <img class="tire-information-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
        </div>
        <div class="tire-information-box-content">
            Der Lastindex, auch Tragfähigkeitsindex genannt, beschreibt die Belastbarkeit des Reifens. Der Index stellt dabei eine Kennziffer dar, die jeweils einer Radlast in Kilogramm zugeordnet wird.        </div>
        <div class="tire-information-box-media">
                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/reifen/info/Tragfaehigkeitsindex.jpg" alt="Traglastindex">
                    </div>
    </div>
    <div class="tire-information-box standard-filter" data-information="speedindex">
        <div class="tire-information-box-title">
            Geschwindigkeitsindex            <img class="tire-information-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
        </div>
        <div class="tire-information-box-content">
            Bei dem Geschwindigkeitsindex handelt es sich um Maximalgeschwindigkeit, für die die Reifen ausgelegt sind. Dargestellt wird dieser Index als Buchstabenkürzel am Ende der Reifenkennung.        </div>
        <div class="tire-information-box-media">
                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/reifen/info/Geschwindigkeitsindex.jpg" alt="Geschwindigkeitsindex">
                    </div>
    </div>
    <div class="tire-information-box more-filter" data-information="ms">
        <div class="tire-information-box-title">
            M+S            <img class="tire-information-overlay-back" alt="schließen" src="data:image/png;base64,...">
            <img class="tire-information-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
        </div>
        <div class="tire-information-box-content">
            "M+S" steht für "Matsch und Schnee" und ist eine Reifenkennzeichnung für Winterreifen. Reifen mit dieser Kennzeichnung eignen sich entweder für winterliche Straßenverhältnisse oder haben eine Geländeeignung. Es bedeutet aber nicht, dass der Reifen über spezielle Wintereigenschaften verfügt, wie bei den geprüften Reifen mit dem Schneeflockensymbol.        </div>
        <div class="tire-information-box-media">
                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/reifen/info/MS.jpg" alt="M+S">
                    </div>
    </div>
    <div class="tire-information-box more-filter" data-information="3pmsf">
        <div class="tire-information-box-title">
            Schneeflockensymbol            <img class="tire-information-overlay-back" alt="schließen" src="data:image/png;base64,...">
            <img class="tire-information-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
        </div>
        <div class="tire-information-box-content">
            Das Schneeflockensymbol wird auch als 3PMSF-Symbol bezeichnet und steht für "Three-Peak Mountain Snowflake". Es zeigt einen Berg und eine Schneeflocke. Ab dem 1. Januar 2018 müssen neue Reifen dieses Symbol tragen, um als wintertauglich zu gelten. Egal, ob es sich um Ganzjahres- oder Winterreifen handelt, mit dieser Kennzeichnung ist im Winter der volle Versicherungsschutz gewährleistet.        </div>
        <div class="tire-information-box-media">
                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/reifen/info/Schneeflockensymbol.jpg" alt="Schneeflockensymbol">
                    </div>
    </div>
    <div class="tire-information-box more-filter" data-information="runflat">
        <div class="tire-information-box-title">
            Runflat            <img class="tire-information-overlay-back" alt="schließen" src="data:image/png;base64,...">
            <img class="tire-information-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
        </div>
        <div class="tire-information-box-content">
            Runflat-Reifen sind speziell entwickelte Reifen, die auch bei einer Reifenpanne für eine kurze Strecke fahrbar bleiben, ohne dass der Reifen sofort platzt. Sie haben verstärkte Seitenwände, die dem Gewicht des Fahrzeugs auch ohne Luft standhalten können.        </div>
        <div class="tire-information-box-media">
                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/reifen/info/Runflat.jpg" alt="Runflat">
                    </div>
    </div>
    <div class="tire-information-box more-filter" data-information="oe">
        <div class="tire-information-box-title">
            Reifen mit OE-Kennung            <img class="tire-information-overlay-back" alt="schließen" src="data:image/png;base64,...">
            <img class="tire-information-overlay-close" alt="schließen" src="data:image/svg+xml;base64,...">
        </div>
        <div class="tire-information-box-content">
            Die OE Kennung auf einem Reifen steht für "Original Equipment" Kennung und gibt an, dass dieser Reifen von einem Hersteller speziell für die Erstausrüstung eines bestimmten Fahrzeugmodells produziert wurde. Die OE-Kennung besteht aus einer Kombination von Buchstaben und Zahlen, die Informationen über die Größe, das Profil und die Tragfähigkeit des Reifens liefern. OE-Reifen können jedoch auch uneingeschränkt auf anderen Fahrzeugen verwendet werden.        </div>
        <div class="tire-information-box-media">
                            <img src="https://www.felgenshop.de/source/skin/default/img/fsv2/reifen/info/OE-Kennung.jpg" alt="Reifen mit OE-Kennung">
                    </div>
    </div>
</div>

<div class="mobile-filter-background"></div>

<script src="https://browser.sentry-cdn.com/7.44.2/bundle.tracing.min.js" integrity="sha384-CmO9kmtYvT9SLiSEn7uD4hNHOv+TM8He5Lqk7sh877bE9I7SeTFq/BQ21b2cw1s4" crossorigin="anonymous"></script>

<script>
    try {
        Sentry.init({
            dsn: "https://716b4c4ffdc14f81aab906854390fcad@sentry.df-automotive.de/8",
            release: "1826656a59d8c4b8c0df04497a40b75b39c18844",
            tracesSampleRate: 1.0,
                        environment: "production"
                    });

        Sentry.setContext("session", {
            session: "255ib2rvba7boaak1fcdjeb38t"
        });
    } catch (e) {}

</script>

<script src="https://www.felgenshop.de/source/skin/default//js/fsv2/reifen.js"></script>



<script id="tire-box-template" type="text/x-handlebars-template">
    <div class="col-xs-12 tire-box-container {{tireBoxData.tireBoxVisible}}" data-tire-box-position="{{tireBoxData.tireBoxPosition}}" itemtype="https://schema.org/Product" itemscope>
        <div class="tire-box">
            <div class="tire-box-padding">
                <div class="tire-badges">
                    <div class="tire-badge {{tireBoxData.tireBadgeShow}}" style="background-color: {{tireBoxData.tireBadgeColor}}">{{tireBoxData.tireBadgeText}}</div>
                    <div class="tire-badge express {{tireBoxData.tireBadgeExpress}}"><img alt="Express Versand" src="data:image/svg+xml;base64,..." /> Express</div>
                </div>
                <div class="row tire-box-mobile">
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img itemprop="image" alt="{{tireBoxData.article.article}}" class="tire-image" src="{{tireBoxData.article.image_url}}" />
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,..."/>
                                        <span class="cube">{{tireBoxData.article.wetgrip}}</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,..."/>
                                        <span class="cube">{{tireBoxData.article.rollingresistance}}</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-12 d-flex justify-content-center">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,..."/>
                                        <span class="cube">{{tireBoxData.article.rollingnoisedb}}</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-9">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="{{tireBoxData.wariManufacturerLogo}}" />
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <meta itemprop="productID" content="{{tireBoxData.article.article_id}}">
                                <span class="tire-article-name" itemprop="name">{{tireBoxData.article.article}}</span>
                                <meta itemprop="category" content="Fahrzeuge & Teile > Fahrzeugersatzteile & -zubehör > Kfz-Teile > Kfz-Räder > Felgen & Reifen für Kfz > Autoreifen">
                                <span class="tire-article-extra" itemprop="model">{{tireBoxData.article.article_extra}}</span>
                                <meta itemprop="model" content="{{tireBoxData.article.profil_desc}}">
                                <span itemprop="brand" itemscope itemtype="https://schema.org/Brand" class="d-none">
                                  <meta itemprop="name" content="{{tireBoxData.article.manufacturer}}"/>
                                </span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">{{tireBoxData.article.breite}}/{{tireBoxData.article.verhaeltnis}} R{{tireBoxData.article.zoll}} {{tireBoxData.article.traglastindex}}{{tireBoxData.article.geschwindigkeitsindex}}</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                <img alt="Winterreifen" class="tire-article-type-image {{tireBoxData.tireTypeWinter}}" src="data:image/svg+xml;base64,..." />
                                <img alt="Sommerreifen" class="tire-article-type-image {{tireBoxData.tireTypeSummer}}" src="data:image/svg+xml;base64,..." />
                                <img alt="Ganzjahresreifen" class="tire-article-type-image {{tireBoxData.tireTypeAllSeason}}" src="data:image/svg+xml;base64,..." />
                                <span class="tire-article-type {{tireBoxData.tireTypeWinter}}">Winterreifen</span>
                                <span class="tire-article-type {{tireBoxData.tireTypeSummer}}">Sommerreifen</span>
                                <span class="tire-article-type {{tireBoxData.tireTypeAllSeason}}">Ganzjahresreifen</span>
                            </div>
                            <div class="col-xs-12 tire-article-loadindex-margin">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">{{tireBoxData.article.traglastindex}}</div> ({{tireBoxData.traglastMax}} kg)</span>
                            </div>
                            <div class="col-xs-12">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">{{tireBoxData.article.geschwindigkeitsindex}}</div> (max. {{tireBoxData.geschwindigkeitMax}} km/h)</span>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-12">
                        <a itemprop="offers" itemtype="https://schema.org/AggregateOffer" itemscope href="{{tireBoxData.basketLink}}" class="fs-btn default green block raise ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,..." />
                            <span class="tire-buy-button-total-price">({{tireBoxData.totalPrice}})</span>
                            <span class="tire-buy-button-article-price">{{tireBoxData.vk_brutto}}</span>
                            <span class="tire-buy-button-text">4 Reifen je</span>

                            <meta itemprop="priceCurrency" content="EUR" />
                            <meta itemprop="lowPrice" content="{{tireBoxData.rawtotalPrice}}" />
                            <meta itemprop="price" content="{{tireBoxData.rawtotalPrice}}" />
                            <meta itemprop="availability" content="http://schema.org/InStock">
                            <meta itemprop="itemCondition" itemtype="http://schema.org/OfferItemCondition" content="http://schema.org/NewCondition"/>
                        </a>
                    </div>
                </div>
                <div class="row tire-box-desktop">
                    <div class="col-xs-3 col-md-2 col-lg-3 col-xl-2">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="{{tireBoxData.article.article}}" class="tire-image" src="{{tireBoxData.article.image_url}}" />
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-3">
                        <div class="row">
                            <div class="col-xs-12">
                                <img alt="reifenhersteller" class="tire-manufacturer-logo" src="{{tireBoxData.wariManufacturerLogo}}" />
                            </div>
                            <div class="col-xs-12 tire-article-name-margin">
                                <span class="tire-article-name">{{tireBoxData.article.article}}</span>
                                <span class="tire-article-extra">{{tireBoxData.article.article_extra}}</span>
                            </div>
                            <div class="col-xs-12 tire-article-size-margin">
                                <span class="tire-article-size">{{tireBoxData.article.breite}}/{{tireBoxData.article.verhaeltnis}} R{{tireBoxData.article.zoll}} {{tireBoxData.article.traglastindex}}{{tireBoxData.article.geschwindigkeitsindex}}</span>
                            </div>
                            <div class="col-xs-12 tire-article-type-margin d-flex align-items-center">
                                {{#if tireBoxData.tireTypeWinter}}
                                <img alt="Winterreifen" class="tire-article-type-image {{tireBoxData.tireTypeWinter}}" src="data:image/svg+xml;base64,..." />
                                <span class="tire-article-type {{tireBoxData.tireTypeWinter}}">Winterreifen</span>
                                {{/if}}
                                {{#if tireBoxData.tireTypeSummer}}
                                <img alt="Sommerreifen" class="tire-article-type-image {{tireBoxData.tireTypeSummer}}" src="data:image/svg+xml;base64,..." />
                                <span class="tire-article-type {{tireBoxData.tireTypeSummer}}">Sommerreifen</span>
                                {{/if}}
                                {{#if tireBoxData.tireTypeAllSeason}}
                                <img alt="Ganzjahresreifen" class="tire-article-type-image {{tireBoxData.tireTypeAllSeason}}" src="data:image/svg+xml;base64,..." />
                                <span class="tire-article-type {{tireBoxData.tireTypeAllSeason}}">Ganzjahresreifen</span>
                                {{/if}}
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-4 col-md-5 col-lg-4">
                        <div class="row">
                            <div class="col-xs-5">
                                <span class="tire-article-loadindex-title">Traglast:</span>
                                <span class="tire-article-loadindex"><div class="bold">{{tireBoxData.article.traglastindex}}</div> ({{tireBoxData.traglastMax}} kg)</span>
                            </div>
                            <div class="col-xs-7">
                                <span class="tire-article-speedindex-title">Geschwindigkeit:</span>
                                <span class="tire-article-speedindex"><div class="bold">{{tireBoxData.article.geschwindigkeitsindex}}</div> (max. {{tireBoxData.geschwindigkeitMax}} km/h)</span>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="wet-grip detail" title="Nasshaftung">
                                        <img alt="Nasshaftung" src="data:image/svg+xml;base64,..."/>
                                        <span class="cube">{{tireBoxData.article.wetgrip}}</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="fuel detail" title="Kraftstoffeffizienz">
                                        <img alt="Kraftstoffeffizienz" src="data:image/svg+xml;base64,..."/>
                                        <span class="cube">{{tireBoxData.article.rollingresistance}}</span>
                                    </div>
                                </div>
                            </div>
                            <div class="col-xs-4 col-sm-3">
                                <div class="tire-attributes">
                                    <div class="noise detail" title="Rollgeräusch">
                                        <img alt="Rollgeräusch" src="data:image/svg+xml;base64,..."/>
                                        <span class="cube">{{tireBoxData.article.rollingnoisedb}}</span>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                    <div class="col-xs-2 height-100-percent col-xl-offset-1">
                        <a href="{{tireBoxData.basketLink}}" class="fs-btn default green block ripple z-depth klaviyo-add-article-with-tire-only tire-buy-button">
                            <img alt="Reifen kaufen" class="tire-buy-button-basket-icon" src="data:image/svg+xml;base64,..." />
                            <span class="tire-buy-button-text">4 Reifen je</span>
                            <span class="tire-buy-button-article-price">{{tireBoxData.vk_brutto}}</span>
                            <span class="tire-buy-button-total-price">({{tireBoxData.totalPrice}})</span>
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </div>
</script>
    </div>
    <div class="fs-footer clearfix">
      <div class="container-fluid">
        <div class="footer clearfix">
          <div class="row">
            <div class="newsletter-social clearfix">
              <div class="container">
                                  <div class="col-xs-12 xol-sm-12 col-md-12 col-lg-4">
                  <div class="social-media">
                                      <a target="_blank" href="https://www.facebook.com/df.automotive/" class="social-btn fb">
                      <svg width="26" height="26">
                        <image xlink:href="data:image/svg+xml;base64,..." src="data:image/png;base64,..." width="26" height="28" alt="facebook">
                      </svg>
                    </a>
                                                        <a target="_blank" href="https://www.instagram.com/dfautomotive/" class="social-btn instagram">
                      <svg width="26" height="26">
                        <image xlink:href="data:image/svg+xml;base64,..." src="data:image/png;base64,..." width="26" height="28" alt="instagram">
                      </svg>
                    </a>
                                                        <a target="_blank" href="https://www.youtube.com/@DFAutomotiveTV" class="social-btn yt">
                      <svg width="26" height="26">
                        <image xlink:href="data:image/svg+xml;base64,..." src="data:image/png;base64,..." width="26" height="28" alt="youtube">
                      </svg>
                    </a>
                                                        <a target="_blank" href="https://www.pinterest.de/dfautomotive/" class="social-btn pinterest">
                      <svg width="26" height="26">
                        <image xlink:href="data:image/svg+xml;base64,..." src="data:image/png;base64,..." width="26" height="28" alt="pinterest">
                      </svg>
                    </a>
                                    </div>
                </div>
              </div>
            </div>
          </div>
          <div class="row">
            <div class="container">
              <div class="row">
                <div class="metanav clearfix">
                  <div class="col-xs-12 col-sm-6 col-md-3">
                    <ul class="df-list">
                      <li class="title">
                        <a href="https://www.df-automotive.de" target="_blank">DF Automotive</a>
                      </li>
                                                                                                                                          <li>
                                <a href="https://www.df-automotive.de/unternehmen/ueber-uns/" target="_blank">Über uns</a>
                              </li>
                                                                                                                                                                              <li>
                                <a href="https://www.df-automotive.de/karriere/df-als-arbeitgeber/" target="_blank">Karriere</a>
                              </li>
                                                                                                                                                                              <li>
                                <a href="https://www.felgenshop.de/impressum/">Impressum</a>
                              </li>
                                                                                                                                                                              <li>
                                <a href="https://www.felgenshop.de/kontakt/">Kontakt</a>
                              </li>
                                                                                                                                                                              <li>
                                <a href="https://www.velonity-b2b.com" target="_blank">B2B</a>
                              </li>
                                                                                                        </ul>
                  </div>
                  <div class="col-xs-12 col-sm-6 col-md-3">
                    <ul class="info-list">
                      <li class="title">Informationen</li>
                                                                                              <li>
                            <a href="https://www.felgenshop.de/meinebestellungen/">Meine Bestellungen</a>
                          </li>
                                                                                                <li>
                            <a href="https://www.felgenshop.de/retouren/">Retouren
</a>
                          </li>
                                                                                                <li>
                            <a href="https://www.felgenshop.de/faq/">FAQ</a>
                          </li>
                                                                                                <li>
                            <a href="https://www.felgenshop.de/datenschutz/">Datenschutz</a>
                          </li>
                                                                                                <li>
                            <a href="https://www.felgenshop.de/agb/">AGB</a>
                          </li>
                                                                  </ul>
                  </div>
                  <div class="col-xs-12 col-sm-6 col-md-3">
                    <ul class="trusted-list">
                      <li class="title">
                                                     <!-- <a href="https://www.trustedshops.com/shop/certificate.php?shop_id=X29D756F9C95ACDD6CBBE4712BEE04289&amp;tb" target="_blank" title="Wir sind geprüft"></a> -->
                              Trusted Shop                                                </li>
                      <li>
                        <img alt="check-icon" class="icon" data-src="data:image/png;base64,...">
                        Schnelle Lieferzeiten                      </li>
                      <li>
                        <img alt="check-icon" class="icon" data-src="data:image/png;base64,...">
                        Käuferschutz                      </li>
                                              <li>
                        <img alt="check-icon" class="icon" data-src="data:image/png;base64,...">
                        Bestellung über SSL                      </li>
                      <li>
                        <img alt="check-icon" class="icon" data-src="data:image/png;base64,...">
                        Telefon Support                      </li>
                    </ul>
                  </div>
                  <div class="col-xs-12 col-sm-6 col-md-3">
                      <ul>
                                                  <li class="title">Service &amp; Shops</li>
                          <li>
                            <span><a href="http://www.sportfahrwerk-billiger.de">Sportfahrwerk Shop</a></span>
                          </li>
                          <li>
                            <span><a href="http://www.sportauspuff-billiger.de">Sportauspuff Shop</a></span>
                          </li>
                          <br>
                                                <li>
                          <span><a href="mailto:service@felgenshop.de"> service@felgenshop.de</a></span>
                        </li>
                        <li>
                          <span><a href="tel:0461 430415-20"> 0461 430415-20</a></span>
                        </li>
                        <li>
                          <span>Mo-Fr 9-12 Uhr / 14-18 Uhr</span>
                        </li>
                      </ul>
                  </div>
                </div>
              </div>
            </div>
          </div>
          <div class="row">
            <div class="container">
              <div class="payment-ship">
                <div class="row">
                  <div class="col-xs-12 col-sm-12 col-md-6">
                    <div class="payments">
                      <span class="title">Zahlungsmethoden</span>
                      <div class="paymentmethods clearfix">
                                                                              <!-- Shop mit Finanzierung Reifen -->
                                                            <div class="item">
                                    <img class="" width="125" height="62.5" data-src="/source/skin/default/img/footer/paypal.png" alt="paypal">
                                </div>
                                                                                        <div class="item">
                                    <img class="" width="125" height="62.5" data-src="/source/skin/default/img/footer/klarna.png" alt="klarna">
                                </div>
                                                                                                                    <div class="item">
                                    <img class="" width="125" height="62.5" data-src="/source/skin/default/img/footer/vorkasse_de.png" alt="vorkasse">
                                </div>
                                                                                                                                                                                                                                      <div class="item">
                                  <img class="" width="125" height="62.5" data-src="/source/skin/default/img/footer/amazon_pay.png" alt="amazon-payments">
                                </div>
                                                          <div class="item">
                              <img class="" width="125" height="62.5" data-src="/source/skin/default/img/footer/kreditkartenzahlung.png" alt="kreditkartenzahlung">
                            </div>
                                                        <div class="item">
                                <img class="" width="125" height="62.5" data-src="/source/skin/default/img/footer/kreditkartenzahlung.png" alt="mastercard-visa">
                            </div>
                            <!-- !Shop mit Finanzierung Reifen -->
                                                    <!-- !Shop ohne Finanzierung Reifen -->
                                              </div>
                    </div>
                  </div>
                  <div class="col-xs-12 col-sm-12 col-md-3">
                    <div class="ship">
                      <span class="title">Versand</span>
                                                                        <div class="shipmethods clearfix">
                            <div class="item">
                              <img class="" width="125" height="62.5" data-src="/source/skin/default/img/footer/dhl.png" alt="dhl">
                            </div>
                            <div class="item">
                              <img class="" width="125" height="62.5" data-src="/source/skin/default/img/footer/gls.png" alt="gls">
                            </div>
                            <div class="item">
                                <img class="" width="125" height="62.5" data-src="/source/skin/default/img/footer/dpd.png" alt="dpd">
                            </div>
                          </div>
                                                                  </div>
                  </div>
                    <div class="col-xs-12 col-sm-12 col-md-3 ">
                        <div class="award">
                            <span class="title">Ausgezeichnet</span>
                            <div class="awardmethods clearfix">
                                <div class="item">
                                    <img class="" width="75" height="105" data-src="/source/skin/default/img/CoBi_TopShop2023_Logo_6Jahre.svg" alt="Computer Bild 6 Jahre Top Shop">
                                </div>
                                <div class="item">
                                    <img class="" width="75" height="105" data-src="/source/skin/default/img/top1002020.png" alt="Top100 2020">
                                </div>
                                <div class="item">
                                    <img class="" width="75" height="105" data-src="/source/skin/default/img/topjob2022.png" alt="TopJob 2022">
                                </div>
                                <div class="item">
                                                                                                                  <img class="" width="75" height="75" data-src="/source/skin/default/img/approved-online-shop.webp" alt="continental">
                                                                                                          </div>
                                <div class="item">
                                    <a href="https://www.felgenshop.de/blog/df-automotive-ist-klimaneutral/">
                                        <img style="max-width: 209px;" class="" width="209" height="45" data-src="https://ministatic.df-automotive.de/climatepartner/v2018_DE_C_20551-2303-1001.png" alt="Klimaneutral">
                                    </a>
                                </div>
                            </div>
                        </div>
                    </div>
                </div>
              </div>
            </div>
          </div>
          <div class="row border">
            <div class="container">
              <div class="row d-flex justify-content-center">
                <div class="copyright clearfix">
                  Copyright 2023 <span>DF Automotive GmbH</span>
                </div>
              </div>
            </div>
          </div>
        </div>
      </div>
    </div>
    <div class="fs-cookie-bar container-fluid d-none" style="display: block;">
      <div class="row">
        <div class="container">
          <span>
            Um unsere Webseite für Sie optimal zu gestalten und fortlaufend verbessern zu können, verwenden wir Cookies. Weitere Informationen zu Cookies erhalten Sie in unserer <a href="https://www.felgenshop.de/datenschutz/">Datenschutzerklärung</a>
            <button id="fs-hint" class="fs-btn default smaller green z-depth-1 raise ripple">OK, verstanden</button>
          </span>
        </div>
      </div>
    </div>
  </div>
 
<!-- Cookie Opt In-->
<div data-nosnippet="" class="keksbox-overlay-layer d-none"></div>
<div data-nosnippet="" class="keksbox-overlay d-none">
  <div class="container-fluid keksbox-flex">
    <div class="row">
      <div class="col-xs-12 mb-3">
        <div class="keksbox-headline-position">
          <img class="keksbox-headline-img" width="32px" height="32px" alt="icon-cookie-tire-bitten" src="/source/skin/default/img/fsv2/icon/icon-cookie-tire-bitten.svg">
          <span class="keksbox-headline">Wir verwenden Cookies</span>
        </div>
      </div>
      <div class="col-xs-12 mb-3">
        <span class="keksbox-text">Wir nutzen auf unserer Website Cookies. Einige von ihnen sind essenziell, während andere uns helfen, diese Website und Ihre Erfahrung zu verbessern.</span>
        <span class="keksbox-text keksbox-settings-text">Mit einem Klick auf "Alle akzeptieren" stimmen Sie der Verwendung von Cookies und anderen Technologien zur Verarbeitung Ihrer Daten zu. Mehr dazu in unserer <a href="/datenschutz">Datenschutzerklärung</a>.</span>
      </div>
      <div class="col-xs-12 keksbox-settings-container">
        <div class="row mb-3 keksbox-checkbox-padding">
          <div class="col-xs-5 keksbox-checkbox-position">
            <input id="checkbox-essenziell" type="checkbox" class="d-none" checked="" disabled="">
            <img data-id="checkbox-essenziell" data-keks-name="df-cookie-essenziell" alt="checkbox-essenziell" src="/source/skin/default/img/fsv2/icon/icon-checkbox.svg" class="keksbox-checkbox disabled checked">
            <span class="keksbox-checkbox-text">Essenziell</span>
          </div>
          <div class="col-xs-7 keksbox-checkbox-position">
            <input id="checkbox-marketing" type="checkbox" class="d-none">
            <img data-id="checkbox-marketing" data-keks-name="df-cookie-marketing" alt="checkbox-marketing" src="/source/skin/default/img/fsv2/icon/icon-checkbox-outline.svg" class="keksbox-checkbox">
            <span class="keksbox-checkbox-text">Marketing</span>
          </div>
        </div>
        <div class="row keksbox-checkbox-padding">
          <div class="col-xs-5 keksbox-checkbox-position">
            <input id="checkbox-statistiken" type="checkbox" class="d-none">
            <img data-id="checkbox-statistiken" data-keks-name="df-cookie-statistiken" alt="checkbox-statistiken" src="/source/skin/default/img/fsv2/icon/icon-checkbox-outline.svg" class="keksbox-checkbox">
            <span class="keksbox-checkbox-text">Statistiken</span>
          </div>
          <div class="col-xs-7 keksbox-checkbox-position">
            <input id="checkbox-externe-medien" type="checkbox" class="d-none">
            <img data-id="checkbox-externe-medien" data-keks-name="df-cookie-externe-medien" alt="checkbox-externe-medien" src="/source/skin/default/img/fsv2/icon/icon-checkbox-outline.svg" class="keksbox-checkbox">
            <span class="keksbox-checkbox-text">Externe Medien</span>
          </div>
        </div>
      </div>
      <div class="col-xs-12 mb-2">
        <button id="accept-all-kekse" class="fs-btn default block-big grey">Alle akzeptieren</button>
      </div>
      <div class="col-xs-12">
        <button id="keksbox-settings" class="fs-btn default block-big grey line-height-30 einstellungen keksbox-settings">Einstellungen</button>
        <button id="keksbox-save" class="fs-btn default block-big grey line-height-30 d-none keksbox-settings">Auswahl akzeptieren</button>
      </div>
      <div class="col-xs-12 keksbox-footer">
        <a class="keksbox-footer-item" href="/datenschutz">Datenschutzerklärung</a>
        <span class="keksbox-footer-pipe">|</span>
        <a class="keksbox-footer-item" href="/impressum">Impressum</a>
      </div>
    </div>
  </div>
</div>

  <input type="checkbox" name="mobile-fhz" id="mobile-fhz">
<div class="hsn-tsn-overlay fhz-choice-wrap mobile clearfix">
  <label for="mobile-fhz" class="dismiss fs-btn light toggle dismiss-btn">
    <i class="icon">
      <img alt="close" src="data:image/svg+xml;base64,...">
    </i>
    Fenster schließen  </label>
  <div class="fhz-tabs tabs-choice-mobile smaller step-main">
    <div class="tabs-inner">
        <p class="title">
                            <strong>Fahrzeug</strong>auswahl                    </p>
                <ul class="tabs clearfix">
          <li data-activates="fhz" class="active pmd-ripple-effect">Fahrzeug</li>
          <li data-activates="hsntsn" class="pmd-ripple-effect">
              mit Fahrzeugschein                        </li>
        </ul>
                <div class="tab" data-target="fhz">
          <div class="chosen-wrap">
                             <div class="select-wrap first">
<select id="overlay_pkw_hersteller" tabindex="-1" class="select2-hidden-accessible" aria-hidden="true"><option value="">Hersteller wählen</option><option value="96">Aiways</option><option value="28">Alfa Romeo</option><option value="66">Aston Martin</option><option value="3">Audi</option><option value="58">Austin</option><option value="106">B-ON</option><option value="109">Baic</option><option value="70">Bentley</option><option value="4">BMW</option><option value="80">BMW Alpina</option><option value="110">Borgward</option><option value="108">Bugatti</option><option value="105">BYD</option><option value="61">Cadillac</option><option value="37">Chevrolet</option><option value="18">Chrysler</option><option value="36">Citroen</option><option value="55">Corvette</option><option value="91">Cupra</option><option value="56">Dacia</option><option value="38">Daewoo</option><option value="62">Daihatsu</option><option value="78">DeLorean</option><option value="104">Dethleffs</option><option value="98">DFSK</option><option value="63">Dodge</option><option value="90">DS Automobiles</option><option value="39">Ferrari</option><option value="16">Fiat</option><option value="85">Fisker</option><option value="5">Ford</option><option value="100">Genesis</option><option value="71">Holden</option><option value="11">Honda</option><option value="40">Hummer</option><option value="22">Hyundai</option><option value="107">Ineos</option><option value="67">Infiniti</option><option value="72">Isuzu</option><option value="93">Iveco</option><option value="41">Jaguar</option><option value="42">Jeep</option><option value="43">Kia</option><option value="88">KTM</option><option value="73">Lada</option><option value="68">Lamborghini</option><option value="44">Lancia</option><option value="45">Land Rover</option><option value="111">LEVC</option><option value="13">Lexus</option><option value="46">Lotus</option><option value="99">Lynk &amp; Co</option><option value="47">Maserati</option><option value="87">Maybach</option><option value="19">Mazda</option><option value="84">McLaren</option><option value="8">Mercedes</option><option value="48">MG</option><option value="49">Mini</option><option value="21">Mitsubishi</option><option value="102">Nio</option><option value="20">Nissan</option><option value="94">NSU</option><option value="15">Opel</option><option value="26">Peugeot</option><option value="103">Pössl</option><option value="95">Polestar</option><option value="75">Pontiac</option><option value="7">Porsche</option><option value="65">Proton</option><option value="50">Renault</option><option value="92">Renault Alpine</option><option value="89">Rolls Royce</option><option value="51">Rover</option><option value="17">Saab</option><option value="76">Saturn</option><option value="77">Scion</option><option value="10">Seat</option><option value="9">Skoda</option><option value="23">Smart</option><option value="64">Ssangyong</option><option value="52">Subaru</option><option value="97">Sunbeam</option><option value="25">Suzuki</option><option value="86">Tesla</option><option value="12">Toyota</option><option value="53">Trabant</option><option value="1">Volkswagen (VW)</option><option value="24">Volvo</option></select><span class="select2 select2-container select2-container--default" dir="ltr" style="width: 100%;"><span class="selection"><span class="select2-selection select2-selection--single" role="combobox" aria-haspopup="true" aria-expanded="false" tabindex="0" aria-labelledby="select2-overlay_pkw_hersteller-container"><span class="select2-selection__rendered" id="select2-overlay_pkw_hersteller-container" title="Hersteller wählen">Hersteller wählen</span><span class="select2-selection__arrow" role="presentation"><b role="presentation"></b></span></span></span><span class="dropdown-wrapper" aria-hidden="true"></span></span>
</div>
               <div class="select-wrap ">
    <select id="overlay_pkw_baugruppe" disabled="" tabindex="-1" class="select2-hidden-accessible" aria-hidden="true"><option value="">Baugruppe wählen</option></select><span class="select2 select2-container select2-container--default select2-container--disabled" dir="ltr" style="width: 100%;"><span class="selection"><span class="select2-selection select2-selection--single" role="combobox" aria-haspopup="true" aria-expanded="false" tabindex="-1" aria-labelledby="select2-overlay_pkw_baugruppe-container"><span class="select2-selection__rendered" id="select2-overlay_pkw_baugruppe-container" title="Baugruppe wählen">Baugruppe wählen</span><span class="select2-selection__arrow" role="presentation"><b role="presentation"></b></span></span></span><span class="dropdown-wrapper" aria-hidden="true"></span></span>
</div>
              <script>
    var baujahr_translate ="(Baujahr)";
</script>
<div class="select-wrap">
<select id="overlay_pkw_modell" class="show_baujahr select2-hidden-accessible" disabled="" tabindex="-1" aria-hidden="true"><option value="">Modell wählen</option></select><span class="select2 select2-container select2-container--default select2-container--disabled" dir="ltr" style="width: 100%;"><span class="selection"><span class="select2-selection select2-selection--single" role="combobox" aria-haspopup="true" aria-expanded="false" tabindex="-1" aria-labelledby="select2-overlay_pkw_modell-container"><span class="select2-selection__rendered" id="select2-overlay_pkw_modell-container" title="Modell wählen">Modell wählen</span><span class="select2-selection__arrow" role="presentation"><b role="presentation"></b></span></span></span><span class="dropdown-wrapper" aria-hidden="true"></span></span>
</div>              <div class="select-wrap">
<select id="overlay_pkw_motor" disabled="" tabindex="-1" class="select2-hidden-accessible" aria-hidden="true"><option value="">Motor wählen</option></select><span class="select2 select2-container select2-container--default select2-container--disabled" dir="ltr" style="width: 100%;"><span class="selection"><span class="select2-selection select2-selection--single" role="combobox" aria-haspopup="true" aria-expanded="false" tabindex="-1" aria-labelledby="select2-overlay_pkw_motor-container"><span class="select2-selection__rendered" id="select2-overlay_pkw_motor-container" title="Motor wählen">Motor wählen</span><span class="select2-selection__arrow" role="presentation"><b role="presentation"></b></span></span></span><span class="dropdown-wrapper" aria-hidden="true"></span></span>
</div>
                            <div class="fhz-reset">
                                  
                  <div class="btn-wrap">
                                          <a href="alufelgen/#!felgenfilter/sortiert=empfehlung" class="fs-btn default lightgrey z-depth-1 raise ripple">Ohne Fahrzeug suchen</a>
                                                          </div>
                              </div>
          </div>
        </div>
                    <div class="tab" data-target="hsntsn">
                <!-- <p class="divider"><strong>Eingabe via HSN / TSN</strong></p> -->
                                <form class="hsntsn_form row clearfix" name="hsntsn_form" method="post" enctype="multipart/form-data" action="#">
                                                                <div class="col-xs-12 col-sm-6">
                            <input class="hsninput" name="hsn" type="text" maxlength="4" placeholder="HSN">
                        </div>
                        <div class="col-xs-12 col-sm-6 mb-3">
                            <input class="tsninput" name="tsn" type="text" maxlength="3" placeholder="TSN">
                        </div>
                                        <div class="col-xs-12">
                        <small class="hsn-tsn-hint">Die HSN und TSN finden Sie in Ihrem Fahrzeugschein</small>
                    </div>
                </form>
                <div class="hsn-tsn-info clearfix mt-0">
                      <span class="hsn-tsn-video play-yt" data-target=".fs-video-box.hsntsnvid">
                        <small class="vid mt-0" data-target=".fs-video-box.hsntsnvid">
                          <i class="icon">
                            <img alt="icon-linkto" src="...">
                          </i>
                          Zum Erklärvideo                        </small>
                      </span>
                </div>
                <div class="col-12 alert alert-warning error-msg"><p></p></div>
                <div class="tab-slideOut" style="display: none;">
                    <div class="slideOut-result">
                        <div class="slideOut-single-result">
                            <strong class="text-uppercase">Marke</strong>
                            <p class="tab-slideOut-hrst"></p>
                            <strong class="text-uppercase">Modell</strong>
                            <p class="tab-slideOut-model"></p>
                            <strong class="text-uppercase">Motor</strong>
                            <p class="tab-slideOut-eng"></p>
                            <input class="slideOut-find-btn col-xs-8 col-xs-offset-2 fs-btn default green z-depth-1 raise ripple" type="submit" onclick="" value="Fahrzeug finden">
                            <p class="col-xs-12 wrong-result">Nicht dein Fahrzeug? Hier manuell wählen</p>
                        </div>
                        <div class="slideOut-multi-result">
                            <p class="results-heading"></p>
                            <ul class="results-list">
                                <p class="wrong-result">Ist dein Fahrzeug nicht dabei? Hier manuell wählen</p>
                            </ul>
                        </div>
                    </div>
                </div>
            </div>
            </div>
  </div>
    <!-- STEP LOADING -->
<div class="fhz-tabs tabs-choice-mobile smaller step-loading hide-step">
    <div class="tabs-inner tab-full-height-width d-flex justify-content-center align-items-center">
        <div class="row step-loading-position">
            <div class="col-xs-12 d-flex justify-content-center mb-5">
                <div class="spinning-tire-loading">
                    <i class="icon">
                        <img src="data:image/svg+xml;base64,...">
                    </i>
                </div>
            </div>
            <div class="col-xs-12 d-flex justify-content-center step-loading-text-desktop">
                <div class="text-info-format">Bitte warten - Ihr Fahrzeugschein wird analysiert</div>
            </div>
            <div class="col-xs-12 d-flex justify-content-center step-loading-text-mobile">
                <div class="text-info-format">Bitte warten</div>
            </div>
            <div class="col-xs-12 d-flex justify-content-center step-loading-text-mobile">
                <div class="text-info-format">-</div>
            </div>
            <div class="col-xs-12 d-flex justify-content-center step-loading-text-mobile">
                <div class="text-info-format">Ihr Fahrzeugschein wird analysiert</div>
            </div>
        </div>
    </div>
</div>

<!-- STEP NOT FOUND -->
<!--
    id "add-new-photo"     "Neues Foto hochladen" Funktion müsste auf diesen Button gelegt werden
-->
<div class="fhz-tabs tabs-choice-mobile smaller step-no-result hide-step">
    <div class="tabs-inner tab-full-height-width d-flex justify-content-center align-items-center">
        <div class="row step-loading-position">
            <div class="col-xs-12 d-flex justify-content-center mb-5">
                <!-- input style="display: none;" id="add-new-photo" type="file"/> -->
                <label class="fs-btn default green z-depth-1 raise ripple automatic-recognition" for="automatic-recognition-file"><i class="icon"><img src="data:image/svg+xml;base64,..."></i>Neues Foto hochladen</label>
            </div>
            <div class="col-xs-12 d-flex justify-content-center">
                <div class="text-info-format">Leider konnte Ihr Fahrzeugschein nicht erkannt werden</div>
            </div>
        </div>
    </div>
</div>

<!-- STEP MEHRERE ERGEBNISSE -->
<!--
    id "recognition-result-hsn"     Ausgelesene HSN einfügen
    id "recognition-result-tsn"     Ausgelesene TSN einfügen
    id "recognition-results"        Bei mehreren Treffern müssen hier die Ergebnisse eingefügt werden
-->
<div class="fhz-tabs tabs-choice-mobile smaller step-recognition-result hide-step">
    <div class="tabs-inner d-flex justify-content-center align-items-center">
        <label for="mobile-fhz" class="recognition-result-dismiss dismiss toggle fs-btn d-none d-md-block">
            <i class="icon">
                <img src="data:image/svg+xml;base64,...">
            </i>
        </label>
        <div class="row step-loading-position">
            <div class="col-xs-12 d-flex justify-content-center mb-5">
                <div class="font-size-16 d-inline recognition-result-info-text-width">
                    Es wurden folgende Ergebnisse ermittelt:
                </div>
            </div>
            <div class="col-xs-12 d-flex justify-content-center mb-5">
                <div class="text-info-format font-size-16" id="recognition-results"></div>
            </div>
            <div class="col-xs-12 d-flex justify-content-center">
                <!-- input style="display: none;" id="add-new-photo" type="file"/> -->
                <label class="fs-btn default green z-depth-1 raise ripple" for="automatic-recognition-file"><i class="icon"><img src="data:image/svg+xml;base64,..."></i>Nicht Ihr Fahrzeug?</label>
            </div>
        </div>
    </div>
</div>

<!-- STEP ERKENNUNGSHINWEIS -->
<div class="fhz-tabs tabs-choice-mobile smaller step-recognition-note scale-down-0-8 hide-step">
    <div class="tabs-inner tab-full-height-width d-flex justify-content-center align-items-center">
        <div class="row step-loading-position">
            <div class="col-xs-12">
                <div class="row">
                    <div class="col-xs-12 d-flex justify-content-center mb-2">
                        <span class="recognition-note-text-right">So sollte Ihr Foto aussehen</span>
                    </div>
                    <div class="col-xs-12 d-flex justify-content-center mb-5">
                                                    <img class="image-right" data-src="/source/skin/default/img/fahrzeugscheinanalyse/richtig.webp" alt="Foto richtig">
                                            </div>
                    <div class="col-xs-12 d-flex justify-content-center mb-2">
                        <span class="recognition-note-text-wrong">So kann Ihr Foto nicht erkannt werden</span>
                    </div>
                    <div class="col-xs-12 d-flex justify-content-center mb-5">
                        <div class="row">
                            <div class="col-xs-6">
                                                              <img class="image-wrong" data-src="/source/skin/default/img/fahrzeugscheinanalyse/falsch1.webp" alt="Foto falsch">
                                                          </div>
                            <div class="col-xs-6">
                                                              <img class="image-wrong" data-src="/source/skin/default/img/fahrzeugscheinanalyse/falsch2.webp" alt="Foto falsch">
                                                          </div>
                        </div>
                    </div>
                    <div class="col-xs-12 d-flex justify-content-center mb-3">
                        <div class="checkbox">
                            <label for="checkbox-datenschutz" class="fs-checkbox fs-checkbox-ripple-effect">
                                <input name="checkbox-datenschutz" id="checkbox-datenschutz" type="checkbox">
                                <span class="fs-checkbox-label">&nbsp;</span>
                            </label>
                        </div>
                        <div class="checkbox-text">
                            <span class="checkbox-datenschutz-text">
                                Ja ich habe die                                <a class="checkbox-datenschutz-text" href="#">Datenschutzvereinbarung</a>
                                gelesen und akzeptiere sie                            </span>
                        </div>
                    </div>
                    <div class="col-xs-12 d-flex justify-content-center">
                        <label class="fs-btn default green z-depth-1 raise ripple label-disabled" for="automatic-recognition-file"><i class="icon"><img src="data:image/svg+xml;base64,..."></i>Foto hochladen</label>
                    </div>
                </div>
            </div>
        </div>
    </div>
</div>
</div>

<label for="mobile-fhz" class="fhz-overlay toggle"></label>

<script>
  var res = document.createElement("link");
  res.rel = "stylesheet";
    res.href = "";
  res.type = 'text/css';
  document.head.appendChild(res);
</script>

<script type="text/javascript">

        
  
  
  _paq.push(['trackPageView']);
  _paq.push(['enableLinkTracking']);
  _paq.push(['appendToTrackingUrl',
          'pew=1892771946'
          ]);
  _paq.push(['enableHeartBeatTimer']);

  (function() {
    var u="/";
    _paq.push(['setUserId', '255ib2rvba7boaak1fcdjeb38t'])
    _paq.push(['setTrackerUrl', u+'pp/p.js']);
            _paq.push(['setSiteId', 2]);
        cookieIsset('df-cookie-statistiken', function () {
      var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
      g.type='text/javascript'; g.async=true; g.defer=true; g.src=u+'pj/p.js'; s.parentNode.insertBefore(g,s);
    });
  })();
</script>

    <script type="text/javascript">
        (function () {
            var _tsid = 'X29D756F9C95ACDD6CBBE4712BEE04289';
            _tsConfig = {
                'yOffset': '-30', /* offset from page bottom */
                'variant': 'default', /* default, reviews, custom, custom_reviews */
                'customElementId': '', /* required for variants custom and custom_reviews */
                'trustcardDirection': '', /* for custom variants: topRight, topLeft, bottomRight, bottomLeft */
                'customBadgeWidth': '', /* for custom variants: 40 - 90 (in pixels) */
                'customBadgeHeight': '', /* for custom variants: 40 - 90 (in pixels) */
                'disableResponsive': 'false', /* deactivate responsive behaviour */
                'disableTrustbadge': 'false' /* deactivate trustbadge */
            };
            var _ts = document.createElement('script');
            _ts.type = 'text/javascript';
            _ts.charset = 'utf-8';
            _ts.async = true;
            _ts.src = '//widgets.trustedshops.com/js/' + _tsid + '.js';
            var __ts = document.getElementsByTagName('script')[0];
            __ts.parentNode.insertBefore(_ts, __ts);
        })();
    </script>

<style>
  .debug-translated {
    animation: debug-translated-animation 2s infinite;
  }
  @keyframes debug-translated-animation {
    0%   {
      background-color: #000;
      color: #fff;
    }
    50%  {
      background-color: #fff;
      color: #000;
    }
    100%   {
      background-color: #000;
      color: #fff;
    }
  }
</style>
<script>
//Translation
var search = "​​​​";
function revealTranslations(){
    var elems = $('*').filter((i, e) => $(e).clone().children().remove().end().text().indexOf(search) > -1 );
    elems.addClass("debug-translated");
};
</script>

<script src="https://unpkg.com/@popperjs/core@2"></script>
<script src="https://unpkg.com/tippy.js@6"></script>
<script>var supercharges = supercharges || [];
var supercharged = (function (supercharge) { supercharges.push(supercharge); });</script>
<script src="/ext/js/supercharger/supercharger.min.js?v2"></script>
<script>supercharged(function(){

new SuperchargerBadge.Badge({
   targetXPath: ".fs-article-box",
   containsText: "Borbet N",
   position: "TopRight",
   width: `400px`,
   height: `{{height}}px`,
   margin: `20px 1px`,
   padding: `5px 5px`,
   backgroundColor: "rgba(0,0,0,0)",
   fontColor: "white",
   fontSize: "14px",
   text: "<svg onclick='$(`.campaignpopup-container`).show()' height='48px' width='48px' id='Ebene_1' xmlns='http://www.w3.org/2000/svg' viewBox='0 0 100 100'><defs><style>.cls-1{fill:#fff;}.cls-2{fill:#61ba00;}</style></defs><circle class='cls-2' cx='50' cy='50' r='50'/><path class='cls-1' d='m86.68,49c.19-.81.28-1.63.28-2.46,0-6.76-6-12.16-12.81-11.53-1.24-5.08-5.87-8.86-11.37-8.86s-10.13,3.79-11.37,8.86c-6.82-.64-12.81,4.77-12.81,11.53,0,.83.09,1.65.28,2.46-3.46,2.05-5.64,5.74-5.64,9.87,0,6.38,5.25,11.58,11.69,11.58h14.15v6.51l-3.49,5.58c-.61,1.23.28,2.67,1.65,2.67h11.07c1.37,0,2.26-1.44,1.65-2.67l-3.49-5.58v-6.51h14.15c6.45,0,11.69-5.19,11.69-11.58,0-4.13-2.18-7.82-5.63-9.87h0Zm-6.06,15.91h-35.69c-3.39,0-6.15-2.71-6.15-6.04,0-2.65,1.76-4.96,4.37-5.74l3.18-.96-1.51-2.96c-.45-.88-.68-1.78-.68-2.68,0-3.33,2.76-6.04,6.15-6.04.85,0,1.71.19,2.53.55l4.33,1.92-.52-5.24c0-3.33,2.76-6.04,6.15-6.04s6.15,2.71,6.14,6.16l-.51,5.12,4.33-1.92c4.11-1.81,8.68,1.32,8.68,5.49,0,.9-.23,1.8-.68,2.68l-1.51,2.96,3.18.96c2.61.78,4.37,3.09,4.37,5.74,0,3.33-2.76,6.04-6.15,6.04h0Z'/><path class='cls-1' d='m34.35,38.72h-8.7v8.5h-6.45v-8.5h-8.65v-6.1h8.65v-8.5h6.45v8.5h8.7v6.1Z'/></svg>",
   customCss: `{container} .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}`,
});
      })</script><style>
                .Supercharger-iau7lrwth {
                    pointer-events: none;
                    position: absolute;
                    margin: 0;
                    padding: 0;
                    left: 0;
                    top: 0;
                }
                .Supercharger-iau7lrwth .Supercharger-BadgeContainer {
                    position: relative;
                }
                .Supercharger-iau7lrwth .Supercharger-Badge {
                    pointer-events: auto; 
                    position: absolute;
                    background-color: rgba(0,0,0,0);
                    color: white;
                    font-size: 14px;
                    margin: 20px 1px;
                    padding: 5px 5px;
                    
                    
                    /* Vertical Center */
                    
                    
                    /* Horizontal Center */
                    
                      
                    /* Center */
                    
                    
                    /* Left */
                    
                    /* Right */
                    right:0;
                    
                    /* Top */
                    top:0;
                    /* Bottom */
                    
                }
            .Supercharger-iau7lrwth .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}</style>
<script>supercharged(function(){

new SuperchargerBadge.Badge({
   targetXPath: ".tyre-content .tyre-image",
   containsText: "NOKIAN",
   position: "TopRight",
   width: `400px`,
   height: `{{height}}px`,
   margin: `0px 0px`,
   padding: `0px 0px`,
   backgroundColor: "rgba(0,0,0,0)",
   fontColor: "white",
   fontSize: "14px",
   text: "<svg onclick='$(`.campaignpopup-container`).show()' id='Ebene_1' xmlns='http://www.w3.org/2000/svg' viewBox='0 0 100 100'><defs><style>.cls-1{fill:#fff;}.cls-2{fill:#61ba00;}</style></defs><circle class='cls-2' cx='50' cy='50' r='50'/><path class='cls-1' d='m86.68,49c.19-.81.28-1.63.28-2.46,0-6.76-6-12.16-12.81-11.53-1.24-5.08-5.87-8.86-11.37-8.86s-10.13,3.79-11.37,8.86c-6.82-.64-12.81,4.77-12.81,11.53,0,.83.09,1.65.28,2.46-3.46,2.05-5.64,5.74-5.64,9.87,0,6.38,5.25,11.58,11.69,11.58h14.15v6.51l-3.49,5.58c-.61,1.23.28,2.67,1.65,2.67h11.07c1.37,0,2.26-1.44,1.65-2.67l-3.49-5.58v-6.51h14.15c6.45,0,11.69-5.19,11.69-11.58,0-4.13-2.18-7.82-5.63-9.87h0Zm-6.06,15.91h-35.69c-3.39,0-6.15-2.71-6.15-6.04,0-2.65,1.76-4.96,4.37-5.74l3.18-.96-1.51-2.96c-.45-.88-.68-1.78-.68-2.68,0-3.33,2.76-6.04,6.15-6.04.85,0,1.71.19,2.53.55l4.33,1.92-.52-5.24c0-3.33,2.76-6.04,6.15-6.04s6.15,2.71,6.14,6.16l-.51,5.12,4.33-1.92c4.11-1.81,8.68,1.32,8.68,5.49,0,.9-.23,1.8-.68,2.68l-1.51,2.96,3.18.96c2.61.78,4.37,3.09,4.37,5.74,0,3.33-2.76,6.04-6.15,6.04h0Z'/><path class='cls-1' d='m34.35,38.72h-8.7v8.5h-6.45v-8.5h-8.65v-6.1h8.65v-8.5h6.45v8.5h8.7v6.1Z'/></svg>",
   customCss: `{container} .Supercharger-Badge {
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 1000;

}

#detail-tyre-content-table {container} .Supercharger-Badge {
    right: -5px;
    top: 10px;
}
#detail-tyre-content-table {container} .Supercharger-Badge svg {
  height: 50px;
  width: 50px;
}
@media (min-width: 992px) {
  #detail-tyre-content-table {container} .Supercharger-Badge svg {
    height: 36px;
    width: 36px;
  }
}


#tyre-recommendation {container} .Supercharger-Badge {
    right: -5px;
    top: 10px;
}
#tyre-recommendation {container} .Supercharger-Badge svg {
  height: 60px;
  width: 60px;
}`,
});
      })</script><style>
                .Supercharger-agpnj5tfcd {
                    pointer-events: none;
                    position: absolute;
                    margin: 0;
                    padding: 0;
                    left: 0;
                    top: 0;
                }
                .Supercharger-agpnj5tfcd .Supercharger-BadgeContainer {
                    position: relative;
                }
                .Supercharger-agpnj5tfcd .Supercharger-Badge {
                    pointer-events: auto; 
                    position: absolute;
                    background-color: rgba(0,0,0,0);
                    color: white;
                    font-size: 14px;
                    margin: 0px 0px;
                    padding: 0px 0px;
                    
                    
                    /* Vertical Center */
                    
                    
                    /* Horizontal Center */
                    
                      
                    /* Center */
                    
                    
                    /* Left */
                    
                    /* Right */
                    right:0;
                    
                    /* Top */
                    top:0;
                    /* Bottom */
                    
                }
            .Supercharger-agpnj5tfcd .Supercharger-Badge {
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 1000;

}

#detail-tyre-content-table .Supercharger-agpnj5tfcd .Supercharger-Badge {
    right: -5px;
    top: 10px;
}
#detail-tyre-content-table .Supercharger-agpnj5tfcd .Supercharger-Badge svg {
  height: 50px;
  width: 50px;
}
@media (min-width: 992px) {
  #detail-tyre-content-table .Supercharger-agpnj5tfcd .Supercharger-Badge svg {
    height: 36px;
    width: 36px;
  }
}


#tyre-recommendation .Supercharger-agpnj5tfcd .Supercharger-Badge {
    right: -5px;
    top: 10px;
}
#tyre-recommendation .Supercharger-agpnj5tfcd .Supercharger-Badge svg {
  height: 60px;
  width: 60px;
}</style>
<script>supercharged(function(){

new SuperchargerBadge.Badge({
   targetXPath: ".fs-article-box",
   containsText: "RONAL R71",
   position: "TopRight",
   width: `400px`,
   height: `{{height}}px`,
   margin: `20px 1px`,
   padding: `5px 5px`,
   backgroundColor: "rgba(0,0,0,0)",
   fontColor: "white",
   fontSize: "14px",
   text: "<svg onclick='$(`.campaignpopup-container`).show()' height='48px' width='48px' id='Ebene_1' xmlns='http://www.w3.org/2000/svg' viewBox='0 0 100 100'><defs><style>.cls-1{fill:#fff;}.cls-2{fill:#61ba00;}</style></defs><circle class='cls-2' cx='50' cy='50' r='50'/><path class='cls-1' d='m86.68,49c.19-.81.28-1.63.28-2.46,0-6.76-6-12.16-12.81-11.53-1.24-5.08-5.87-8.86-11.37-8.86s-10.13,3.79-11.37,8.86c-6.82-.64-12.81,4.77-12.81,11.53,0,.83.09,1.65.28,2.46-3.46,2.05-5.64,5.74-5.64,9.87,0,6.38,5.25,11.58,11.69,11.58h14.15v6.51l-3.49,5.58c-.61,1.23.28,2.67,1.65,2.67h11.07c1.37,0,2.26-1.44,1.65-2.67l-3.49-5.58v-6.51h14.15c6.45,0,11.69-5.19,11.69-11.58,0-4.13-2.18-7.82-5.63-9.87h0Zm-6.06,15.91h-35.69c-3.39,0-6.15-2.71-6.15-6.04,0-2.65,1.76-4.96,4.37-5.74l3.18-.96-1.51-2.96c-.45-.88-.68-1.78-.68-2.68,0-3.33,2.76-6.04,6.15-6.04.85,0,1.71.19,2.53.55l4.33,1.92-.52-5.24c0-3.33,2.76-6.04,6.15-6.04s6.15,2.71,6.14,6.16l-.51,5.12,4.33-1.92c4.11-1.81,8.68,1.32,8.68,5.49,0,.9-.23,1.8-.68,2.68l-1.51,2.96,3.18.96c2.61.78,4.37,3.09,4.37,5.74,0,3.33-2.76,6.04-6.15,6.04h0Z'/><path class='cls-1' d='m34.35,38.72h-8.7v8.5h-6.45v-8.5h-8.65v-6.1h8.65v-8.5h6.45v8.5h8.7v6.1Z'/></svg>",
   customCss: `{container} .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}`,
});
      })</script><style>
                .Supercharger-7vtduljtoh {
                    pointer-events: none;
                    position: absolute;
                    margin: 0;
                    padding: 0;
                    left: 0;
                    top: 0;
                }
                .Supercharger-7vtduljtoh .Supercharger-BadgeContainer {
                    position: relative;
                }
                .Supercharger-7vtduljtoh .Supercharger-Badge {
                    pointer-events: auto; 
                    position: absolute;
                    background-color: rgba(0,0,0,0);
                    color: white;
                    font-size: 14px;
                    margin: 20px 1px;
                    padding: 5px 5px;
                    
                    
                    /* Vertical Center */
                    
                    
                    /* Horizontal Center */
                    
                      
                    /* Center */
                    
                    
                    /* Left */
                    
                    /* Right */
                    right:0;
                    
                    /* Top */
                    top:0;
                    /* Bottom */
                    
                }
            .Supercharger-7vtduljtoh .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}</style>
<script>supercharged(function(){

new SuperchargerBadge.Badge({
   targetXPath: ".fs-article-box",
   containsText: "RONAL R70",
   position: "TopRight",
   width: `400px`,
   height: `{{height}}px`,
   margin: `20px 1px`,
   padding: `5px 5px`,
   backgroundColor: "rgba(0,0,0,0)",
   fontColor: "white",
   fontSize: "14px",
   text: "<svg onclick='$(`.campaignpopup-container`).show()' height='48px' width='48px' id='Ebene_1' xmlns='http://www.w3.org/2000/svg' viewBox='0 0 100 100'><defs><style>.cls-1{fill:#fff;}.cls-2{fill:#61ba00;}</style></defs><circle class='cls-2' cx='50' cy='50' r='50'/><path class='cls-1' d='m86.68,49c.19-.81.28-1.63.28-2.46,0-6.76-6-12.16-12.81-11.53-1.24-5.08-5.87-8.86-11.37-8.86s-10.13,3.79-11.37,8.86c-6.82-.64-12.81,4.77-12.81,11.53,0,.83.09,1.65.28,2.46-3.46,2.05-5.64,5.74-5.64,9.87,0,6.38,5.25,11.58,11.69,11.58h14.15v6.51l-3.49,5.58c-.61,1.23.28,2.67,1.65,2.67h11.07c1.37,0,2.26-1.44,1.65-2.67l-3.49-5.58v-6.51h14.15c6.45,0,11.69-5.19,11.69-11.58,0-4.13-2.18-7.82-5.63-9.87h0Zm-6.06,15.91h-35.69c-3.39,0-6.15-2.71-6.15-6.04,0-2.65,1.76-4.96,4.37-5.74l3.18-.96-1.51-2.96c-.45-.88-.68-1.78-.68-2.68,0-3.33,2.76-6.04,6.15-6.04.85,0,1.71.19,2.53.55l4.33,1.92-.52-5.24c0-3.33,2.76-6.04,6.15-6.04s6.15,2.71,6.14,6.16l-.51,5.12,4.33-1.92c4.11-1.81,8.68,1.32,8.68,5.49,0,.9-.23,1.8-.68,2.68l-1.51,2.96,3.18.96c2.61.78,4.37,3.09,4.37,5.74,0,3.33-2.76,6.04-6.15,6.04h0Z'/><path class='cls-1' d='m34.35,38.72h-8.7v8.5h-6.45v-8.5h-8.65v-6.1h8.65v-8.5h6.45v8.5h8.7v6.1Z'/></svg>",
   customCss: `{container} .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}`,
});
      })</script><style>
                .Supercharger-7prrh9quwej {
                    pointer-events: none;
                    position: absolute;
                    margin: 0;
                    padding: 0;
                    left: 0;
                    top: 0;
                }
                .Supercharger-7prrh9quwej .Supercharger-BadgeContainer {
                    position: relative;
                }
                .Supercharger-7prrh9quwej .Supercharger-Badge {
                    pointer-events: auto; 
                    position: absolute;
                    background-color: rgba(0,0,0,0);
                    color: white;
                    font-size: 14px;
                    margin: 20px 1px;
                    padding: 5px 5px;
                    
                    
                    /* Vertical Center */
                    
                    
                    /* Horizontal Center */
                    
                      
                    /* Center */
                    
                    
                    /* Left */
                    
                    /* Right */
                    right:0;
                    
                    /* Top */
                    top:0;
                    /* Bottom */
                    
                }
            .Supercharger-7prrh9quwej .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}</style>
<script>supercharged(function(){

new SuperchargerBadge.Badge({
   targetXPath: ".fs-article-box",
   containsText: "Brock B43",
   position: "TopRight",
   width: `400px`,
   height: `{{height}}px`,
   margin: `20px 1px`,
   padding: `5px 5px`,
   backgroundColor: "rgba(0,0,0,0)",
   fontColor: "white",
   fontSize: "14px",
   text: "<svg onclick='$(`.campaignpopup-container`).show()' height='48px' width='48px' id='Ebene_1' xmlns='http://www.w3.org/2000/svg' viewBox='0 0 100 100'><defs><style>.cls-1{fill:#fff;}.cls-2{fill:#61ba00;}</style></defs><circle class='cls-2' cx='50' cy='50' r='50'/><path class='cls-1' d='m86.68,49c.19-.81.28-1.63.28-2.46,0-6.76-6-12.16-12.81-11.53-1.24-5.08-5.87-8.86-11.37-8.86s-10.13,3.79-11.37,8.86c-6.82-.64-12.81,4.77-12.81,11.53,0,.83.09,1.65.28,2.46-3.46,2.05-5.64,5.74-5.64,9.87,0,6.38,5.25,11.58,11.69,11.58h14.15v6.51l-3.49,5.58c-.61,1.23.28,2.67,1.65,2.67h11.07c1.37,0,2.26-1.44,1.65-2.67l-3.49-5.58v-6.51h14.15c6.45,0,11.69-5.19,11.69-11.58,0-4.13-2.18-7.82-5.63-9.87h0Zm-6.06,15.91h-35.69c-3.39,0-6.15-2.71-6.15-6.04,0-2.65,1.76-4.96,4.37-5.74l3.18-.96-1.51-2.96c-.45-.88-.68-1.78-.68-2.68,0-3.33,2.76-6.04,6.15-6.04.85,0,1.71.19,2.53.55l4.33,1.92-.52-5.24c0-3.33,2.76-6.04,6.15-6.04s6.15,2.71,6.14,6.16l-.51,5.12,4.33-1.92c4.11-1.81,8.68,1.32,8.68,5.49,0,.9-.23,1.8-.68,2.68l-1.51,2.96,3.18.96c2.61.78,4.37,3.09,4.37,5.74,0,3.33-2.76,6.04-6.15,6.04h0Z'/><path class='cls-1' d='m34.35,38.72h-8.7v8.5h-6.45v-8.5h-8.65v-6.1h8.65v-8.5h6.45v8.5h8.7v6.1Z'/></svg>",
   customCss: `{container} .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}`,
});
      })</script><style>
                .Supercharger-hu2x1a5ish {
                    pointer-events: none;
                    position: absolute;
                    margin: 0;
                    padding: 0;
                    left: 0;
                    top: 0;
                }
                .Supercharger-hu2x1a5ish .Supercharger-BadgeContainer {
                    position: relative;
                }
                .Supercharger-hu2x1a5ish .Supercharger-Badge {
                    pointer-events: auto; 
                    position: absolute;
                    background-color: rgba(0,0,0,0);
                    color: white;
                    font-size: 14px;
                    margin: 20px 1px;
                    padding: 5px 5px;
                    
                    
                    /* Vertical Center */
                    
                    
                    /* Horizontal Center */
                    
                      
                    /* Center */
                    
                    
                    /* Left */
                    
                    /* Right */
                    right:0;
                    
                    /* Top */
                    top:0;
                    /* Bottom */
                    
                }
            .Supercharger-hu2x1a5ish .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}</style>
<script>supercharged(function(){

new SuperchargerBadge.Badge({
   targetXPath: ".fs-article-box",
   containsText: "Brock B41",
   position: "TopRight",
   width: `400px`,
   height: `{{height}}px`,
   margin: `20px 1px`,
   padding: `5px 5px`,
   backgroundColor: "rgba(0,0,0,0)",
   fontColor: "white",
   fontSize: "14px",
   text: "<svg onclick='$(`.campaignpopup-container`).show()' height='48px' width='48px' id='Ebene_1' xmlns='http://www.w3.org/2000/svg' viewBox='0 0 100 100'><defs><style>.cls-1{fill:#fff;}.cls-2{fill:#61ba00;}</style></defs><circle class='cls-2' cx='50' cy='50' r='50'/><path class='cls-1' d='m86.68,49c.19-.81.28-1.63.28-2.46,0-6.76-6-12.16-12.81-11.53-1.24-5.08-5.87-8.86-11.37-8.86s-10.13,3.79-11.37,8.86c-6.82-.64-12.81,4.77-12.81,11.53,0,.83.09,1.65.28,2.46-3.46,2.05-5.64,5.74-5.64,9.87,0,6.38,5.25,11.58,11.69,11.58h14.15v6.51l-3.49,5.58c-.61,1.23.28,2.67,1.65,2.67h11.07c1.37,0,2.26-1.44,1.65-2.67l-3.49-5.58v-6.51h14.15c6.45,0,11.69-5.19,11.69-11.58,0-4.13-2.18-7.82-5.63-9.87h0Zm-6.06,15.91h-35.69c-3.39,0-6.15-2.71-6.15-6.04,0-2.65,1.76-4.96,4.37-5.74l3.18-.96-1.51-2.96c-.45-.88-.68-1.78-.68-2.68,0-3.33,2.76-6.04,6.15-6.04.85,0,1.71.19,2.53.55l4.33,1.92-.52-5.24c0-3.33,2.76-6.04,6.15-6.04s6.15,2.71,6.14,6.16l-.51,5.12,4.33-1.92c4.11-1.81,8.68,1.32,8.68,5.49,0,.9-.23,1.8-.68,2.68l-1.51,2.96,3.18.96c2.61.78,4.37,3.09,4.37,5.74,0,3.33-2.76,6.04-6.15,6.04h0Z'/><path class='cls-1' d='m34.35,38.72h-8.7v8.5h-6.45v-8.5h-8.65v-6.1h8.65v-8.5h6.45v8.5h8.7v6.1Z'/></svg>",
   customCss: `{container} .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}`,
});
      })</script><style>
                .Supercharger-6vjyjv5vmr {
                    pointer-events: none;
                    position: absolute;
                    margin: 0;
                    padding: 0;
                    left: 0;
                    top: 0;
                }
                .Supercharger-6vjyjv5vmr .Supercharger-BadgeContainer {
                    position: relative;
                }
                .Supercharger-6vjyjv5vmr .Supercharger-Badge {
                    pointer-events: auto; 
                    position: absolute;
                    background-color: rgba(0,0,0,0);
                    color: white;
                    font-size: 14px;
                    margin: 20px 1px;
                    padding: 5px 5px;
                    
                    
                    /* Vertical Center */
                    
                    
                    /* Horizontal Center */
                    
                      
                    /* Center */
                    
                    
                    /* Left */
                    
                    /* Right */
                    right:0;
                    
                    /* Top */
                    top:0;
                    /* Bottom */
                    
                }
            .Supercharger-6vjyjv5vmr .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}</style>
<script>supercharged(function(){

new SuperchargerBadge.Badge({
   targetXPath: ".fs-article-box",
   containsText: "Brock B32",
   position: "TopRight",
   width: `400px`,
   height: `{{height}}px`,
   margin: `20px 1px`,
   padding: `5px 5px`,
   backgroundColor: "rgba(0,0,0,0)",
   fontColor: "white",
   fontSize: "14px",
   text: "<svg onclick='$(`.campaignpopup-container`).show()' height='48px' width='48px' id='Ebene_1' xmlns='http://www.w3.org/2000/svg' viewBox='0 0 100 100'><defs><style>.cls-1{fill:#fff;}.cls-2{fill:#61ba00;}</style></defs><circle class='cls-2' cx='50' cy='50' r='50'/><path class='cls-1' d='m86.68,49c.19-.81.28-1.63.28-2.46,0-6.76-6-12.16-12.81-11.53-1.24-5.08-5.87-8.86-11.37-8.86s-10.13,3.79-11.37,8.86c-6.82-.64-12.81,4.77-12.81,11.53,0,.83.09,1.65.28,2.46-3.46,2.05-5.64,5.74-5.64,9.87,0,6.38,5.25,11.58,11.69,11.58h14.15v6.51l-3.49,5.58c-.61,1.23.28,2.67,1.65,2.67h11.07c1.37,0,2.26-1.44,1.65-2.67l-3.49-5.58v-6.51h14.15c6.45,0,11.69-5.19,11.69-11.58,0-4.13-2.18-7.82-5.63-9.87h0Zm-6.06,15.91h-35.69c-3.39,0-6.15-2.71-6.15-6.04,0-2.65,1.76-4.96,4.37-5.74l3.18-.96-1.51-2.96c-.45-.88-.68-1.78-.68-2.68,0-3.33,2.76-6.04,6.15-6.04.85,0,1.71.19,2.53.55l4.33,1.92-.52-5.24c0-3.33,2.76-6.04,6.15-6.04s6.15,2.71,6.14,6.16l-.51,5.12,4.33-1.92c4.11-1.81,8.68,1.32,8.68,5.49,0,.9-.23,1.8-.68,2.68l-1.51,2.96,3.18.96c2.61.78,4.37,3.09,4.37,5.74,0,3.33-2.76,6.04-6.15,6.04h0Z'/><path class='cls-1' d='m34.35,38.72h-8.7v8.5h-6.45v-8.5h-8.65v-6.1h8.65v-8.5h6.45v8.5h8.7v6.1Z'/></svg>",
   customCss: `{container} .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}`,
});
      })</script><style>
                .Supercharger-ion1rxkh37 {
                    pointer-events: none;
                    position: absolute;
                    margin: 0;
                    padding: 0;
                    left: 0;
                    top: 0;
                }
                .Supercharger-ion1rxkh37 .Supercharger-BadgeContainer {
                    position: relative;
                }
                .Supercharger-ion1rxkh37 .Supercharger-Badge {
                    pointer-events: auto; 
                    position: absolute;
                    background-color: rgba(0,0,0,0);
                    color: white;
                    font-size: 14px;
                    margin: 20px 1px;
                    padding: 5px 5px;
                    
                    
                    /* Vertical Center */
                    
                    
                    /* Horizontal Center */
                    
                      
                    /* Center */
                    
                    
                    /* Left */
                    
                    /* Right */
                    right:0;
                    
                    /* Top */
                    top:0;
                    /* Bottom */
                    
                }
            .Supercharger-ion1rxkh37 .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}</style>
<script>supercharged(function(){

new SuperchargerBadge.Badge({
   targetXPath: ".fs-article-box",
   containsText: "RC34",
   position: "TopRight",
   width: `400px`,
   height: `{{height}}px`,
   margin: `20px 1px`,
   padding: `5px 5px`,
   backgroundColor: "rgba(0,0,0,0)",
   fontColor: "white",
   fontSize: "14px",
   text: "<svg onclick='$(`.campaignpopup-container`).show()' height='48px' width='48px' id='Ebene_1' xmlns='http://www.w3.org/2000/svg' viewBox='0 0 100 100'><defs><style>.cls-1{fill:#fff;}.cls-2{fill:#61ba00;}</style></defs><circle class='cls-2' cx='50' cy='50' r='50'/><path class='cls-1' d='m86.68,49c.19-.81.28-1.63.28-2.46,0-6.76-6-12.16-12.81-11.53-1.24-5.08-5.87-8.86-11.37-8.86s-10.13,3.79-11.37,8.86c-6.82-.64-12.81,4.77-12.81,11.53,0,.83.09,1.65.28,2.46-3.46,2.05-5.64,5.74-5.64,9.87,0,6.38,5.25,11.58,11.69,11.58h14.15v6.51l-3.49,5.58c-.61,1.23.28,2.67,1.65,2.67h11.07c1.37,0,2.26-1.44,1.65-2.67l-3.49-5.58v-6.51h14.15c6.45,0,11.69-5.19,11.69-11.58,0-4.13-2.18-7.82-5.63-9.87h0Zm-6.06,15.91h-35.69c-3.39,0-6.15-2.71-6.15-6.04,0-2.65,1.76-4.96,4.37-5.74l3.18-.96-1.51-2.96c-.45-.88-.68-1.78-.68-2.68,0-3.33,2.76-6.04,6.15-6.04.85,0,1.71.19,2.53.55l4.33,1.92-.52-5.24c0-3.33,2.76-6.04,6.15-6.04s6.15,2.71,6.14,6.16l-.51,5.12,4.33-1.92c4.11-1.81,8.68,1.32,8.68,5.49,0,.9-.23,1.8-.68,2.68l-1.51,2.96,3.18.96c2.61.78,4.37,3.09,4.37,5.74,0,3.33-2.76,6.04-6.15,6.04h0Z'/><path class='cls-1' d='m34.35,38.72h-8.7v8.5h-6.45v-8.5h-8.65v-6.1h8.65v-8.5h6.45v8.5h8.7v6.1Z'/></svg>",
   customCss: `{container} .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}`,
});
      })</script><style>
                .Supercharger-6qcwl0y679 {
                    pointer-events: none;
                    position: absolute;
                    margin: 0;
                    padding: 0;
                    left: 0;
                    top: 0;
                }
                .Supercharger-6qcwl0y679 .Supercharger-BadgeContainer {
                    position: relative;
                }
                .Supercharger-6qcwl0y679 .Supercharger-Badge {
                    pointer-events: auto; 
                    position: absolute;
                    background-color: rgba(0,0,0,0);
                    color: white;
                    font-size: 14px;
                    margin: 20px 1px;
                    padding: 5px 5px;
                    
                    
                    /* Vertical Center */
                    
                    
                    /* Horizontal Center */
                    
                      
                    /* Center */
                    
                    
                    /* Left */
                    
                    /* Right */
                    right:0;
                    
                    /* Top */
                    top:0;
                    /* Bottom */
                    
                }
            .Supercharger-6qcwl0y679 .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}</style>
<script>supercharged(function(){

new SuperchargerBadge.Badge({
   targetXPath: ".fs-article-box",
   containsText: "RC32",
   position: "TopRight",
   width: `400px`,
   height: `{{height}}px`,
   margin: `20px 1px`,
   padding: `5px 5px`,
   backgroundColor: "rgba(0,0,0,0)",
   fontColor: "white",
   fontSize: "14px",
   text: "<svg onclick='$(`.campaignpopup-container`).show()' height='48px' width='48px' id='Ebene_1' xmlns='http://www.w3.org/2000/svg' viewBox='0 0 100 100'><defs><style>.cls-1{fill:#fff;}.cls-2{fill:#61ba00;}</style></defs><circle class='cls-2' cx='50' cy='50' r='50'/><path class='cls-1' d='m86.68,49c.19-.81.28-1.63.28-2.46,0-6.76-6-12.16-12.81-11.53-1.24-5.08-5.87-8.86-11.37-8.86s-10.13,3.79-11.37,8.86c-6.82-.64-12.81,4.77-12.81,11.53,0,.83.09,1.65.28,2.46-3.46,2.05-5.64,5.74-5.64,9.87,0,6.38,5.25,11.58,11.69,11.58h14.15v6.51l-3.49,5.58c-.61,1.23.28,2.67,1.65,2.67h11.07c1.37,0,2.26-1.44,1.65-2.67l-3.49-5.58v-6.51h14.15c6.45,0,11.69-5.19,11.69-11.58,0-4.13-2.18-7.82-5.63-9.87h0Zm-6.06,15.91h-35.69c-3.39,0-6.15-2.71-6.15-6.04,0-2.65,1.76-4.96,4.37-5.74l3.18-.96-1.51-2.96c-.45-.88-.68-1.78-.68-2.68,0-3.33,2.76-6.04,6.15-6.04.85,0,1.71.19,2.53.55l4.33,1.92-.52-5.24c0-3.33,2.76-6.04,6.15-6.04s6.15,2.71,6.14,6.16l-.51,5.12,4.33-1.92c4.11-1.81,8.68,1.32,8.68,5.49,0,.9-.23,1.8-.68,2.68l-1.51,2.96,3.18.96c2.61.78,4.37,3.09,4.37,5.74,0,3.33-2.76,6.04-6.15,6.04h0Z'/><path class='cls-1' d='m34.35,38.72h-8.7v8.5h-6.45v-8.5h-8.65v-6.1h8.65v-8.5h6.45v8.5h8.7v6.1Z'/></svg>",
   customCss: `{container} .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}`,
});
      })</script><style>
                .Supercharger-kmodu5ktu8 {
                    pointer-events: none;
                    position: absolute;
                    margin: 0;
                    padding: 0;
                    left: 0;
                    top: 0;
                }
                .Supercharger-kmodu5ktu8 .Supercharger-BadgeContainer {
                    position: relative;
                }
                .Supercharger-kmodu5ktu8 .Supercharger-Badge {
                    pointer-events: auto; 
                    position: absolute;
                    background-color: rgba(0,0,0,0);
                    color: white;
                    font-size: 14px;
                    margin: 20px 1px;
                    padding: 5px 5px;
                    
                    
                    /* Vertical Center */
                    
                    
                    /* Horizontal Center */
                    
                      
                    /* Center */
                    
                    
                    /* Left */
                    
                    /* Right */
                    right:0;
                    
                    /* Top */
                    top:0;
                    /* Bottom */
                    
                }
            .Supercharger-kmodu5ktu8 .Supercharger-Badge {
    margin-top: 5px;
    margin-right: 5px;
    font-style: italic;
    font-family: "Calibri",sans-serif;
    text-transform: uppercase;
    z-index: 10000;
}</style>
<script>supercharged(function(){

new SuperchargerInpage.Inpage({
   targetXPath: "#tyre-recom-wrap > div:nth-child(1) > div:nth-child(1)",
   containsText: "",
   domPosition: "afterbegin",
   width: `1540px`,
   height: `500px`,
   margin: `25px 25px`,
   padding: `0px 0px`,
   html: `<img src="https://ministatic.df-automotive.de/reifenuebersicht-banner/reifenbanner-desktop.jpg" onclick="$('.campaignpopup-container').show()" class="hidden-xs">
<img src="https://ministatic.df-automotive.de/reifenuebersicht-banner/reifenbanner-mobile.jpg" onclick="$('.campaignpopup-container').show()" class="visible-xs-block">`,
   customCss: `{container} img {
    display: inline-block;
    width: 100%;
    cursor: pointer;
    margin-top: 25px;
   padding: 0px !important;
}

`
});
      })</script><style>
                .Supercharger-6avhcc75ot {
                }
                .Supercharger-6avhcc75ot .Supercharger-Inpage {
                    position: relative;
                    margin: 25px 25px;
                    padding: 0px 0px;
                    max-width: 100%;
                }
            .Supercharger-6avhcc75ot img {
    display: inline-block;
    width: 100%;
    cursor: pointer;
    margin-top: 25px;
   padding: 0px !important;
}

</style>
    <script>
        cookieIsset('df-cookie-externe-medien', function () {
            var userlikeScript = document.createElement('script');
            userlikeScript.defer = true;
            userlikeScript.setAttribute('src', 'https://userlike-cdn-widgets.s3-eu-west-1.amazonaws.com/38a811b9f9bf47098632b6c96760a822c85337defcbc48169bba2d799b21442e.js');
            document.body.appendChild(userlikeScript);
        });
    </script>




<div id="snippet-search" class="d-none">
    <div class="option search sticky">
        <img alt="search" src="/source/skin/default/img/fsv2/reifen/search.svg">
        <input class="tire-select-search-input" value="" placeholder="Suche" data-input="REPLACE-ME">
    </div>
</div>

<div id="snippet-footer" class="d-none">
    <div class="option sticky footer">
        <div class="save">Speichern</div>
        <div class="reset">Zurücksetzen</div>
    </div>
</div>
<deepl-input-controller></deepl-input-controller><script src="https://widgets.trustedshops.com/assets/trustbadge.js" charset="utf-8" data-type="trustbadge-business-logic"></script><iframe id="trustbadge-iframe" style="display: none;"></iframe><div id="trustbadge-container-98e3dadd90eb493088abdc5597a70810" style="z-index: 2147483647; position: fixed;"><div class="_t53mel"><div id="minimized-trustbadge-98e3dadd90eb493088abdc5597a70810" class="_e962gh"><p id="trustbadge-minimized-menu-button-98e3dadd90eb493088abdc5597a70810" class="_14hdeiv"><img alt="ellipsis" width="10" height="3" class="_ay4mkz" src="https://widgets.trustedshops.com/assets/images/sprite.ce0555cc1bbf340d17e00adb2d201f8dbc02ab01.svg#ellipsis-light"></p><div class="_1mh95iw"><img alt="trustmark" width="50" height="50" class="_9q4m8w" src="https://widgets.trustedshops.com/assets/images/sprite.ce0555cc1bbf340d17e00adb2d201f8dbc02ab01.svg#trustmark"><p class="_1bse7md">Käuferschutz</p></div></div></div></div></body></html>

"""
# BeautifulSoup nesnesi oluşturma
soup = BeautifulSoup(html_code, 'html.parser')

# Boş bir liste oluşturun
data = []

# Gerekli bilgileri çıkarma ve listeye ekleme
tire_boxes = soup.find_all('div', class_='row tire-box-desktop')

for tire_box in tire_boxes:
    article_size = tire_box.find('span', class_='tire-article-size')
    article_name = tire_box.find('span', class_='tire-article-name')
    load_index = tire_box.find('span', class_='tire-article-loadindex')
    speed_index = tire_box.find('span', class_='tire-article-speedindex')
    article_price = tire_box.find('span', class_='tire-buy-button-article-price')
    cube_value = tire_box.find('span', class_='cube')
    total_price = tire_box.find('span', class_='tire-buy-button-total-price')
    
    data.append({
        'Article Size': article_size.text.strip() if article_size else "",
        'Article Name': article_name.text.strip() if article_name else "",
        'Load Index': load_index.text.strip() if load_index else "",
        'Speed Index': speed_index.text.strip() if speed_index else "",
        'Article Price': article_price.text.strip() if article_price else "",
        'Cube Value': cube_value.text.strip() if cube_value else "",
        'Total Price': total_price.text.strip() if total_price else ""
    })

# Pandas DataFrame oluşturma
df = pd.DataFrame(data)

# Dosya yolunu belirleyin
dosya_yolu = 'C:/Users/Dell/Desktop/felgenshop/tire_data.csv'

# DataFrame'i CSV dosyasına kaydetme
df.to_csv(dosya_yolu, index=False)

print(f"Veriler '{dosya_yolu}' dosyasına kaydedildi.")
# Out:
# Veriler 'C:/Users/Dell/Desktop/felgenshop/tire_data.csv' dosyasına kaydedildi.
